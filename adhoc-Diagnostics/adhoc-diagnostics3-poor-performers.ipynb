# %%
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# Configuration
data_path = Path('../data/full-data/processed')
output_path = Path('../data/full-data/diagnostics')
output_path.mkdir(parents=True, exist_ok=True)

# Poor performers to investigate
POOR_PERFORMERS = ['Hotel_01', 'Hotel_14', 'Hotel_17', 'Hotel_24', 'Hotel_07', 
                   'Hotel_13', 'Hotel_21', 'Hotel_23', 'Hotel_31', 'Hotel_33', 'Hotel_36']

print("="*80)
print("DIAGNOSTIC ANALYSIS: POOR PERFORMING HOTELS")
print("="*80)
print(f"Investigating {len(POOR_PERFORMERS)} hotels with R² < 0.15")
print("-" * 80)

def analyze_hotel(hotel_id):
    """Comprehensive diagnostic for a hotel"""
    print(f"\n{'='*80}")
    print(f"HOTEL: {hotel_id}")
    print(f"{'='*80}")
    
    try:
        df = pd.read_csv(data_path / f'{hotel_id}_lagged_dataset.csv')
        df['date'] = pd.to_datetime(df['date'])
        df = df.sort_values('date').reset_index(drop=True)
        
        # Basic info
        print(f"\n1. BASIC STATISTICS:")
        print(f"   Total observations: {len(df)}")
        print(f"   Date range: {df['date'].min()} to {df['date'].max()}")
        print(f"   Base rate range: ${df['base_rate'].min():.2f} - ${df['base_rate'].max():.2f}")
        print(f"   Base rate mean: ${df['base_rate'].mean():.2f}")
        print(f"   Base rate std: ${df['base_rate'].std():.2f}")
        print(f"   Coefficient of variation: {(df['base_rate'].std() / df['base_rate'].mean()):.2%}")
        
        # Check for trends
        df['trend'] = df['base_rate'].rolling(window=30, min_periods=1).mean()
        df['deviation_from_trend'] = (df['base_rate'] - df['trend']) / df['trend']
        
        print(f"\n2. PRICE VOLATILITY:")
        print(f"   Mean absolute deviation from trend: {df['deviation_from_trend'].abs().mean():.2%}")
        print(f"   Max deviation from trend: {df['deviation_from_trend'].abs().max():.2%}")
        
        # Strong trend detection
        first_half_mean = df.iloc[:len(df)//2]['base_rate'].mean()
        second_half_mean = df.iloc[len(df)//2:]['base_rate'].mean()
        trend_change = (second_half_mean - first_half_mean) / first_half_mean
        print(f"   Price change (1st half vs 2nd half): {trend_change:.2%}")
        
        if abs(trend_change) > 0.20:
            print(f"   ⚠️ STRONG TREND DETECTED: {trend_change:.2%}")
        
        # Competitor analysis
        competitor_cols = [col for col in df.columns if '-USD' in col and 'lag_1' in col]
        print(f"\n3. COMPETITOR ANALYSIS:")
        print(f"   Number of competitors: {len(competitor_cols)}")
        
        if len(competitor_cols) > 0:
            # Correlation with competitors
            correlations = []
            for comp in competitor_cols:
                corr = df['base_rate'].corr(df[comp])
                correlations.append(corr)
            
            print(f"   Correlation with competitors:")
            print(f"     Mean: {np.mean(correlations):.3f}")
            print(f"     Max: {np.max(correlations):.3f}")
            print(f"     Min: {np.min(correlations):.3f}")
            
            if np.mean(correlations) < 0.3:
                print(f"   ⚠️ WEAK CORRELATION WITH COMPETITORS")
            
            # Missing data in competitors
            missing_rates = []
            for comp in competitor_cols:
                missing_rate = df[comp].isna().sum() / len(df)
                missing_rates.append(missing_rate)
            
            print(f"   Missing data in competitors:")
            print(f"     Mean: {np.mean(missing_rates):.1%}")
            print(f"     Max: {np.max(missing_rates):.1%}")
            
            if np.mean(missing_rates) > 0.30:
                print(f"   ⚠️ HIGH MISSING DATA IN COMPETITORS")
            
            # Check competitor price volatility
            comp_volatility = []
            for comp in competitor_cols:
                if df[comp].notna().sum() > 10:
                    cv = df[comp].std() / df[comp].mean()
                    comp_volatility.append(cv)
            
            if comp_volatility:
                print(f"   Competitor price volatility (CV):")
                print(f"     Mean: {np.mean(comp_volatility):.2%}")
                print(f"     Max: {np.max(comp_volatility):.2%}")
        
        # Seasonality check
        print(f"\n4. SEASONALITY PATTERNS:")
        df['month'] = df['date'].dt.month
        monthly_means = df.groupby('month')['base_rate'].mean()
        seasonal_range = (monthly_means.max() - monthly_means.min()) / monthly_means.mean()
        print(f"   Seasonal price range: {seasonal_range:.1%}")
        
        if seasonal_range < 0.10:
            print(f"   ⚠️ WEAK SEASONALITY")
        
        df['day_of_week'] = df['date'].dt.dayofweek
        weekly_means = df.groupby('day_of_week')['base_rate'].mean()
        weekly_range = (weekly_means.max() - weekly_means.min()) / weekly_means.mean()
        print(f"   Weekly price range: {weekly_range:.1%}")
        
        # Check for structural breaks
        print(f"\n5. STRUCTURAL BREAKS:")
        # Split into 4 quarters
        quarter_size = len(df) // 4
        quarter_means = []
        for i in range(4):
            start = i * quarter_size
            end = (i + 1) * quarter_size if i < 3 else len(df)
            quarter_means.append(df.iloc[start:end]['base_rate'].mean())
        
        max_jump = max(abs(quarter_means[i+1] - quarter_means[i]) / quarter_means[i] for i in range(3))
        print(f"   Max quarter-to-quarter change: {max_jump:.2%}")
        
        if max_jump > 0.30:
            print(f"   ⚠️ POSSIBLE STRUCTURAL BREAK")
        
        # Check for outliers
        print(f"\n6. OUTLIERS:")
        z_scores = np.abs((df['base_rate'] - df['base_rate'].mean()) / df['base_rate'].std())
        outliers = (z_scores > 3).sum()
        print(f"   Number of outliers (|z| > 3): {outliers}")
        print(f"   Percentage: {outliers / len(df):.1%}")
        
        if outliers / len(df) > 0.05:
            print(f"   ⚠️ HIGH OUTLIER RATE")
        
        # Summary diagnosis
        print(f"\n7. DIAGNOSIS SUMMARY:")
        issues = []
        
        if abs(trend_change) > 0.20:
            issues.append("Strong trend not captured by 30-day detrending")
        
        if len(competitor_cols) > 0 and np.mean(correlations) < 0.3:
            issues.append("Weak correlation with competitors - independent pricing")
        
        if len(competitor_cols) > 0 and np.mean(missing_rates) > 0.30:
            issues.append("High missing competitor data - imputation quality")
        
        if seasonal_range < 0.10:
            issues.append("Weak seasonality - temporal features less useful")
        
        if max_jump > 0.30:
            issues.append("Structural break - pricing strategy changed")
        
        if outliers / len(df) > 0.05:
            issues.append("Many outliers - data quality or special events")
        
        if issues:
            print(f"   Issues identified:")
            for i, issue in enumerate(issues, 1):
                print(f"     {i}. {issue}")
        else:
            print(f"   No clear issues identified - may need different features")
        
        # Recommendations
        print(f"\n8. RECOMMENDATIONS:")
        
        if abs(trend_change) > 0.20:
            print(f"   • Try longer detrending window (60 or 90 days)")
            print(f"   • Consider polynomial detrending")
        
        if len(competitor_cols) > 0 and np.mean(correlations) < 0.3:
            print(f"   • Add demand-side features (occupancy, booking pace)")
            print(f"   • Add autoregressive terms (own historical prices)")
            print(f"   • Consider event/holiday data")
        
        if seasonal_range > 0.20:
            print(f"   • Strong seasonality - ensure cyclic encoding is working")
            print(f"   • Consider holiday-specific features")
        
        if max_jump > 0.30:
            print(f"   • Split data before/after break and model separately")
            print(f"   • Add time period dummy variables")
        
        return {
            'hotel_id': hotel_id,
            'n_obs': len(df),
            'price_cv': df['base_rate'].std() / df['base_rate'].mean(),
            'trend_change': trend_change,
            'mean_competitor_corr': np.mean(correlations) if len(competitor_cols) > 0 else None,
            'mean_missing_rate': np.mean(missing_rates) if len(competitor_cols) > 0 else None,
            'seasonal_range': seasonal_range,
            'max_quarter_jump': max_jump,
            'outlier_rate': outliers / len(df),
            'issues': ', '.join(issues) if issues else 'None'
        }
        
    except Exception as e:
        print(f"ERROR: {str(e)}")
        return None

# Run diagnostics
results = []
for hotel_id in POOR_PERFORMERS:
    result = analyze_hotel(hotel_id)
    if result:
        results.append(result)

# Save summary
if results:
    summary_df = pd.DataFrame(results)
    summary_df.to_csv(output_path / 'poor_performers_diagnosis.csv', index=False)
    
    print(f"\n{'='*80}")
    print("OVERALL SUMMARY")
    print(f"{'='*80}")
    print(f"\nDiagnostics saved to: {output_path / 'poor_performers_diagnosis.csv'}")
    
    print(f"\nCommon Issues Across Hotels:")
    all_issues = []
    for r in results:
        if r['issues'] != 'None':
            all_issues.extend(r['issues'].split(', '))
    
    from collections import Counter
    issue_counts = Counter(all_issues)
    for issue, count in issue_counts.most_common():
        print(f"  • {issue}: {count} hotels")

print("\nComplete")
# Out:
# ================================================================================
# DIAGNOSTIC ANALYSIS: POOR PERFORMING HOTELS
# ================================================================================
# Investigating 11 hotels with R² < 0.15
# --------------------------------------------------------------------------------
#
# ================================================================================
# HOTEL: Hotel_01
# ================================================================================
#
# 1. BASIC STATISTICS:
#    Total observations: 554
#    Date range: 2025-04-01 00:00:00 to 2026-10-06 00:00:00
#    Base rate range: $169.00 - $589.00
#    Base rate mean: $266.47
#    Base rate std: $95.13
#    Coefficient of variation: 35.70%
#
# 2. PRICE VOLATILITY:
#    Mean absolute deviation from trend: 10.64%
#    Max deviation from trend: 79.73%
#    Price change (1st half vs 2nd half): -28.39%
#    ⚠️ STRONG TREND DETECTED: -28.39%
#
# 3. COMPETITOR ANALYSIS:
#    Number of competitors: 5
#    Correlation with competitors:
#      Mean: 0.756
#      Max: 0.826
#      Min: 0.685
#    Missing data in competitors:
#      Mean: 0.0%
#      Max: 0.0%
#    Competitor price volatility (CV):
#      Mean: 33.19%
#      Max: 41.80%
#
# 4. SEASONALITY PATTERNS:
#    Seasonal price range: 72.3%
#    Weekly price range: 19.8%
#
# 5. STRUCTURAL BREAKS:
#    Max quarter-to-quarter change: 46.18%
#    ⚠️ POSSIBLE STRUCTURAL BREAK
#
# 6. OUTLIERS:
#    Number of outliers (|z| > 3): 5
#    Percentage: 0.9%
#
# 7. DIAGNOSIS SUMMARY:
#    Issues identified:
#      1. Strong trend not captured by 30-day detrending
#      2. Structural break - pricing strategy changed
#
# 8. RECOMMENDATIONS:
#    • Try longer detrending window (60 or 90 days)
#    • Consider polynomial detrending
#    • Strong seasonality - ensure cyclic encoding is working
#    • Consider holiday-specific features
#    • Split data before/after break and model separately
#    • Add time period dummy variables
#
# ================================================================================
# HOTEL: Hotel_14
# ================================================================================
#
# 1. BASIC STATISTICS:
#    Total observations: 676
#    Date range: 2024-11-30 00:00:00 to 2026-10-06 00:00:00
#    Base rate range: $199.00 - $399.00
#    Base rate mean: $279.12
#    Base rate std: $40.53
#    Coefficient of variation: 14.52%
#
# 2. PRICE VOLATILITY:
#    Mean absolute deviation from trend: 7.34%
#    Max deviation from trend: 53.23%
#    Price change (1st half vs 2nd half): -3.70%
#
# 3. COMPETITOR ANALYSIS:
#    Number of competitors: 5
#    Correlation with competitors:
#      Mean: 0.350
#      Max: 0.535
#      Min: 0.128
#    Missing data in competitors:
#      Mean: 0.0%
#      Max: 0.0%
#    Competitor price volatility (CV):
#      Mean: 22.30%
#      Max: 50.72%
#
# 4. SEASONALITY PATTERNS:
#    Seasonal price range: 23.5%
#    Weekly price range: 4.7%
#
# 5. STRUCTURAL BREAKS:
#    Max quarter-to-quarter change: 16.78%
#
# 6. OUTLIERS:
#    Number of outliers (|z| > 3): 0
#    Percentage: 0.0%
#
# 7. DIAGNOSIS SUMMARY:
#    No clear issues identified - may need different features
#
# 8. RECOMMENDATIONS:
#    • Strong seasonality - ensure cyclic encoding is working
#    • Consider holiday-specific features
#
# ================================================================================
# HOTEL: Hotel_17
# ================================================================================
#
# 1. BASIC STATISTICS:
#    Total observations: 593
#    Date range: 2025-01-16 00:00:00 to 2026-08-31 00:00:00
#    Base rate range: $259.00 - $749.00
#    Base rate mean: $436.54
#    Base rate std: $106.65
#    Coefficient of variation: 24.43%
#
# 2. PRICE VOLATILITY:
#    Mean absolute deviation from trend: 15.92%
#    Max deviation from trend: 62.84%
#    Price change (1st half vs 2nd half): 4.18%
#
# 3. COMPETITOR ANALYSIS:
#    Number of competitors: 8
#    Correlation with competitors:
#      Mean: 0.350
#      Max: 0.419
#      Min: 0.283
#    Missing data in competitors:
#      Mean: 0.0%
#      Max: 0.0%
#    Competitor price volatility (CV):
#      Mean: 29.62%
#      Max: 38.83%
#
# 4. SEASONALITY PATTERNS:
#    Seasonal price range: 28.5%
#    Weekly price range: 38.9%
#
# 5. STRUCTURAL BREAKS:
#    Max quarter-to-quarter change: 31.86%
#    ⚠️ POSSIBLE STRUCTURAL BREAK
#
# 6. OUTLIERS:
#    Number of outliers (|z| > 3): 0
#    Percentage: 0.0%
#
# 7. DIAGNOSIS SUMMARY:
#    Issues identified:
#      1. Structural break - pricing strategy changed
#
# 8. RECOMMENDATIONS:
#    • Strong seasonality - ensure cyclic encoding is working
#    • Consider holiday-specific features
#    • Split data before/after break and model separately
#    • Add time period dummy variables
#
# ================================================================================
# HOTEL: Hotel_24
# ================================================================================
#
# 1. BASIC STATISTICS:
#    Total observations: 609
#    Date range: 2024-11-30 00:00:00 to 2026-07-31 00:00:00
#    Base rate range: $64.00 - $349.00
#    Base rate mean: $115.43
#    Base rate std: $45.04
#    Coefficient of variation: 39.02%
#
# 2. PRICE VOLATILITY:
#    Mean absolute deviation from trend: 18.69%
#    Max deviation from trend: 181.11%
#    Price change (1st half vs 2nd half): 33.13%
#    ⚠️ STRONG TREND DETECTED: 33.13%
#
# 3. COMPETITOR ANALYSIS:
#    Number of competitors: 10
#    Correlation with competitors:
#      Mean: 0.419
#      Max: 0.649
#      Min: 0.084
#    Missing data in competitors:
#      Mean: 0.0%
#      Max: 0.0%
#    Competitor price volatility (CV):
#      Mean: 20.39%
#      Max: 26.74%
#
# 4. SEASONALITY PATTERNS:
#    Seasonal price range: 68.3%
#    Weekly price range: 22.1%
#
# 5. STRUCTURAL BREAKS:
#    Max quarter-to-quarter change: 32.00%
#    ⚠️ POSSIBLE STRUCTURAL BREAK
#
# 6. OUTLIERS:
#    Number of outliers (|z| > 3): 7
#    Percentage: 1.1%
#
# 7. DIAGNOSIS SUMMARY:
#    Issues identified:
#      1. Strong trend not captured by 30-day detrending
#      2. Structural break - pricing strategy changed
#
# 8. RECOMMENDATIONS:
#    • Try longer detrending window (60 or 90 days)
#    • Consider polynomial detrending
#    • Strong seasonality - ensure cyclic encoding is working
#    • Consider holiday-specific features
#    • Split data before/after break and model separately
#    • Add time period dummy variables
#
# ================================================================================
# HOTEL: Hotel_07
# ================================================================================
#
# 1. BASIC STATISTICS:
#    Total observations: 675
#    Date range: 2024-12-01 00:00:00 to 2026-10-06 00:00:00
#    Base rate range: $99.00 - $379.00
#    Base rate mean: $163.22
#    Base rate std: $42.07
#    Coefficient of variation: 25.77%
#
# 2. PRICE VOLATILITY:
#    Mean absolute deviation from trend: 9.56%
#    Max deviation from trend: 91.35%
#    Price change (1st half vs 2nd half): 6.26%
#
# 3. COMPETITOR ANALYSIS:
#    Number of competitors: 8
#    Correlation with competitors:
#      Mean: 0.608
#      Max: 0.781
#      Min: 0.433
#    Missing data in competitors:
#      Mean: 0.0%
#      Max: 0.0%
#    Competitor price volatility (CV):
#      Mean: 23.04%
#      Max: 26.23%
#
# 4. SEASONALITY PATTERNS:
#    Seasonal price range: 58.2%
#    Weekly price range: 15.5%
#
# 5. STRUCTURAL BREAKS:
#    Max quarter-to-quarter change: 49.54%
#    ⚠️ POSSIBLE STRUCTURAL BREAK
#
# 6. OUTLIERS:
#    Number of outliers (|z| > 3): 3
#    Percentage: 0.4%
#
# 7. DIAGNOSIS SUMMARY:
#    Issues identified:
#      1. Structural break - pricing strategy changed
#
# 8. RECOMMENDATIONS:
#    • Strong seasonality - ensure cyclic encoding is working
#    • Consider holiday-specific features
#    • Split data before/after break and model separately
#    • Add time period dummy variables
#
# ================================================================================
# HOTEL: Hotel_13
# ================================================================================
#
# 1. BASIC STATISTICS:
#    Total observations: 615
#    Date range: 2025-01-30 00:00:00 to 2026-10-06 00:00:00
#    Base rate range: $0.00 - $289.00
#    Base rate mean: $136.78
#    Base rate std: $66.96
#    Coefficient of variation: 48.96%
#
# 2. PRICE VOLATILITY:
#    Mean absolute deviation from trend: 19.09%
#    Max deviation from trend: 111.02%
#    Price change (1st half vs 2nd half): -18.80%
#
# 3. COMPETITOR ANALYSIS:
#    Number of competitors: 9
#    Correlation with competitors:
#      Mean: 0.402
#      Max: 0.541
#      Min: 0.167
#    Missing data in competitors:
#      Mean: 0.0%
#      Max: 0.0%
#    Competitor price volatility (CV):
#      Mean: 33.83%
#      Max: 46.80%
#
# 4. SEASONALITY PATTERNS:
#    Seasonal price range: 87.6%
#    Weekly price range: 25.1%
#
# 5. STRUCTURAL BREAKS:
#    Max quarter-to-quarter change: 58.05%
#    ⚠️ POSSIBLE STRUCTURAL BREAK
#
# 6. OUTLIERS:
#    Number of outliers (|z| > 3): 0
#    Percentage: 0.0%
#
# 7. DIAGNOSIS SUMMARY:
#    Issues identified:
#      1. Structural break - pricing strategy changed
#
# 8. RECOMMENDATIONS:
#    • Strong seasonality - ensure cyclic encoding is working
#    • Consider holiday-specific features
#    • Split data before/after break and model separately
#    • Add time period dummy variables
#
# ================================================================================
# HOTEL: Hotel_21
# ================================================================================
#
# 1. BASIC STATISTICS:
#    Total observations: 640
#    Date range: 2024-11-30 00:00:00 to 2026-08-31 00:00:00
#    Base rate range: $189.00 - $799.00
#    Base rate mean: $281.86
#    Base rate std: $61.90
#    Coefficient of variation: 21.96%
#
# 2. PRICE VOLATILITY:
#    Mean absolute deviation from trend: 13.12%
#    Max deviation from trend: 153.65%
#    Price change (1st half vs 2nd half): 6.77%
#
# 3. COMPETITOR ANALYSIS:
#    Number of competitors: 10
#    Correlation with competitors:
#      Mean: 0.426
#      Max: 0.533
#      Min: 0.279
#    Missing data in competitors:
#      Mean: 0.0%
#      Max: 0.0%
#    Competitor price volatility (CV):
#      Mean: 17.29%
#      Max: 21.40%
#
# 4. SEASONALITY PATTERNS:
#    Seasonal price range: 36.2%
#    Weekly price range: 15.7%
#
# 5. STRUCTURAL BREAKS:
#    Max quarter-to-quarter change: 11.51%
#
# 6. OUTLIERS:
#    Number of outliers (|z| > 3): 11
#    Percentage: 1.7%
#
# 7. DIAGNOSIS SUMMARY:
#    No clear issues identified - may need different features
#
# 8. RECOMMENDATIONS:
#    • Strong seasonality - ensure cyclic encoding is working
#    • Consider holiday-specific features
#
# ================================================================================
# HOTEL: Hotel_23
# ================================================================================
# 1. BASIC STATISTICS:
#    Total observations: 676
#    Date range: 2024-11-30 00:00:00 to 2026-10-06 00:00:00
#    Base rate range: $199.00 - $399.00
#    Base rate mean: $304.07
#    Base rate std: $38.96
#    Coefficient of variation: 12.81%
#
# 2. PRICE VOLATILITY:
#    Mean absolute deviation from trend: 6.04%
#    Max deviation from trend: 49.10%
#    Price change (1st half vs 2nd half): 11.10%
#
# 3. COMPETITOR ANALYSIS:
#    Number of competitors: 10
#    Correlation with competitors:
#      Mean: 0.251
#      Max: 0.498
#      Min: 0.025
#    ⚠️ WEAK CORRELATION WITH COMPETITORS
#    Missing data in competitors:
#      Mean: 0.0%
#      Max: 0.0%
#    Competitor price volatility (CV):
#      Mean: 21.22%
#      Max: 51.42%
#
# 4. SEASONALITY PATTERNS:
#    Seasonal price range: 19.9%
#    Weekly price range: 3.5%
#
# 5. STRUCTURAL BREAKS:
#    Max quarter-to-quarter change: 19.14%
#
# 6. OUTLIERS:
#    Number of outliers (|z| > 3): 0
#    Percentage: 0.0%
#
# 7. DIAGNOSIS SUMMARY:
#    Issues identified:
#      1. Weak correlation with competitors - independent pricing
#
# 8. RECOMMENDATIONS:
#    • Add demand-side features (occupancy, booking pace)
#    • Add autoregressive terms (own historical prices)
#    • Consider event/holiday data
#
# ================================================================================
# HOTEL: Hotel_31
# ================================================================================
#
# 1. BASIC STATISTICS:
#    Total observations: 676
#    Date range: 2024-11-30 00:00:00 to 2026-10-06 00:00:00
#    Base rate range: $99.00 - $1019.00
#    Base rate mean: $272.88
#    Base rate std: $171.98
#    Coefficient of variation: 63.02%
#
# 2. PRICE VOLATILITY:
#    Mean absolute deviation from trend: 27.34%
#    Max deviation from trend: 299.07%
#    Price change (1st half vs 2nd half): 59.86%
#    ⚠️ STRONG TREND DETECTED: 59.86%
#
# 3. COMPETITOR ANALYSIS:
#    Number of competitors: 6
#    Correlation with competitors:
#      Mean: 0.523
#      Max: 0.593
#      Min: 0.477
#    Missing data in competitors:
#      Mean: 0.0%
#      Max: 0.0%
#    Competitor price volatility (CV):
#      Mean: 38.73%
#      Max: 45.42%
#
# 4. SEASONALITY PATTERNS:
#    Seasonal price range: 90.3%
#    Weekly price range: 48.8%
#
# 5. STRUCTURAL BREAKS:
#    Max quarter-to-quarter change: 140.23%
#    ⚠️ POSSIBLE STRUCTURAL BREAK
#
# 6. OUTLIERS:
#    Number of outliers (|z| > 3): 21
#    Percentage: 3.1%
#
# 7. DIAGNOSIS SUMMARY:
#    Issues identified:
#      1. Strong trend not captured by 30-day detrending
#      2. Structural break - pricing strategy changed
#
# 8. RECOMMENDATIONS:
#    • Try longer detrending window (60 or 90 days)
#    • Consider polynomial detrending
#    • Strong seasonality - ensure cyclic encoding is working
#    • Consider holiday-specific features
#    • Split data before/after break and model separately
#    • Add time period dummy variables
#
# ================================================================================
# HOTEL: Hotel_33
# ================================================================================
#
# 1. BASIC STATISTICS:
#    Total observations: 675
#    Date range: 2024-12-01 00:00:00 to 2026-10-06 00:00:00
#    Base rate range: $129.00 - $449.00
#    Base rate mean: $149.70
#    Base rate std: $32.03
#    Coefficient of variation: 21.39%
#
# 2. PRICE VOLATILITY:
#    Mean absolute deviation from trend: 11.47%
#    Max deviation from trend: 197.35%
#    Price change (1st half vs 2nd half): -12.84%
#
# 3. COMPETITOR ANALYSIS:
#    Number of competitors: 6
#    Correlation with competitors:
#      Mean: 0.257
#      Max: 0.400
#      Min: -0.012
#    ⚠️ WEAK CORRELATION WITH COMPETITORS
#    Missing data in competitors:
#      Mean: 0.0%
#      Max: 0.0%
#    Competitor price volatility (CV):
#      Mean: 23.61%
#      Max: 30.26%
#
# 4. SEASONALITY PATTERNS:
#    Seasonal price range: 21.0%
#    Weekly price range: 31.6%
#
# 5. STRUCTURAL BREAKS:
#    Max quarter-to-quarter change: 15.20%
#
# 6. OUTLIERS:
#    Number of outliers (|z| > 3): 8
#    Percentage: 1.2%
#
# 7. DIAGNOSIS SUMMARY:
#    Issues identified:
#      1. Weak correlation with competitors - independent pricing
#
# 8. RECOMMENDATIONS:
#    • Add demand-side features (occupancy, booking pace)
#    • Add autoregressive terms (own historical prices)
#    • Consider event/holiday data
#    • Strong seasonality - ensure cyclic encoding is working
#    • Consider holiday-specific features
#
# ================================================================================
# HOTEL: Hotel_36
# ================================================================================
#
# 1. BASIC STATISTICS:
#    Total observations: 675
#    Date range: 2024-12-01 00:00:00 to 2026-10-06 00:00:00
#    Base rate range: $35.00 - $265.00
#    Base rate mean: $124.72
#    Base rate std: $49.89
#    Coefficient of variation: 40.00%
#
# 2. PRICE VOLATILITY:
#    Mean absolute deviation from trend: 13.57%
#    Max deviation from trend: 121.92%
#    Price change (1st half vs 2nd half): 43.80%
#    ⚠️ STRONG TREND DETECTED: 43.80%
#
# 3. COMPETITOR ANALYSIS:
#    Number of competitors: 6
#    Correlation with competitors:
#      Mean: 0.709
#      Max: 0.775
#      Min: 0.546
#    Missing data in competitors:
#      Mean: 0.0%
#      Max: 0.0%
#    Competitor price volatility (CV):
#      Mean: 44.26%
#      Max: 51.96%
#
# 4. SEASONALITY PATTERNS:
#    Seasonal price range: 91.7%
#    Weekly price range: 20.3%
#
# 5. STRUCTURAL BREAKS:
#    Max quarter-to-quarter change: 135.57%
#    ⚠️ POSSIBLE STRUCTURAL BREAK
#
# 6. OUTLIERS:
#    Number of outliers (|z| > 3): 0
#    Percentage: 0.0%
#
# 7. DIAGNOSIS SUMMARY:
#    Issues identified:
#      1. Strong trend not captured by 30-day detrending
#      2. Structural break - pricing strategy changed
#
# 8. RECOMMENDATIONS:
#    • Try longer detrending window (60 or 90 days)
#    • Consider polynomial detrending
#    • Strong seasonality - ensure cyclic encoding is working
#    • Consider holiday-specific features
#    • Split data before/after break and model separately
#    • Add time period dummy variables
#
# ================================================================================
# OVERALL SUMMARY
# ================================================================================
#
# Diagnostics saved to: ..\data\full-data\diagnostics\poor_performers_diagnosis.csv
#
# Common Issues Across Hotels:
#   • Structural break - pricing strategy changed: 7 hotels
#   • Strong trend not captured by 30-day detrending: 4 hotels
#   • Weak correlation with competitors - independent pricing: 2 hotels
#
# Complete
