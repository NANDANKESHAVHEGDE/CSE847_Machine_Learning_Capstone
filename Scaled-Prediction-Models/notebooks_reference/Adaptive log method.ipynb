# %% [markdown]
# # XGB with adaptive log method

# %%
"""
COMPREHENSIVE ADAPTIVE MODEL REPORT
====================================

Generate detailed report with:
1. CV metrics (Train R², Test R², Overfitting Gap)
2. Error metrics (RMSE, MAPE, MAE) - CALCULATED DIRECTLY FROM MODEL
3. Feature details per hotel
4. Configuration details
5. Top performers table
6. Complete results table

Format similar to OutofSample-NP-XGB-Iteration2.pdf
"""

import pandas as pd
import numpy as np
import json
from pathlib import Path
import pickle
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import TimeSeriesSplit

# ============================================================================
# LOAD RESULTS
# ============================================================================

output_path = Path('../models/adaptive_log_method')

with open(output_path / 'adaptive_summary.json', 'r') as f:
    results = json.load(f)

successful = {h: r for h, r in results.items() if r.get('status') == 'success'}

print("="*80)
print("COMPREHENSIVE ADAPTIVE MODEL REPORT")
print("="*80)
print(f"Based on {len(successful)} successfully trained hotels")
print("="*80)

# ============================================================================
# LOAD DETAILED METRICS
# ============================================================================

# Metric calculation functions
def calculate_mape(y_true, y_pred, epsilon=1e-10):
    """Calculate Mean Absolute Percentage Error"""
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    mask = np.abs(y_true) > epsilon
    if mask.sum() == 0:
        return np.nan
    return np.mean(np.abs((y_true[mask] - y_pred[mask]) / y_true[mask])) * 100

def calculate_rmse(y_true, y_pred):
    """Calculate Root Mean Squared Error"""
    return np.sqrt(mean_squared_error(y_true, y_pred))

def calculate_mae(y_true, y_pred):
    """Calculate Mean Absolute Error"""
    return mean_absolute_error(y_true, y_pred)

def detrend_log_series(series, window):
    """Detrend with flexible window"""
    trend = series.rolling(window=window, min_periods=1, center=False).mean()
    detrended = series - trend
    return detrended, trend

def prepare_data_for_metrics(df, config):
    """Prepare data exactly as in training to calculate metrics"""
    df_processed = df.copy()
    feature_cols = []
    
    trend_window = config['trend_window']
    feature_set = config['feature_set']
    
    # Competitor features
    all_comp_lag_cols = [col for col in df.columns 
                         if '_lag_' in col 
                         and 'base_rate' not in col.lower()
                         and any(currency in col for currency in ['-USD', '-EUR', '-HKD', '-CNY'])]
    
    if feature_set == 'simple':
        comp_lag_cols = [col for col in all_comp_lag_cols 
                        if any(f'_lag_{i}' in col for i in [1, 2, 3, 4, 5])]
    else:
        comp_lag_cols = all_comp_lag_cols
    
    # Log + detrend
    for col in comp_lag_cols:
        log_prices = np.log(df_processed[col].replace(0, np.nan))
        detrended, _ = detrend_log_series(log_prices, window=trend_window)
        df_processed[f'{col}_log_detrended'] = detrended
        feature_cols.append(f'{col}_log_detrended')
    
    # Market aggregates (extended only)
    if feature_set == 'extended':
        lag1_cols = [col for col in comp_lag_cols if '_lag_1' in col]
        
        if len(lag1_cols) > 1:
            for col in lag1_cols:
                df_processed[f'{col}_log'] = np.log(df_processed[col].replace(0, np.nan))
            
            lag1_log_cols = [f'{col}_log' for col in lag1_cols]
            
            df_processed['comp_mean_log'] = df_processed[lag1_log_cols].mean(axis=1)
            df_processed['comp_min_log'] = df_processed[lag1_log_cols].min(axis=1)
            df_processed['comp_max_log'] = df_processed[lag1_log_cols].max(axis=1)
            df_processed['comp_std_log'] = df_processed[lag1_log_cols].std(axis=1)
            
            feature_cols.extend(['comp_mean_log', 'comp_min_log', 'comp_max_log', 'comp_std_log'])
    
    # Temporal features
    temporal_cols = ['day_of_week', 'month', 'is_weekend', 'day_of_year']
    temporal_cols = [col for col in temporal_cols if col in df_processed.columns]
    feature_cols.extend(temporal_cols)
    
    if 'day_of_week' in df_processed.columns:
        df_processed['sin_day_of_week'] = np.sin(2 * np.pi * df_processed['day_of_week'] / 7)
        df_processed['cos_day_of_week'] = np.cos(2 * np.pi * df_processed['day_of_week'] / 7)
        feature_cols.extend(['sin_day_of_week', 'cos_day_of_week'])
    
    if 'month' in df_processed.columns:
        df_processed['sin_month'] = np.sin(2 * np.pi * df_processed['month'] / 12)
        df_processed['cos_month'] = np.cos(2 * np.pi * df_processed['month'] / 12)
        feature_cols.extend(['sin_month', 'cos_month'])
    
    if 'day_of_year' in df_processed.columns:
        df_processed['sin_day_of_year'] = np.sin(2 * np.pi * df_processed['day_of_year'] / 365)
        df_processed['cos_day_of_year'] = np.cos(2 * np.pi * df_processed['day_of_year'] / 365)
        feature_cols.extend(['sin_day_of_year', 'cos_day_of_year'])
    
    X = df_processed[feature_cols].copy()
    
    # Target
    y_original = df_processed['base_rate']
    y_log = np.log(y_original.replace(0, np.nan))
    y_detrended, y_trend = detrend_log_series(y_log, window=trend_window)
    
    # Drop NaN
    valid_idx = ~(X.isnull().any(axis=1) | y_detrended.isnull() | y_log.isnull())
    X = X[valid_idx].reset_index(drop=True)
    y_detrended = y_detrended[valid_idx].reset_index(drop=True)
    y_log = y_log[valid_idx].reset_index(drop=True)
    y_trend = y_trend[valid_idx].reset_index(drop=True)
    y_original = y_original[valid_idx].reset_index(drop=True)
    
    return X, y_detrended, y_log, y_trend, y_original, feature_cols

processed_data_path = Path('../data/full-data/processed')
DATA_END_DATE = '2025-12-31'

detailed_results = []

for hotel_id, result in successful.items():
    try:
        # Load model to get feature details
        model_file = output_path / f'{hotel_id}_model.pkl'
        with open(model_file, 'rb') as f:
            model_data = pickle.load(f)
        
        model = model_data['model']
        scaler = model_data['scaler']
        config = model_data['config']
        
        # Load data to calculate additional metrics
        data_file = processed_data_path / f'{hotel_id}_lagged_dataset.csv'
        df = pd.read_csv(data_file)
        df['date'] = pd.to_datetime(df['date'])
        df = df[df['date'] <= DATA_END_DATE].copy()
        
        # Get competitor count
        comp_cols = [col for col in df.columns 
                    if '_lag_' in col 
                    and 'base_rate' not in col.lower()
                    and any(currency in col for currency in ['-USD', '-EUR', '-HKD', '-CNY'])]
        
        # Count unique competitors (remove lag suffix)
        unique_comps = set()
        for col in comp_cols:
            # Extract competitor name (before _lag_)
            comp_name = col.split('_lag_')[0]
            unique_comps.add(comp_name)
        
        n_competitors = len(unique_comps)
        
        # Calculate additional metrics from data
        base_rates = df['base_rate'].values
        mean_price = float(np.mean(base_rates))
        std_price = float(np.std(base_rates))
        
        # ====================================================================
        # CALCULATE RMSE, MAE, MAPE DIRECTLY FROM MODEL
        # ====================================================================
        
        train_rmse, test_rmse = np.nan, np.nan
        train_mae, test_mae = np.nan, np.nan
        train_mape, test_mape = np.nan, np.nan
        
        try:
            # Prepare data
            X, y_detrended, y_log, y_trend, y_original, feature_cols = prepare_data_for_metrics(df, config)
            
            if len(X) > 0:
                # Scale features
                X_scaled = scaler.transform(X)
                
                # Setup cross-validation
                min_train_size = config.get('min_train_days', 200)
                n_splits = max(2, len(X) // 100)
                tscv = TimeSeriesSplit(n_splits=n_splits)
                
                train_actuals = []
                train_preds = []
                test_actuals = []
                test_preds = []
                
                # Use last CV fold for metrics (same as what was used for R² calculation)
                for train_idx, test_idx in tscv.split(X_scaled):
                    if len(train_idx) < min_train_size:
                        continue
                    
                    # This is the last valid fold
                    X_train_fold = X_scaled[train_idx]
                    X_test_fold = X_scaled[test_idx]
                    y_train_fold = y_detrended.iloc[train_idx]
                    y_test_fold = y_detrended.iloc[test_idx]
                    y_trend_train = y_trend.iloc[train_idx]
                    y_trend_test = y_trend.iloc[test_idx]
                    y_orig_train = y_original.iloc[train_idx]
                    y_orig_test = y_original.iloc[test_idx]
                
                # Make predictions
                train_pred_detrended = model.predict(X_train_fold)
                test_pred_detrended = model.predict(X_test_fold)
                
                # Transform back to original scale
                train_pred_log = train_pred_detrended + y_trend_train.values
                test_pred_log = test_pred_detrended + y_trend_test.values
                
                train_pred_original = np.exp(train_pred_log)
                test_pred_original = np.exp(test_pred_log)
                
                # Calculate metrics
                train_rmse = calculate_rmse(y_orig_train.values, train_pred_original)
                train_mae = calculate_mae(y_orig_train.values, train_pred_original)
                train_mape = calculate_mape(y_orig_train.values, train_pred_original)
                
                test_rmse = calculate_rmse(y_orig_test.values, test_pred_original)
                test_mae = calculate_mae(y_orig_test.values, test_pred_original)
                test_mape = calculate_mape(y_orig_test.values, test_pred_original)
                
        except Exception as e:
            print(f"  Warning: Could not calculate error metrics for {hotel_id}: {e}")
        
        detailed_results.append({
            'hotel_id': hotel_id,
            'observations': len(df),
            'n_features': result['n_features'],
            'n_competitors': n_competitors,
            'train_r2': result['train_r2'],
            'test_r2': result['test_r2'],
            'overfitting_gap': result['train_r2'] - result['test_r2'],
            'train_rmse': train_rmse,
            'test_rmse': test_rmse,
            'train_mae': train_mae,
            'test_mae': test_mae,
            'train_mape': train_mape,
            'test_mape': test_mape,
            'n_folds': result['n_folds'],
            'trend_window': result['trend_window'],
            'feature_set': result['feature_set'],
            'min_train_days': result['min_train_days'],
            'mean_price': mean_price,
            'std_price': std_price,
            'n_configs_tried': result['n_configs_tried']
        })
        
    except Exception as e:
        print(f"Error processing {hotel_id}: {e}")

df_results = pd.DataFrame(detailed_results)
df_results = df_results.sort_values('test_r2', ascending=False)

# ============================================================================
# SECTION 1: OVERALL PERFORMANCE SUMMARY
# ============================================================================

print(f"\n{'='*80}")
print("1. OVERALL PERFORMANCE SUMMARY")
print(f"{'='*80}")

print(f"\nAggregate Statistics:")
print(f"  Hotels Processed: {len(successful)}")
print(f"  Mean Test R²: {df_results['test_r2'].mean():.4f}")
print(f"  Median Test R²: {df_results['test_r2'].median():.4f}")
print(f"  Std Test R²: {df_results['test_r2'].std():.4f}")
print(f"  Min Test R²: {df_results['test_r2'].min():.4f}")
print(f"  Max Test R²: {df_results['test_r2'].max():.4f}")

print(f"\nTraining Performance:")
print(f"  Mean Train R²: {df_results['train_r2'].mean():.4f}")
print(f"  Median Train R²: {df_results['train_r2'].median():.4f}")

print(f"\nOverfitting Analysis:")
print(f"  Mean Overfitting Gap: {df_results['overfitting_gap'].mean():.4f}")
print(f"  Median Overfitting Gap: {df_results['overfitting_gap'].median():.4f}")
print(f"  Gap Std Dev: {df_results['overfitting_gap'].std():.4f}")

print(f"\nError Metrics:")
print(f"  Mean Test RMSE: ${df_results['test_rmse'].mean():.2f}")
print(f"  Median Test RMSE: ${df_results['test_rmse'].median():.2f}")
print(f"  Mean Test MAE: ${df_results['test_mae'].mean():.2f}")
print(f"  Median Test MAE: ${df_results['test_mae'].median():.2f}")
print(f"  Mean Test MAPE: {df_results['test_mape'].mean():.2f}%")
print(f"  Median Test MAPE: {df_results['test_mape'].median():.2f}%")

print(f"\nComparison to Baseline (22 hotels each):")
print(f"  {'Metric':<25} {'Baseline':<12} {'Adaptive':<12} {'Improvement':<12}")
print(f"  {'-'*60}")
print(f"  {'Mean Test R²':<25} {0.1156:<12.4f} {df_results['test_r2'].mean():<12.4f} {((df_results['test_r2'].mean() - 0.1156) / 0.1156 * 100):>+11.1f}%")
print(f"  {'Median Test R²':<25} {0.2236:<12.4f} {df_results['test_r2'].median():<12.4f} {((df_results['test_r2'].median() - 0.2236) / 0.2236 * 100):>+11.1f}%")
print(f"  {'Max Test R²':<25} {0.6421:<12.4f} {df_results['test_r2'].max():<12.4f} {((df_results['test_r2'].max() - 0.6421) / 0.6421 * 100):>+11.1f}%")

# ============================================================================
# SECTION 2: CONFIGURATION ANALYSIS
# ============================================================================

print(f"\n{'='*80}")
print("2. CONFIGURATION ANALYSIS")
print(f"{'='*80}")

print(f"\nDetrending Window Distribution:")
window_dist = df_results['trend_window'].value_counts().sort_index()
for window, count in window_dist.items():
    pct = count / len(df_results) * 100
    print(f"  {window:2d}-day window: {count:2d} hotels ({pct:5.1f}%)")

print(f"\nFeature Set Distribution:")
feature_dist = df_results['feature_set'].value_counts()
for fset, count in feature_dist.items():
    pct = count / len(df_results) * 100
    print(f"  {fset:10s}: {count:2d} hotels ({pct:5.1f}%)")

print(f"\nMin Training Days Distribution:")
train_dist = df_results['min_train_days'].value_counts().sort_index()
for days, count in train_dist.items():
    pct = count / len(df_results) * 100
    print(f"  {days:3d} days: {count:2d} hotels ({pct:5.1f}%)")

print(f"\nFeature Count Statistics:")
print(f"  Mean: {df_results['n_features'].mean():.1f}")
print(f"  Median: {df_results['n_features'].median():.1f}")
print(f"  Min: {df_results['n_features'].min()}")
print(f"  Max: {df_results['n_features'].max()}")

print(f"\nCompetitor Count Statistics:")
print(f"  Mean: {df_results['n_competitors'].mean():.1f}")
print(f"  Median: {df_results['n_competitors'].median():.1f}")
print(f"  Min: {df_results['n_competitors'].min()}")
print(f"  Max: {df_results['n_competitors'].max()}")

# ============================================================================
# SECTION 3: TOP 10 PERFORMERS
# ============================================================================

print(f"\n{'='*80}")
print("3. TOP 10 PERFORMING HOTELS")
print(f"{'='*80}")
print(f"\n{'Hotel':<12} {'Test R²':<9} {'RMSE':<9} {'MAE':<9} {'MAPE':<9} {'Window':<8} {'Features':<8}")
print(f"{'-'*80}")

for idx, row in df_results.head(10).iterrows():
    print(f"{row['hotel_id']:<12} {row['test_r2']:<9.4f} ${row['test_rmse']:<8.2f} "
          f"${row['test_mae']:<8.2f} {row['test_mape']:<8.2f}% {row['trend_window']:<8} {row['n_features']:<8}")

# ============================================================================
# SECTION 4: COMPLETE RESULTS TABLE (like your PDF)
# ============================================================================

print(f"\n{'='*80}")
print("4. COMPLETE RESULTS TABLE - ALL 22 HOTELS")
print(f"{'='*80}")
print(f"\nTable: Adaptive Log Detrending - Complete Results")
print(f"\n{'Hotel':<12} {'Obs':<5} {'Feat':<5} {'Comps':<6} {'Train R²':<9} {'Test R²':<9} {'Gap':<9} {'RMSE':<9} {'MAE':<9} {'MAPE':<9} {'Window':<7} {'FeatureSet':<10}")
print(f"{'-'*120}")

for idx, row in df_results.iterrows():
    print(f"{row['hotel_id']:<12} {row['observations']:<5} {row['n_features']:<5} "
          f"{row['n_competitors']:<6} {row['train_r2']:<9.4f} {row['test_r2']:<9.4f} "
          f"{row['overfitting_gap']:<9.4f} ${row['test_rmse']:<8.2f} ${row['test_mae']:<8.2f} "
          f"{row['test_mape']:<8.2f}% {row['trend_window']:<7} {row['feature_set']:<10}")

# ============================================================================
# SECTION 5: FEATURE DETAILS FOR TOP 5 HOTELS
# ============================================================================

print(f"\n{'='*80}")
print("5. DETAILED FEATURE BREAKDOWN - TOP 5 HOTELS")
print(f"{'='*80}")

for idx, row in df_results.head(5).iterrows():
    hotel_id = row['hotel_id']
    
    print(f"\n{hotel_id}: {row['n_features']} total features")
    print(f"  Configuration:")
    print(f"    - Detrending window: {row['trend_window']} days")
    print(f"    - Feature set: {row['feature_set']}")
    print(f"    - Min training: {row['min_train_days']} days")
    print(f"    - Competitors: {row['n_competitors']}")
    print(f"  Performance:")
    print(f"    - Test R²: {row['test_r2']:.4f}")
    print(f"    - Train R²: {row['train_r2']:.4f}")
    print(f"    - Overfitting gap: {row['overfitting_gap']:.4f}")
    print(f"    - Test RMSE: ${row['test_rmse']:.2f}")
    print(f"    - Test MAE: ${row['test_mae']:.2f}")
    print(f"    - Test MAPE: {row['test_mape']:.2f}%")
    print(f"  Data:")
    print(f"    - Observations: {row['observations']}")
    print(f"    - CV folds: {row['n_folds']}")
    print(f"    - Configs tried: {row['n_configs_tried']}")
    
    # Load model to show feature names
    try:
        model_file = output_path / f'{hotel_id}_model.pkl'
        with open(model_file, 'rb') as f:
            model_data = pickle.load(f)
        
        feature_cols = model_data['feature_cols']
        
        # Categorize features
        comp_features = [f for f in feature_cols if 'lag' in f.lower() and 'detrended' in f]
        market_features = [f for f in feature_cols if 'comp_' in f and 'detrended' not in f]
        temporal_features = [f for f in feature_cols if f not in comp_features + market_features]
        
        print(f"  Feature breakdown:")
        print(f"    - Competitor lag features: {len(comp_features)}")
        print(f"    - Market aggregate features: {len(market_features)}")
        print(f"    - Temporal features: {len(temporal_features)}")
        
        if row['feature_set'] == 'simple':
            print(f"    - Using lags 1-5 only (simple)")
        else:
            print(f"    - Using all available lags (extended)")
        
    except:
        pass

# ============================================================================
# SECTION 6: PERFORMANCE DISTRIBUTION
# ============================================================================

print(f"\n{'='*80}")
print("6. PERFORMANCE DISTRIBUTION")
print(f"{'='*80}")

bins = [
    (float('-inf'), 0, 'Negative', '❌'),
    (0, 0.2, 'Low (0-0.2)', '✓'),
    (0.2, 0.4, 'Medium (0.2-0.4)', '⭐'),
    (0.4, 0.6, 'High (0.4-0.6)', '🌟'),
    (0.6, float('inf'), 'Very High (>0.6)', '🏆')
]

print(f"\n{'Tier':<25} {'Count':<8} {'Percentage':<12} {'Hotels'}")
print(f"{'-'*80}")

for low, high, label, emoji in bins:
    if high == float('inf'):
        hotels_in_bin = df_results[df_results['test_r2'] > low]
    elif low == float('-inf'):
        hotels_in_bin = df_results[df_results['test_r2'] <= high]
    else:
        hotels_in_bin = df_results[(df_results['test_r2'] > low) & (df_results['test_r2'] <= high)]
    
    count = len(hotels_in_bin)
    pct = count / len(df_results) * 100
    hotel_ids = ', '.join(hotels_in_bin['hotel_id'].tolist()[:5])
    if count > 5:
        hotel_ids += f", ... ({count-5} more)"
    
    print(f"{emoji} {label:<22} {count:<8} {pct:>5.1f}%        {hotel_ids}")

# ============================================================================
# SECTION 7: KEY INSIGHTS
# ============================================================================

print(f"\n{'='*80}")
print("7. KEY INSIGHTS")
print(f"{'='*80}")

print(f"\n✅ SUCCESS FACTORS:")
print(f"  1. 7-day detrending window works best for ALL hotels")
print(f"     - Short window = better captures recent price changes")
print(f"     - More responsive to market dynamics")

simple_r2 = df_results[df_results['feature_set'] == 'simple']['test_r2'].mean()
extended_r2 = df_results[df_results['feature_set'] == 'extended']['test_r2'].mean()

print(f"\n  2. Simple features (lags 1-5) generally outperform extended")
print(f"     - Simple mean R²: {simple_r2:.4f}")
print(f"     - Extended mean R²: {extended_r2:.4f}")
print(f"     - 16/22 hotels (72.7%) chose simple features")

print(f"\n  3. Adaptive approach achieved excellent results:")
print(f"     - +303% mean improvement vs baseline")
print(f"     - +98% median improvement vs baseline")
print(f"     - 21/22 hotels with R² > 0 (95.5% success rate)")
print(f"     - Mean Test MAPE: {df_results['test_mape'].mean():.2f}%")
print(f"     - Mean Test RMSE: ${df_results['test_rmse'].mean():.2f}")

print(f"\n  4. Coverage matches baseline:")
print(f"     - Both methods: 22 hotels")
print(f"     - But adaptive has MUCH better performance")

print(f"\n⚠️  AREAS FOR IMPROVEMENT:")
print(f"  1. One hotel (Hotel_24) still has negative R²")
print(f"     - May need special handling or fallback")

gap_high = df_results[df_results['overfitting_gap'] > 0.5]
print(f"\n  2. {len(gap_high)} hotels have overfitting gap > 0.5")
print(f"     - Mean gap: {df_results['overfitting_gap'].mean():.4f}")
print(f"     - May benefit from stronger regularization")

# ============================================================================
# SECTION 8: SAVE COMPREHENSIVE REPORT
# ============================================================================

print(f"\n{'='*80}")
print("8. SAVING COMPREHENSIVE REPORT")
print(f"{'='*80}")

# Save detailed CSV
df_results.to_csv(output_path / 'comprehensive_report.csv', index=False)
print(f"\n✅ Saved: comprehensive_report.csv")

# Save summary statistics
summary_stats = {
    'total_hotels': len(successful),
    'mean_test_r2': float(df_results['test_r2'].mean()),
    'median_test_r2': float(df_results['test_r2'].median()),
    'mean_train_r2': float(df_results['train_r2'].mean()),
    'mean_overfitting_gap': float(df_results['overfitting_gap'].mean()),
    'mean_test_rmse': float(df_results['test_rmse'].mean()),
    'median_test_rmse': float(df_results['test_rmse'].median()),
    'mean_test_mae': float(df_results['test_mae'].mean()),
    'median_test_mae': float(df_results['test_mae'].median()),
    'mean_test_mape': float(df_results['test_mape'].mean()),
    'median_test_mape': float(df_results['test_mape'].median()),
    'baseline_comparison': {
        'baseline_mean_r2': 0.1156,
        'baseline_median_r2': 0.2236,
        'improvement_mean_pct': float((df_results['test_r2'].mean() - 0.1156) / 0.1156 * 100),
        'improvement_median_pct': float((df_results['test_r2'].median() - 0.2236) / 0.2236 * 100)
    },
    'configuration_insights': {
        'most_common_window': int(df_results['trend_window'].mode()[0]),
        'most_common_feature_set': str(df_results['feature_set'].mode()[0]),
        'mean_features': float(df_results['n_features'].mean()),
        'mean_competitors': float(df_results['n_competitors'].mean())
    }
}

with open(output_path / 'summary_statistics.json', 'w') as f:
    json.dump(summary_stats, f, indent=2)
print(f"✅ Saved: summary_statistics.json")

# Create deployment guide
deployment_guide = df_results[[
    'hotel_id', 'test_r2', 'test_rmse', 'test_mae', 'test_mape',
    'trend_window', 'feature_set', 
    'n_features', 'n_competitors', 'n_folds'
]].copy()
deployment_guide['status'] = deployment_guide['test_r2'].apply(
    lambda x: 'DEPLOY' if x > 0.2 else ('REVIEW' if x > 0 else 'FALLBACK')
)
deployment_guide.to_csv(output_path / 'deployment_guide.csv', index=False)
print(f"✅ Saved: deployment_guide.csv")

print(f"\n{'='*80}")
print("🎉 COMPREHENSIVE REPORT COMPLETE!")
print(f"{'='*80}")
print(f"\nGenerated files:")
print(f"  📊 comprehensive_report.csv - Full details for all hotels (WITH RMSE, MAE, MAPE)")
print(f"  📈 summary_statistics.json - Aggregate statistics (WITH ERROR METRICS)")
print(f"  🚀 deployment_guide.csv - Deployment recommendations (WITH ERROR METRICS)")
print(f"\nLocation: {output_path}/")
print(f"\n{'='*80}")
# Out:
# ================================================================================
# COMPREHENSIVE ADAPTIVE MODEL REPORT
# ================================================================================
# Based on 22 successfully trained hotels
# ================================================================================
#
# ================================================================================
# 1. OVERALL PERFORMANCE SUMMARY
# ================================================================================
#
# Aggregate Statistics:
#   Hotels Processed: 22
#   Mean Test R²: 0.4659
#   Median Test R²: 0.4426
#   Std Test R²: 0.2469
#   Min Test R²: -0.2555
#   Max Test R²: 0.7890
#
# Training Performance:
#   Mean Train R²: 0.7947
#   Median Train R²: 0.7841
#
# Overfitting Analysis:
#   Mean Overfitting Gap: 0.3288
#   Median Overfitting Gap: 0.3087
#   Gap Std Dev: 0.2563
#
# Error Metrics:
#   Mean Test RMSE: $25.65
#   Median Test RMSE: $20.57
#   Mean Test MAE: $16.65
#   Median Test MAE: $13.83
#   Mean Test MAPE: 6.43%
#   Median Test MAPE: 6.57%
#
# Comparison to Baseline (22 hotels each):
#   Metric                    Baseline     Adaptive     Improvement
#   ------------------------------------------------------------
#   Mean Test R²              0.1156       0.4659            +303.0%
#   Median Test R²            0.2236       0.4426             +97.9%
#   Max Test R²               0.6421       0.7890             +22.9%
#
# ================================================================================
# 2. CONFIGURATION ANALYSIS
# ================================================================================
#
# Detrending Window Distribution:
#    7-day window: 22 hotels (100.0%)
#
# Feature Set Distribution:
#   simple    : 16 hotels ( 72.7%)
#   extended  :  6 hotels ( 27.3%)
#
# Min Training Days Distribution:
#   180 days:  6 hotels ( 27.3%)
#   200 days:  8 hotels ( 36.4%)
#   250 days:  8 hotels ( 36.4%)
#
# Feature Count Statistics:
#   Mean: 48.6
#   Median: 50.0
#   Min: 29
#   Max: 64
#
# Competitor Count Statistics:
#   Mean: 7.5
#   Median: 8.0
#   Min: 3
#   Max: 10
#
# ================================================================================
# 3. TOP 10 PERFORMING HOTELS
# ================================================================================
#
# Hotel        Test R²   RMSE      MAE       MAPE      Window   Features
# --------------------------------------------------------------------------------
# Hotel_22     0.7890    $5.05     $3.30     1.49    % 7        55
# Hotel_17     0.7399    $50.82    $36.83    8.47    % 7        50
# Hotel_33     0.7105    $9.92     $7.53     4.81    % 7        44
# Hotel_04     0.7103    $13.02    $9.37     6.84    % 7        30
# Hotel_13     0.7098    $10.27    $7.37     5.49    % 7        55
# Hotel_31     0.6609    $63.73    $29.15    10.50   % 7        40
# Hotel_36     0.6473    $7.07     $5.26     4.88    % 7        40
# Hotel_25     0.6201    $16.39    $12.29    6.91    % 7        60
# Hotel_32     0.6131    $70.61    $55.49    8.39    % 7        35
# Hotel_05     0.5496    $27.72    $18.09    7.22    % 7        64
#
# ================================================================================
# 4. COMPLETE RESULTS TABLE - ALL 22 HOTELS
# ================================================================================
#
# Table: Adaptive Log Detrending - Complete Results
#
# Hotel        Obs   Feat  Comps  Train R²  Test R²   Gap       RMSE      MAE       MAPE      Window  FeatureSet
# ------------------------------------------------------------------------------------------------------------------------
# Hotel_22     397   55    9      0.7767    0.7890    -0.0123   $5.05     $3.30     1.49    % 7       simple
# Hotel_17     350   50    8      0.8291    0.7399    0.0892    $50.82    $36.83    8.47    % 7       simple
# Hotel_33     396   44    6      0.5893    0.7105    -0.1212   $9.92     $7.53     4.81    % 7       extended
# Hotel_04     341   30    4      0.7915    0.7103    0.0812    $13.02    $9.37     6.84    % 7       simple
# Hotel_13     336   55    9      0.9366    0.7098    0.2268    $10.27    $7.37     5.49    % 7       simple
# Hotel_31     397   40    6      0.8338    0.6609    0.1729    $63.73    $29.15    10.50   % 7       simple
# Hotel_36     396   40    6      0.9400    0.6473    0.2927    $7.07     $5.26     4.88    % 7       simple
# Hotel_25     396   60    10     0.8640    0.6201    0.2439    $16.39    $12.29    6.91    % 7       simple
# Hotel_32     334   35    5      0.7042    0.6131    0.0911    $70.61    $55.49    8.39    % 7       simple
# Hotel_05     396   64    10     0.9481    0.5496    0.3985    $27.72    $18.09    7.22    % 7       extended
# Hotel_23     397   60    10     0.7089    0.4457    0.2632    $13.72    $8.57     2.87    % 7       simple
# Hotel_03     396   55    9      0.9309    0.4395    0.4914    $23.57    $14.31    5.84    % 7       simple
# Hotel_14     397   35    5      0.7075    0.4358    0.2717    $26.04    $17.92    6.85    % 7       simple
# Hotel_26     397   64    10     0.7398    0.4150    0.3248    $25.88    $16.24    6.14    % 7       extended
# Hotel_07     396   50    8      0.8685    0.3865    0.4820    $13.23    $8.52     5.57    % 7       simple
# Hotel_28     316   44    6      0.7446    0.3664    0.3782    $53.49    $23.62    11.06   % 7       extended
# Hotel_21     397   60    10     0.7391    0.3145    0.4245    $31.33    $20.76    6.56    % 7       simple
# Hotel_30     396   29    3      0.7528    0.2967    0.4561    $20.98    $13.35    9.58    % 7       extended
# Hotel_10     323   55    9      0.6517    0.2933    0.3585    $8.00     $5.54     3.45    % 7       simple
# Hotel_34     324   45    7      0.7665    0.2604    0.5061    $46.99    $33.56    7.85    % 7       simple
# Hotel_01     275   35    5      0.8479    0.1001    0.7477    $20.15    $15.27    6.58    % 7       simple
# Hotel_24     397   64    10     0.8109    -0.2555   1.0664    $6.23     $3.98     4.08    % 7       extended
#
# ================================================================================
# 5. DETAILED FEATURE BREAKDOWN - TOP 5 HOTELS
# ================================================================================
#
# Hotel_22: 55 total features
#   Configuration:
#     - Detrending window: 7 days
#     - Feature set: simple
#     - Min training: 250 days
#     - Competitors: 9
#   Performance:
#     - Test R²: 0.7890
#     - Train R²: 0.7767
#     - Overfitting gap: -0.0123
#     - Test RMSE: $5.05
#     - Test MAE: $3.30
#     - Test MAPE: 1.49%
#   Data:
#     - Observations: 397
#     - CV folds: 4
#     - Configs tried: 24
#   Feature breakdown:
#     - Competitor lag features: 45
#     - Market aggregate features: 0
#     - Temporal features: 10
#     - Using lags 1-5 only (simple)
#
# Hotel_17: 50 total features
#   Configuration:
#     - Detrending window: 7 days
#     - Feature set: simple
#     - Min training: 250 days
#     - Competitors: 8
#   Performance:
#     - Test R²: 0.7399
#     - Train R²: 0.8291
#     - Overfitting gap: 0.0892
#     - Test RMSE: $50.82
#     - Test MAE: $36.83
#     - Test MAPE: 8.47%
#   Data:
#     - Observations: 350
#     - CV folds: 3
#     - Configs tried: 24
#   Feature breakdown:
#     - Competitor lag features: 40
#     - Market aggregate features: 0
#     - Temporal features: 10
#     - Using lags 1-5 only (simple)
#
# Hotel_33: 44 total features
#   Configuration:
#     - Detrending window: 7 days
#     - Feature set: extended
#     - Min training: 250 days
#     - Competitors: 6
#   Performance:
#     - Test R²: 0.7105
#     - Train R²: 0.5893
#     - Overfitting gap: -0.1212
#     - Test RMSE: $9.92
#     - Test MAE: $7.53
#     - Test MAPE: 4.81%
#   Data:
#     - Observations: 396
#     - CV folds: 4
#     - Configs tried: 24
#   Feature breakdown:
#     - Competitor lag features: 30
#     - Market aggregate features: 4
#     - Temporal features: 10
#     - Using all available lags (extended)
#
# Hotel_04: 30 total features
#   Configuration:
#     - Detrending window: 7 days
#     - Feature set: simple
#     - Min training: 250 days
#     - Competitors: 4
#   Performance:
#     - Test R²: 0.7103
#     - Train R²: 0.7915
#     - Overfitting gap: 0.0812
#     - Test RMSE: $13.02
#     - Test MAE: $9.37
#     - Test MAPE: 6.84%
#   Data:
#     - Observations: 341
#     - CV folds: 3
#     - Configs tried: 24
#   Feature breakdown:
#     - Competitor lag features: 20
#     - Market aggregate features: 0
#     - Temporal features: 10
#     - Using lags 1-5 only (simple)
#
# Hotel_13: 55 total features
#   Configuration:
#     - Detrending window: 7 days
#     - Feature set: simple
#     - Min training: 200 days
#     - Competitors: 9
#   Performance:
#     - Test R²: 0.7098
#     - Train R²: 0.9366
#     - Overfitting gap: 0.2268
#     - Test RMSE: $10.27
#     - Test MAE: $7.37
#     - Test MAPE: 5.49%
#   Data:
#     - Observations: 336
#     - CV folds: 4
#     - Configs tried: 16
#   Feature breakdown:
#     - Competitor lag features: 45
#     - Market aggregate features: 0
#     - Temporal features: 10
#     - Using lags 1-5 only (simple)
#
# ================================================================================
# 6. PERFORMANCE DISTRIBUTION
# ================================================================================
#
# Tier                      Count    Percentage   Hotels
# --------------------------------------------------------------------------------
# ❌ Negative               1          4.5%        Hotel_24
# ✓ Low (0-0.2)            1          4.5%        Hotel_01
# ⭐ Medium (0.2-0.4)       6         27.3%        Hotel_07, Hotel_28, Hotel_21, Hotel_30, Hotel_10, ... (1 more)
# 🌟 High (0.4-0.6)         5         22.7%        Hotel_05, Hotel_23, Hotel_03, Hotel_14, Hotel_26
# 🏆 Very High (>0.6)       9         40.9%        Hotel_22, Hotel_17, Hotel_33, Hotel_04, Hotel_13, ... (4 more)
#
# ================================================================================
# 7. KEY INSIGHTS
# ================================================================================
#
# ✅ SUCCESS FACTORS:
#   1. 7-day detrending window works best for ALL hotels
#      - Short window = better captures recent price changes
#      - More responsive to market dynamics
#
#   2. Simple features (lags 1-5) generally outperform extended
#      - Simple mean R²: 0.5104
#      - Extended mean R²: 0.3471
#      - 16/22 hotels (72.7%) chose simple features
#
#   3. Adaptive approach achieved excellent results:
#      - +303% mean improvement vs baseline
#      - +98% median improvement vs baseline
#      - 21/22 hotels with R² > 0 (95.5% success rate)
#      - Mean Test MAPE: 6.43%
#      - Mean Test RMSE: $25.65
#
#   4. Coverage matches baseline:
#      - Both methods: 22 hotels
#      - But adaptive has MUCH better performance
#
# ⚠️  AREAS FOR IMPROVEMENT:
#   1. One hotel (Hotel_24) still has negative R²
#      - May need special handling or fallback
#
#   2. 3 hotels have overfitting gap > 0.5
#      - Mean gap: 0.3288
#      - May benefit from stronger regularization
#
# ================================================================================
# 8. SAVING COMPREHENSIVE REPORT
# ================================================================================
#
# ✅ Saved: comprehensive_report.csv
# ✅ Saved: summary_statistics.json
# ✅ Saved: deployment_guide.csv
#
# ================================================================================
# 🎉 COMPREHENSIVE REPORT COMPLETE!
# ================================================================================
#
# Generated files:
#   📊 comprehensive_report.csv - Full details for all hotels (WITH RMSE, MAE, MAPE)
#   📈 summary_statistics.json - Aggregate statistics (WITH ERROR METRICS)
#   🚀 deployment_guide.csv - Deployment recommendations (WITH ERROR METRICS)
#
# Location: ..\models\adaptive_log_method/
#
# ================================================================================

# %% [markdown]
# ## Detailed Feature analysis

# %%
import pandas as pd
import numpy as np
import json
from pathlib import Path
import pickle
import shap
from xgboost import XGBRegressor
import warnings
warnings.filterwarnings('ignore')

# ============================================================================
# SETUP
# ============================================================================

output_path = Path('../models/adaptive_log_method')
processed_data_path = Path('../data/full-data/processed')

with open(output_path / 'adaptive_summary.json', 'r') as f:
    results = json.load(f)

successful = {h: r for h, r in results.items() if r.get('status') == 'success'}

print("="*80)
print("DETAILED FEATURE ANALYSIS WITH SHAP")
print("="*80)
print(f"Analyzing {len(successful)} hotels")
print("="*80)

# ============================================================================
# HELPER FUNCTIONS
# ============================================================================

def detrend_log_series(series, window):
    """Detrend with flexible window"""
    trend = series.rolling(window=window, min_periods=1, center=False).mean()
    detrended = series - trend
    return detrended, trend

def prepare_features_for_shap(df, config):
    """Prepare features exactly as in training"""
    df_processed = df.copy()
    feature_cols = []
    
    trend_window = config['trend_window']
    feature_set = config['feature_set']
    
    # Competitor features
    all_comp_lag_cols = [col for col in df.columns 
                         if '_lag_' in col 
                         and 'base_rate' not in col.lower()
                         and any(currency in col for currency in ['-USD', '-EUR', '-HKD', '-CNY'])]
    
    if feature_set == 'simple':
        comp_lag_cols = [col for col in all_comp_lag_cols 
                        if any(f'_lag_{i}' in col for i in [1, 2, 3, 4, 5])]
    else:
        comp_lag_cols = all_comp_lag_cols
    
    # Log + detrend
    for col in comp_lag_cols:
        log_prices = np.log(df_processed[col].replace(0, np.nan))
        detrended, _ = detrend_log_series(log_prices, window=trend_window)
        df_processed[f'{col}_log_detrended'] = detrended
        feature_cols.append(f'{col}_log_detrended')
    
    # Market aggregates (extended only)
    if feature_set == 'extended':
        lag1_cols = [col for col in comp_lag_cols if '_lag_1' in col]
        
        if len(lag1_cols) > 1:
            for col in lag1_cols:
                df_processed[f'{col}_log'] = np.log(df_processed[col].replace(0, np.nan))
            
            lag1_log_cols = [f'{col}_log' for col in lag1_cols]
            
            df_processed['comp_mean_log'] = df_processed[lag1_log_cols].mean(axis=1)
            df_processed['comp_min_log'] = df_processed[lag1_log_cols].min(axis=1)
            df_processed['comp_max_log'] = df_processed[lag1_log_cols].max(axis=1)
            df_processed['comp_std_log'] = df_processed[lag1_log_cols].std(axis=1)
            
            feature_cols.extend(['comp_mean_log', 'comp_min_log', 'comp_max_log', 'comp_std_log'])
    
    # Temporal features
    temporal_cols = ['day_of_week', 'month', 'is_weekend', 'day_of_year']
    temporal_cols = [col for col in temporal_cols if col in df_processed.columns]
    feature_cols.extend(temporal_cols)
    
    if 'day_of_week' in df_processed.columns:
        df_processed['sin_day_of_week'] = np.sin(2 * np.pi * df_processed['day_of_week'] / 7)
        df_processed['cos_day_of_week'] = np.cos(2 * np.pi * df_processed['day_of_week'] / 7)
        feature_cols.extend(['sin_day_of_week', 'cos_day_of_week'])
    
    if 'month' in df_processed.columns:
        df_processed['sin_month'] = np.sin(2 * np.pi * df_processed['month'] / 12)
        df_processed['cos_month'] = np.cos(2 * np.pi * df_processed['month'] / 12)
        feature_cols.extend(['sin_month', 'cos_month'])
    
    if 'day_of_year' in df_processed.columns:
        df_processed['sin_day_of_year'] = np.sin(2 * np.pi * df_processed['day_of_year'] / 365)
        df_processed['cos_day_of_year'] = np.cos(2 * np.pi * df_processed['day_of_year'] / 365)
        feature_cols.extend(['sin_day_of_year', 'cos_day_of_year'])
    
    X = df_processed[feature_cols].copy()
    
    # Target
    y_original = df_processed['base_rate']
    y_log = np.log(y_original.replace(0, np.nan))
    y_detrended, y_trend = detrend_log_series(y_log, window=trend_window)
    
    # Drop NaN
    valid_idx = ~(X.isnull().any(axis=1) | y_detrended.isnull() | y_log.isnull())
    X = X[valid_idx].reset_index(drop=True)
    
    return X, feature_cols

def categorize_features(feature_cols):
    """Categorize features into groups"""
    categories = {
        'competitor_lags': [],
        'market_aggregates': [],
        'temporal_basic': [],
        'temporal_cyclical': []
    }
    
    for feat in feature_cols:
        if 'lag' in feat.lower() and 'detrended' in feat:
            categories['competitor_lags'].append(feat)
        elif 'comp_' in feat and 'detrended' not in feat:
            categories['market_aggregates'].append(feat)
        elif 'sin_' in feat or 'cos_' in feat:
            categories['temporal_cyclical'].append(feat)
        else:
            categories['temporal_basic'].append(feat)
    
    return categories

# ============================================================================
# ANALYZE EACH HOTEL
# ============================================================================

all_hotel_features = []

# Process top 10 hotels for detailed analysis
results_sorted = sorted(successful.items(), key=lambda x: x[1]['test_r2'], reverse=True)

for idx, (hotel_id, result) in enumerate(results_sorted, 1):
    print(f"\n{'='*80}")
    print(f"HOTEL {idx}/22: {hotel_id}")
    print(f"{'='*80}")
    
    try:
        # Load model
        model_file = output_path / f'{hotel_id}_model.pkl'
        with open(model_file, 'rb') as f:
            model_data = pickle.load(f)
        
        model = model_data['model']
        scaler = model_data['scaler']
        feature_cols = model_data['feature_cols']
        config = model_data['config']
        
        # Load data
        data_file = processed_data_path / f'{hotel_id}_lagged_dataset.csv'
        df = pd.read_csv(data_file)
        df['date'] = pd.to_datetime(df['date'])
        df = df[df['date'] <= DATA_END_DATE].copy()
        
        # Prepare features
        X, _ = prepare_features_for_shap(df, config)
        
        # Scale
        X_scaled = scaler.transform(X)
        
        # Calculate SHAP values
        print(f"\nCalculating SHAP values...")
        explainer = shap.TreeExplainer(model)
        shap_values = explainer.shap_values(X_scaled[:100])  # Use first 100 samples for speed
        
        # Get mean absolute SHAP values
        mean_abs_shap = np.abs(shap_values).mean(axis=0)
        
        # Create feature importance dataframe
        feature_importance = pd.DataFrame({
            'feature': feature_cols,
            'shap_importance': mean_abs_shap,
            'xgb_importance': model.feature_importances_
        })
        feature_importance = feature_importance.sort_values('shap_importance', ascending=False)
        
        # Categorize features
        categories = categorize_features(feature_cols)
        
        # Print summary
        print(f"\nConfiguration:")
        print(f"  Detrending window: {config['trend_window']} days")
        print(f"  Feature set: {config['feature_set']}")
        print(f"  Min training: {config['min_train_days']} days")
        
        print(f"\nPerformance:")
        print(f"  Test R2: {result['test_r2']:.4f}")
        print(f"  Train R2: {result['train_r2']:.4f}")
        print(f"  Overfitting gap: {result['train_r2'] - result['test_r2']:.4f}")
        
        print(f"\nFeature Categories:")
        print(f"  Competitor lags: {len(categories['competitor_lags'])}")
        print(f"  Market aggregates: {len(categories['market_aggregates'])}")
        print(f"  Temporal basic: {len(categories['temporal_basic'])}")
        print(f"  Temporal cyclical: {len(categories['temporal_cyclical'])}")
        print(f"  Total features: {len(feature_cols)}")
        
        print(f"\nTop 10 Features by SHAP Importance:")
        print(f"  Rank  Feature                                            SHAP          XGB")
        print(f"  --------------------------------------------------------------------------------")
        for i, row in feature_importance.head(10).iterrows():
            print(f"  {feature_importance.index.get_loc(i)+1:<5} {row['feature']:<50} "
                  f"{row['shap_importance']:<12.6f} {row['xgb_importance']:<12.6f}")
        
        # Store for summary
        all_hotel_features.append({
            'hotel_id': hotel_id,
            'test_r2': result['test_r2'],
            'n_features': len(feature_cols),
            'n_competitor_lags': len(categories['competitor_lags']),
            'n_market_agg': len(categories['market_aggregates']),
            'n_temporal': len(categories['temporal_basic']) + len(categories['temporal_cyclical']),
            'trend_window': config['trend_window'],
            'feature_set': config['feature_set'],
            'top_feature': feature_importance.iloc[0]['feature'],
            'top_feature_shap': feature_importance.iloc[0]['shap_importance'],
            'all_features': feature_cols,
            'feature_importance': feature_importance.to_dict('records')
        })
        
        # Save detailed feature list for this hotel
        feature_importance.to_csv(
            output_path / f'{hotel_id}_feature_importance.csv', 
            index=False
        )
        print(f"\nSaved: {hotel_id}_feature_importance.csv")
        
        # Print exact feature list (for top 5 hotels only)
        if idx <= 5:
            print(f"\nEXACT FEATURE LIST (All {len(feature_cols)} features):")
            print(f"\nCompetitor Lag Features ({len(categories['competitor_lags'])}):")
            for feat in categories['competitor_lags']:
                print(f"  - {feat}")
            
            if len(categories['market_aggregates']) > 0:
                print(f"\nMarket Aggregate Features ({len(categories['market_aggregates'])}):")
                for feat in categories['market_aggregates']:
                    print(f"  - {feat}")
            
            print(f"\nTemporal Basic Features ({len(categories['temporal_basic'])}):")
            for feat in categories['temporal_basic']:
                print(f"  - {feat}")
            
            print(f"\nTemporal Cyclical Features ({len(categories['temporal_cyclical'])}):")
            for feat in categories['temporal_cyclical']:
                print(f"  - {feat}")
        
    except Exception as e:
        print(f"Error analyzing {hotel_id}: {e}")
        import traceback
        traceback.print_exc()

# ============================================================================
# SUMMARY ANALYSIS
# ============================================================================

print(f"\n{'='*80}")
print("SUMMARY: FEATURE IMPORTANCE PATTERNS")
print(f"{'='*80}")

df_features = pd.DataFrame(all_hotel_features)

print(f"\nAverage Feature Counts:")
print(f"  Total features: {df_features['n_features'].mean():.1f} (std {df_features['n_features'].std():.1f})")
print(f"  Competitor lags: {df_features['n_competitor_lags'].mean():.1f} (std {df_features['n_competitor_lags'].std():.1f})")
print(f"  Market aggregates: {df_features['n_market_agg'].mean():.1f} (std {df_features['n_market_agg'].std():.1f})")
print(f"  Temporal: {df_features['n_temporal'].mean():.1f} (std {df_features['n_temporal'].std():.1f})")

print(f"\nMost Important Features (Top feature per hotel):")
top_features = df_features['top_feature'].value_counts().head(10)
for feat, count in top_features.items():
    print(f"  {feat}: {count} hotels")

print(f"\nCorrelation: Feature Count vs Performance")
corr = df_features[['n_features', 'test_r2']].corr().iloc[0, 1]
print(f"  Correlation(n_features, test_r2): {corr:.3f}")

# Save complete feature analysis
df_features_export = df_features.drop(['all_features', 'feature_importance'], axis=1)
df_features_export.to_csv(output_path / 'feature_analysis_summary.csv', index=False)

# Save complete feature lists
with open(output_path / 'complete_feature_lists.json', 'w') as f:
    feature_lists = {
        hotel['hotel_id']: {
            'features': hotel['all_features'],
            'n_features': hotel['n_features'],
            'test_r2': hotel['test_r2'],
            'config': {
                'trend_window': hotel['trend_window'],
                'feature_set': hotel['feature_set']
            }
        }
        for hotel in all_hotel_features
    }
    json.dump(feature_lists, f, indent=2)

print(f"\n{'='*80}")
print("FEATURE ANALYSIS COMPLETE!")
print(f"{'='*80}")
print(f"\nGenerated files:")
print(f"  feature_analysis_summary.csv - Summary for all hotels")
print(f"  complete_feature_lists.json - Exact features per hotel")
print(f"  [hotel_id]_feature_importance.csv - SHAP values per hotel")
print(f"\nLocation: {output_path}/")
print(f"{'='*80}")
# Out:
# ================================================================================
# DETAILED FEATURE ANALYSIS WITH SHAP
# ================================================================================
# Analyzing 22 hotels
# ================================================================================
#
# ================================================================================
# HOTEL 1/22: Hotel_22
# ================================================================================
#
# Calculating SHAP values...
#
# Configuration:
#   Detrending window: 7 days
#   Feature set: simple
#   Min training: 250 days
#
# Performance:
#   Test R2: 0.7890
#   Train R2: 0.7767
#   Overfitting gap: -0.0123
#
# Feature Categories:
#   Competitor lags: 45
#   Market aggregates: 0
#   Temporal basic: 4
#   Temporal cyclical: 6
#   Total features: 55
#
# Top 10 Features by SHAP Importance:
#   Rank  Feature                                            SHAP          XGB
#   --------------------------------------------------------------------------------
#   1     day_of_week                                        0.047595     0.572065
#   2     sin_day_of_week                                    0.000699     0.186473
#   3     cos_day_of_year                                    0.000453     0.120606
#   4     cos_month                                          0.000408     0.120856
#   5     booking-us-ac-by-marriott-san-rafael-USD_lag_1_log_detrended 0.000000     0.000000
#   6     booking-us-ac-by-marriott-san-rafael-USD_lag_2_log_detrended 0.000000     0.000000
#   7     booking-us-ac-by-marriott-san-rafael-USD_lag_3_log_detrended 0.000000     0.000000
#   8     booking-us-acquahotel-USD_lag_3_log_detrended      0.000000     0.000000
#   9     booking-us-acquahotel-USD_lag_4_log_detrended      0.000000     0.000000
#   10    booking-us-acquahotel-USD_lag_5_log_detrended      0.000000     0.000000
#
# Saved: Hotel_22_feature_importance.csv
#
# EXACT FEATURE LIST (All 55 features):
#
# Competitor Lag Features (45):
#   - booking-us-ac-by-marriott-san-rafael-USD_lag_1_log_detrended
#   - booking-us-ac-by-marriott-san-rafael-USD_lag_2_log_detrended
#   - booking-us-ac-by-marriott-san-rafael-USD_lag_3_log_detrended
#   - booking-us-ac-by-marriott-san-rafael-USD_lag_4_log_detrended
#   - booking-us-ac-by-marriott-san-rafael-USD_lag_5_log_detrended
#   - booking-us-acquahotel-USD_lag_1_log_detrended
#   - booking-us-acquahotel-USD_lag_2_log_detrended
#   - booking-us-acquahotel-USD_lag_3_log_detrended
#   - booking-us-acquahotel-USD_lag_4_log_detrended
#   - booking-us-acquahotel-USD_lag_5_log_detrended
#   - booking-us-best-western-plus-corte-madera-USD_lag_1_log_detrended
#   - booking-us-best-western-plus-corte-madera-USD_lag_2_log_detrended
#   - booking-us-best-western-plus-corte-madera-USD_lag_3_log_detrended
#   - booking-us-best-western-plus-corte-madera-USD_lag_4_log_detrended
#   - booking-us-best-western-plus-corte-madera-USD_lag_5_log_detrended
#   - booking-us-best-western-plus-novato-oaks-inn-USD_lag_1_log_detrended
#   - booking-us-best-western-plus-novato-oaks-inn-USD_lag_2_log_detrended
#   - booking-us-best-western-plus-novato-oaks-inn-USD_lag_3_log_detrended
#   - booking-us-best-western-plus-novato-oaks-inn-USD_lag_4_log_detrended
#   - booking-us-best-western-plus-novato-oaks-inn-USD_lag_5_log_detrended
#   - booking-us-courtyard-novato-marin-sonoma-USD_lag_1_log_detrended
#   - booking-us-courtyard-novato-marin-sonoma-USD_lag_2_log_detrended
#   - booking-us-courtyard-novato-marin-sonoma-USD_lag_3_log_detrended
#   - booking-us-courtyard-novato-marin-sonoma-USD_lag_4_log_detrended
#   - booking-us-courtyard-novato-marin-sonoma-USD_lag_5_log_detrended
#   - booking-us-courtyard-san-francisco-larkspur-landing-marin-county-USD_lag_1_log_detrended
#   - booking-us-courtyard-san-francisco-larkspur-landing-marin-county-USD_lag_2_log_detrended
#   - booking-us-courtyard-san-francisco-larkspur-landing-marin-county-USD_lag_3_log_detrended
#   - booking-us-courtyard-san-francisco-larkspur-landing-marin-county-USD_lag_4_log_detrended
#   - booking-us-courtyard-san-francisco-larkspur-landing-marin-county-USD_lag_5_log_detrended
#   - booking-us-four-points-by-shertaon-san-rafael-USD_lag_1_log_detrended
#   - booking-us-four-points-by-shertaon-san-rafael-USD_lag_2_log_detrended
#   - booking-us-four-points-by-shertaon-san-rafael-USD_lag_3_log_detrended
#   - booking-us-four-points-by-shertaon-san-rafael-USD_lag_4_log_detrended
#   - booking-us-four-points-by-shertaon-san-rafael-USD_lag_5_log_detrended
#   - booking-us-hotel-francisco-blvd-east-san-rafael-USD_lag_1_log_detrended
#   - booking-us-hotel-francisco-blvd-east-san-rafael-USD_lag_2_log_detrended
#   - booking-us-hotel-francisco-blvd-east-san-rafael-USD_lag_3_log_detrended
#   - booking-us-hotel-francisco-blvd-east-san-rafael-USD_lag_4_log_detrended
#   - booking-us-hotel-francisco-blvd-east-san-rafael-USD_lag_5_log_detrended
#   - booking-us-mill-valley-sausalito-USD_lag_1_log_detrended
#   - booking-us-mill-valley-sausalito-USD_lag_2_log_detrended
#   - booking-us-mill-valley-sausalito-USD_lag_3_log_detrended
#   - booking-us-mill-valley-sausalito-USD_lag_4_log_detrended
#   - booking-us-mill-valley-sausalito-USD_lag_5_log_detrended
#
# Temporal Basic Features (4):
#   - day_of_week
#   - month
#   - is_weekend
#   - day_of_year
#
# Temporal Cyclical Features (6):
#   - sin_day_of_week
#   - cos_day_of_week
#   - sin_month
#   - cos_month
#   - sin_day_of_year
#   - cos_day_of_year
#
# ================================================================================
# HOTEL 2/22: Hotel_17
# ================================================================================
#
# Calculating SHAP values...
#
# Configuration:
#   Detrending window: 7 days
#   Feature set: simple
#   Min training: 250 days
#
# Performance:
#   Test R2: 0.7399
#   Train R2: 0.8291
#   Overfitting gap: 0.0892
#
# Feature Categories:
#   Competitor lags: 40
#   Market aggregates: 0
#   Temporal basic: 4
#   Temporal cyclical: 6
#   Total features: 50
#
# Top 10 Features by SHAP Importance:
#   Rank  Feature                                            SHAP          XGB
#   --------------------------------------------------------------------------------
#   1     day_of_week                                        0.096023     0.352438
#   2     day_of_year                                        0.018853     0.040772
#   3     booking-us-trio-healdsburg-USD_lag_2_log_detrended 0.011189     0.061062
#   4     booking-us-trio-healdsburg-USD_lag_3_log_detrended 0.007648     0.035541
#   5     booking-us-inn-at-sonoma-USD_lag_5_log_detrended   0.007303     0.063065
#   6     cos_day_of_week                                    0.005920     0.058417
#   7     cos_day_of_year                                    0.004972     0.026666
#   8     sin_day_of_week                                    0.003090     0.033628
#   9     booking-us-trio-healdsburg-USD_lag_4_log_detrended 0.002122     0.027253
#   10    booking-us-the-lodge-at-healdsburg-tapestry-collection-by-hilton-USD_lag_1_log_detrended 0.001839     0.023189
#
# Saved: Hotel_17_feature_importance.csv
#
# EXACT FEATURE LIST (All 50 features):
#
# Competitor Lag Features (40):
#   - booking-us-bodega-bay-lodge-USD_lag_1_log_detrended
#   - booking-us-bodega-bay-lodge-USD_lag_2_log_detrended
#   - booking-us-bodega-bay-lodge-USD_lag_3_log_detrended
#   - booking-us-bodega-bay-lodge-USD_lag_4_log_detrended
#   - booking-us-bodega-bay-lodge-USD_lag_5_log_detrended
#   - booking-us-dr-wilkinson-39-s-hot-srpings-resort-USD_lag_1_log_detrended
#   - booking-us-dr-wilkinson-39-s-hot-srpings-resort-USD_lag_2_log_detrended
#   - booking-us-dr-wilkinson-39-s-hot-srpings-resort-USD_lag_3_log_detrended
#   - booking-us-dr-wilkinson-39-s-hot-srpings-resort-USD_lag_4_log_detrended
#   - booking-us-dr-wilkinson-39-s-hot-srpings-resort-USD_lag_5_log_detrended
#   - booking-us-el-dorado-sonoma1-USD_lag_1_log_detrended
#   - booking-us-el-dorado-sonoma1-USD_lag_2_log_detrended
#   - booking-us-el-dorado-sonoma1-USD_lag_3_log_detrended
#   - booking-us-el-dorado-sonoma1-USD_lag_4_log_detrended
#   - booking-us-el-dorado-sonoma1-USD_lag_5_log_detrended
#   - booking-us-gaige-house-USD_lag_1_log_detrended
#   - booking-us-gaige-house-USD_lag_2_log_detrended
#   - booking-us-gaige-house-USD_lag_3_log_detrended
#   - booking-us-gaige-house-USD_lag_4_log_detrended
#   - booking-us-gaige-house-USD_lag_5_log_detrended
#   - booking-us-inn-at-sonoma-USD_lag_1_log_detrended
#   - booking-us-inn-at-sonoma-USD_lag_2_log_detrended
#   - booking-us-inn-at-sonoma-USD_lag_3_log_detrended
#   - booking-us-inn-at-sonoma-USD_lag_4_log_detrended
#   - booking-us-inn-at-sonoma-USD_lag_5_log_detrended
#   - booking-us-the-lodge-at-healdsburg-tapestry-collection-by-hilton-USD_lag_1_log_detrended
#   - booking-us-the-lodge-at-healdsburg-tapestry-collection-by-hilton-USD_lag_2_log_detrended
#   - booking-us-the-lodge-at-healdsburg-tapestry-collection-by-hilton-USD_lag_3_log_detrended
#   - booking-us-the-lodge-at-healdsburg-tapestry-collection-by-hilton-USD_lag_4_log_detrended
#   - booking-us-the-lodge-at-healdsburg-tapestry-collection-by-hilton-USD_lag_5_log_detrended
#   - booking-us-trio-healdsburg-USD_lag_1_log_detrended
#   - booking-us-trio-healdsburg-USD_lag_2_log_detrended
#   - booking-us-trio-healdsburg-USD_lag_3_log_detrended
#   - booking-us-trio-healdsburg-USD_lag_4_log_detrended
#   - booking-us-trio-healdsburg-USD_lag_5_log_detrended
#   - booking-us-vintners-inn-USD_lag_1_log_detrended
#   - booking-us-vintners-inn-USD_lag_2_log_detrended
#   - booking-us-vintners-inn-USD_lag_3_log_detrended
#   - booking-us-vintners-inn-USD_lag_4_log_detrended
#   - booking-us-vintners-inn-USD_lag_5_log_detrended
#
# Temporal Basic Features (4):
#   - day_of_week
#   - month
#   - is_weekend
#   - day_of_year
#
# Temporal Cyclical Features (6):
#   - sin_day_of_week
#   - cos_day_of_week
#   - sin_month
#   - cos_month
#   - sin_day_of_year
#   - cos_day_of_year
#
# ================================================================================
# HOTEL 3/22: Hotel_33
# ================================================================================
# Calculating SHAP values...
#
# Configuration:
#   Detrending window: 7 days
#   Feature set: extended
#   Min training: 250 days
#
# Performance:
#   Test R2: 0.7105
#   Train R2: 0.5893
#   Overfitting gap: -0.1212
#
# Feature Categories:
#   Competitor lags: 30
#   Market aggregates: 4
#   Temporal basic: 4
#   Temporal cyclical: 6
#   Total features: 44
#
# Top 10 Features by SHAP Importance:
#   Rank  Feature                                            SHAP          XGB
#   --------------------------------------------------------------------------------
#   1     sin_day_of_week                                    0.040420     0.239863
#   2     cos_day_of_week                                    0.018818     0.080246
#   3     day_of_week                                        0.015450     0.083131
#   4     cos_day_of_year                                    0.005636     0.031263
#   5     booking-us-hyatt-place-fredericksburg-at-mary-washington-USD_lag_5_log_detrended 0.005039     0.064535
#   6     comp_min_log                                       0.004799     0.029345
#   7     day_of_year                                        0.004081     0.044028
#   8     cos_month                                          0.002577     0.035129
#   9     booking-us-courtyard-fredericksburg-historic-district-USD_lag_5_log_detrended 0.002414     0.046489
#   10    booking-us-hilton-garden-inn-fredericksburg-USD_lag_1_log_detrended 0.001454     0.031254
#
# Saved: Hotel_33_feature_importance.csv
#
# EXACT FEATURE LIST (All 44 features):
#
# Competitor Lag Features (30):
#   - booking-us-courtyard-fredericksburg-historic-district-USD_lag_1_log_detrended
#   - booking-us-courtyard-fredericksburg-historic-district-USD_lag_2_log_detrended
#   - booking-us-courtyard-fredericksburg-historic-district-USD_lag_3_log_detrended
#   - booking-us-courtyard-fredericksburg-historic-district-USD_lag_4_log_detrended
#   - booking-us-courtyard-fredericksburg-historic-district-USD_lag_5_log_detrended
#   - booking-us-fredericksburg-1080-hospitality-USD_lag_1_log_detrended
#   - booking-us-fredericksburg-1080-hospitality-USD_lag_2_log_detrended
#   - booking-us-fredericksburg-1080-hospitality-USD_lag_3_log_detrended
#   - booking-us-fredericksburg-1080-hospitality-USD_lag_4_log_detrended
#   - booking-us-fredericksburg-1080-hospitality-USD_lag_5_log_detrended
#   - booking-us-fredericksburg-hospitality-lane-USD_lag_1_log_detrended
#   - booking-us-fredericksburg-hospitality-lane-USD_lag_2_log_detrended
#   - booking-us-fredericksburg-hospitality-lane-USD_lag_3_log_detrended
#   - booking-us-fredericksburg-hospitality-lane-USD_lag_4_log_detrended
#   - booking-us-fredericksburg-hospitality-lane-USD_lag_5_log_detrended
#   - booking-us-hilton-garden-inn-fredericksburg-USD_lag_1_log_detrended
#   - booking-us-hilton-garden-inn-fredericksburg-USD_lag_2_log_detrended
#   - booking-us-hilton-garden-inn-fredericksburg-USD_lag_3_log_detrended
#   - booking-us-hilton-garden-inn-fredericksburg-USD_lag_4_log_detrended
#   - booking-us-hilton-garden-inn-fredericksburg-USD_lag_5_log_detrended
#   - booking-us-hyatt-place-fredericksburg-at-mary-washington-USD_lag_1_log_detrended
#   - booking-us-hyatt-place-fredericksburg-at-mary-washington-USD_lag_2_log_detrended
#   - booking-us-hyatt-place-fredericksburg-at-mary-washington-USD_lag_3_log_detrended
#   - booking-us-hyatt-place-fredericksburg-at-mary-washington-USD_lag_4_log_detrended
#   - booking-us-hyatt-place-fredericksburg-at-mary-washington-USD_lag_5_log_detrended
#   - booking-us-residence-inn-by-marriott-fredericksburg-USD_lag_1_log_detrended
#   - booking-us-residence-inn-by-marriott-fredericksburg-USD_lag_2_log_detrended
#   - booking-us-residence-inn-by-marriott-fredericksburg-USD_lag_3_log_detrended
#   - booking-us-residence-inn-by-marriott-fredericksburg-USD_lag_4_log_detrended
#   - booking-us-residence-inn-by-marriott-fredericksburg-USD_lag_5_log_detrended
#
# Market Aggregate Features (4):
#   - comp_mean_log
#   - comp_min_log
#   - comp_max_log
#   - comp_std_log
#
# Temporal Basic Features (4):
#   - day_of_week
#   - month
#   - is_weekend
#   - day_of_year
#
# Temporal Cyclical Features (6):
#   - sin_day_of_week
#   - cos_day_of_week
#   - sin_month
#   - cos_month
#   - sin_day_of_year
#   - cos_day_of_year
#
# ================================================================================
# HOTEL 4/22: Hotel_04
# ================================================================================
#
# Calculating SHAP values...
#
# Configuration:
#   Detrending window: 7 days
#   Feature set: simple
#   Min training: 250 days
#
# Performance:
#   Test R2: 0.7103
#   Train R2: 0.7915
#   Overfitting gap: 0.0812
#
# Feature Categories:
#   Competitor lags: 20
#   Market aggregates: 0
#   Temporal basic: 4
#   Temporal cyclical: 6
#   Total features: 30
#
# Top 10 Features by SHAP Importance:
#   Rank  Feature                                            SHAP          XGB
#   --------------------------------------------------------------------------------
#   1     day_of_week                                        0.105047     0.433170
#   2     booking-us-best-western-pony-soldier-USD_lag_1_log_detrended 0.009729     0.045652
#   3     sin_day_of_week                                    0.003937     0.101307
#   4     sin_day_of_year                                    0.003631     0.036465
#   5     booking-us-flagstaff-travelodge-USD_lag_1_log_detrended 0.003262     0.041382
#   6     booking-us-high-country-motor-lodge-USD_lag_1_log_detrended 0.002681     0.045459
#   7     booking-us-flagstaff-travelodge-USD_lag_2_log_detrended 0.002124     0.034333
#   8     booking-us-econo-lodge-flagstaff-USD_lag_2_log_detrended 0.001867     0.044193
#   9     day_of_year                                        0.001853     0.037677
#   10    cos_day_of_week                                    0.001309     0.044272
#
# Saved: Hotel_04_feature_importance.csv
#
# EXACT FEATURE LIST (All 30 features):
#
# Competitor Lag Features (20):
#   - booking-us-best-western-pony-soldier-USD_lag_1_log_detrended
#   - booking-us-best-western-pony-soldier-USD_lag_2_log_detrended
#   - booking-us-best-western-pony-soldier-USD_lag_3_log_detrended
#   - booking-us-best-western-pony-soldier-USD_lag_4_log_detrended
#   - booking-us-best-western-pony-soldier-USD_lag_5_log_detrended
#   - booking-us-econo-lodge-flagstaff-USD_lag_1_log_detrended
#   - booking-us-econo-lodge-flagstaff-USD_lag_2_log_detrended
#   - booking-us-econo-lodge-flagstaff-USD_lag_3_log_detrended
#   - booking-us-econo-lodge-flagstaff-USD_lag_4_log_detrended
#   - booking-us-econo-lodge-flagstaff-USD_lag_5_log_detrended
#   - booking-us-flagstaff-travelodge-USD_lag_1_log_detrended
#   - booking-us-flagstaff-travelodge-USD_lag_2_log_detrended
#   - booking-us-flagstaff-travelodge-USD_lag_3_log_detrended
#   - booking-us-flagstaff-travelodge-USD_lag_4_log_detrended
#   - booking-us-flagstaff-travelodge-USD_lag_5_log_detrended
#   - booking-us-high-country-motor-lodge-USD_lag_1_log_detrended
#   - booking-us-high-country-motor-lodge-USD_lag_2_log_detrended
#   - booking-us-high-country-motor-lodge-USD_lag_3_log_detrended
#   - booking-us-high-country-motor-lodge-USD_lag_4_log_detrended
#   - booking-us-high-country-motor-lodge-USD_lag_5_log_detrended
#
# Temporal Basic Features (4):
#   - day_of_week
#   - month
#   - is_weekend
#   - day_of_year
#
# Temporal Cyclical Features (6):
#   - sin_day_of_week
#   - cos_day_of_week
#   - sin_month
#   - cos_month
#   - sin_day_of_year
#   - cos_day_of_year
#
# ================================================================================
# HOTEL 5/22: Hotel_13
# ================================================================================
#
# Calculating SHAP values...
#
# Configuration:
#   Detrending window: 7 days
#   Feature set: simple
#   Min training: 200 days
#
# Performance:
#   Test R2: 0.7098
#   Train R2: 0.9366
#   Overfitting gap: 0.2268
#
# Feature Categories:
#   Competitor lags: 45
#   Market aggregates: 0
#   Temporal basic: 4
#   Temporal cyclical: 6
#   Total features: 55
#
# Top 10 Features by SHAP Importance:
#   Rank  Feature                                            SHAP          XGB
#   --------------------------------------------------------------------------------
#   1     day_of_week                                        0.068982     0.228328
#   2     cos_day_of_week                                    0.007227     0.053956
#   3     booking-us-blue-door-inn-estes-park-USD_lag_1_log_detrended 0.004565     0.034843
#   4     booking-us-murphy-s-resort-USD_lag_2_log_detrended 0.004318     0.035864
#   5     booking-us-twin-owls-motor-lodge-USD_lag_1_log_detrended 0.003937     0.043890
#   6     booking-us-twin-owls-motor-lodge-USD_lag_3_log_detrended 0.003214     0.050791
#   7     booking-us-econo-lodge-estes-park-USD_lag_4_log_detrended 0.002877     0.043696
#   8     day_of_year                                        0.002848     0.043879
#   9     sin_day_of_year                                    0.001883     0.031711
#   10    booking-us-twin-owls-motor-lodge-USD_lag_2_log_detrended 0.001882     0.034742
#
# Saved: Hotel_13_feature_importance.csv
#
# EXACT FEATURE LIST (All 55 features):
#
# Competitor Lag Features (45):
#   - booking-us-appenzell-inn-USD_lag_1_log_detrended
#   - booking-us-appenzell-inn-USD_lag_2_log_detrended
#   - booking-us-appenzell-inn-USD_lag_3_log_detrended
#   - booking-us-appenzell-inn-USD_lag_4_log_detrended
#   - booking-us-appenzell-inn-USD_lag_5_log_detrended
#   - booking-us-blue-door-inn-estes-park-USD_lag_1_log_detrended
#   - booking-us-blue-door-inn-estes-park-USD_lag_2_log_detrended
#   - booking-us-blue-door-inn-estes-park-USD_lag_3_log_detrended
#   - booking-us-blue-door-inn-estes-park-USD_lag_4_log_detrended
#   - booking-us-blue-door-inn-estes-park-USD_lag_5_log_detrended
#   - booking-us-budget-host-estes-park-USD_lag_1_log_detrended
#   - booking-us-budget-host-estes-park-USD_lag_2_log_detrended
#   - booking-us-budget-host-estes-park-USD_lag_3_log_detrended
#   - booking-us-budget-host-estes-park-USD_lag_4_log_detrended
#   - booking-us-budget-host-estes-park-USD_lag_5_log_detrended
#   - booking-us-comfort-inn-estes-park-USD_lag_1_log_detrended
#   - booking-us-comfort-inn-estes-park-USD_lag_2_log_detrended
#   - booking-us-comfort-inn-estes-park-USD_lag_3_log_detrended
#   - booking-us-comfort-inn-estes-park-USD_lag_4_log_detrended
#   - booking-us-comfort-inn-estes-park-USD_lag_5_log_detrended
#   - booking-us-discovery-lodge-USD_lag_1_log_detrended
#   - booking-us-discovery-lodge-USD_lag_2_log_detrended
#   - booking-us-discovery-lodge-USD_lag_3_log_detrended
#   - booking-us-discovery-lodge-USD_lag_4_log_detrended
#   - booking-us-discovery-lodge-USD_lag_5_log_detrended
#   - booking-us-econo-lodge-estes-park-USD_lag_1_log_detrended
#   - booking-us-econo-lodge-estes-park-USD_lag_2_log_detrended
#   - booking-us-econo-lodge-estes-park-USD_lag_3_log_detrended
#   - booking-us-econo-lodge-estes-park-USD_lag_4_log_detrended
#   - booking-us-econo-lodge-estes-park-USD_lag_5_log_detrended
#   - booking-us-estes-park-101-south-saint-vrain-avenue-USD_lag_1_log_detrended
#   - booking-us-estes-park-101-south-saint-vrain-avenue-USD_lag_2_log_detrended
#   - booking-us-estes-park-101-south-saint-vrain-avenue-USD_lag_3_log_detrended
#   - booking-us-estes-park-101-south-saint-vrain-avenue-USD_lag_4_log_detrended
#   - booking-us-estes-park-101-south-saint-vrain-avenue-USD_lag_5_log_detrended
#   - booking-us-murphy-s-resort-USD_lag_1_log_detrended
#   - booking-us-murphy-s-resort-USD_lag_2_log_detrended
#   - booking-us-murphy-s-resort-USD_lag_3_log_detrended
#   - booking-us-murphy-s-resort-USD_lag_4_log_detrended
#   - booking-us-murphy-s-resort-USD_lag_5_log_detrended
#   - booking-us-twin-owls-motor-lodge-USD_lag_1_log_detrended
#   - booking-us-twin-owls-motor-lodge-USD_lag_2_log_detrended
#   - booking-us-twin-owls-motor-lodge-USD_lag_3_log_detrended
#   - booking-us-twin-owls-motor-lodge-USD_lag_4_log_detrended
#   - booking-us-twin-owls-motor-lodge-USD_lag_5_log_detrended
#
# Temporal Basic Features (4):
#   - day_of_week
#   - month
#   - is_weekend
#   - day_of_year
#
# Temporal Cyclical Features (6):
#   - sin_day_of_week
#   - cos_day_of_week
#   - sin_month
#   - cos_month
#   - sin_day_of_year
#   - cos_day_of_year
#
# ================================================================================
# HOTEL 6/22: Hotel_31
# ================================================================================
#
# Calculating SHAP values...
# Configuration:
#   Detrending window: 7 days
#   Feature set: simple
#   Min training: 200 days
#
# Performance:
#   Test R2: 0.6609
#   Train R2: 0.8338
#   Overfitting gap: 0.1729
#
# Feature Categories:
#   Competitor lags: 30
#   Market aggregates: 0
#   Temporal basic: 4
#   Temporal cyclical: 6
#   Total features: 40
#
# Top 10 Features by SHAP Importance:
#   Rank  Feature                                            SHAP          XGB
#   --------------------------------------------------------------------------------
#   1     day_of_week                                        0.084363     0.184418
#   2     booking-us-triada-palm-springs-autograph-collection-USD_lag_1_log_detrended 0.021797     0.024832
#   3     booking-us-ace-and-swim-club-USD_lag_4_log_detrended 0.021539     0.076134
#   4     cos_day_of_week                                    0.020519     0.026876
#   5     booking-us-palm-desert-1620-south-indian-trail-USD_lag_1_log_detrended 0.020239     0.028190
#   6     booking-us-ace-and-swim-club-USD_lag_3_log_detrended 0.018738     0.067342
#   7     booking-us-ace-and-swim-club-USD_lag_1_log_detrended 0.017065     0.015721
#   8     booking-us-palm-desert-1620-south-indian-trail-USD_lag_4_log_detrended 0.011962     0.022136
#   9     booking-us-ace-and-swim-club-USD_lag_5_log_detrended 0.010363     0.042974
#   10    booking-us-best-western-las-brisas-palm-springs-USD_lag_2_log_detrended 0.010052     0.017298
#
# Saved: Hotel_31_feature_importance.csv
#
# ================================================================================
# HOTEL 7/22: Hotel_36
# ================================================================================
#
# Calculating SHAP values...
#
# Configuration:
#   Detrending window: 7 days
#   Feature set: simple
#   Min training: 250 days
#
# Performance:
#   Test R2: 0.6473
#   Train R2: 0.9400
#   Overfitting gap: 0.2927
#
# Feature Categories:
#   Competitor lags: 30
#   Market aggregates: 0
#   Temporal basic: 4
#   Temporal cyclical: 6
#   Total features: 40
#
# Top 10 Features by SHAP Importance:
#   Rank  Feature                                            SHAP          XGB
#   --------------------------------------------------------------------------------
#   1     day_of_week                                        0.045374     0.171909
#   2     day_of_year                                        0.009897     0.049799
#   3     booking-us-elk-refuge-inn-USD_lag_1_log_detrended  0.009077     0.060437
#   4     sin_day_of_week                                    0.006099     0.060328
#   5     booking-us-motel-6-jackson-USD_lag_1_log_detrended 0.005079     0.036831
#   6     cos_day_of_year                                    0.004429     0.051884
#   7     cos_day_of_week                                    0.003599     0.032658
#   8     sin_day_of_year                                    0.003593     0.051152
#   9     cos_month                                          0.003521     0.032109
#   10    booking-us-miller-park-lodge-USD_lag_3_log_detrended 0.003281     0.032725
#
# Saved: Hotel_36_feature_importance.csv
#
# ================================================================================
# HOTEL 8/22: Hotel_25
# ================================================================================
#
# Calculating SHAP values...
#
# Configuration:
#   Detrending window: 7 days
#   Feature set: simple
#   Min training: 200 days
#
# Performance:
#   Test R2: 0.6201
#   Train R2: 0.8640
#   Overfitting gap: 0.2439
#
# Feature Categories:
#   Competitor lags: 50
#   Market aggregates: 0
#   Temporal basic: 4
#   Temporal cyclical: 6
#   Total features: 60
#
# Top 10 Features by SHAP Importance:
#   Rank  Feature                                            SHAP          XGB
#   --------------------------------------------------------------------------------
#   1     day_of_week                                        0.061940     0.252513
#   2     booking-us-residence-inn-by-marriott-branson-USD_lag_1_log_detrended 0.020155     0.050617
#   3     cos_day_of_week                                    0.015423     0.040583
#   4     day_of_year                                        0.011949     0.032340
#   5     booking-us-grand-victorian-inn-USD_lag_1_log_detrended 0.009933     0.036322
#   6     booking-us-lodge-of-the-ozarks-USD_lag_1_log_detrended 0.004943     0.040305
#   7     booking-us-fairfield-inn-by-marriott-branson-USD_lag_1_log_detrended 0.004472     0.024047
#   8     booking-us-best-western-music-capital-inn-branson-USD_lag_2_log_detrended 0.003173     0.031134
#   9     booking-us-hampton-inn-branson-on-the-strip-USD_lag_5_log_detrended 0.003107     0.027387
#   10    booking-us-grand-victorian-inn-USD_lag_5_log_detrended 0.002163     0.032310
#
# Saved: Hotel_25_feature_importance.csv
#
# ================================================================================
# HOTEL 9/22: Hotel_32
# ================================================================================
#
# Calculating SHAP values...
#
# Configuration:
#   Detrending window: 7 days
#   Feature set: simple
#   Min training: 200 days
#
# Performance:
#   Test R2: 0.6131
#   Train R2: 0.7042
#   Overfitting gap: 0.0911
#
# Feature Categories:
#   Competitor lags: 25
#   Market aggregates: 0
#   Temporal basic: 4
#   Temporal cyclical: 6
#   Total features: 35
#
# Top 10 Features by SHAP Importance:
#   Rank  Feature                                            SHAP          XGB
#   --------------------------------------------------------------------------------
#   1     cos_day_of_week                                    0.058871     0.127165
#   2     sin_day_of_week                                    0.039697     0.201110
#   3     day_of_week                                        0.023763     0.132292
#   4     booking-us-healdsburg-25-matheson-street-USD_lag_5_log_detrended 0.015550     0.104667
#   5     booking-us-the-madrona-USD_lag_2_log_detrended     0.006175     0.019811
#   6     booking-us-the-madrona-USD_lag_4_log_detrended     0.005843     0.023758
#   7     booking-us-healdsburg-25-matheson-street-USD_lag_1_log_detrended 0.005176     0.018164
#   8     booking-us-the-stavrand-USD_lag_5_log_detrended    0.005124     0.017641
#   9     booking-us-the-madrona-USD_lag_5_log_detrended     0.002916     0.019459
#   10    booking-us-the-madrona-USD_lag_3_log_detrended     0.002737     0.017067
#
# Saved: Hotel_32_feature_importance.csv
#
# ================================================================================
# HOTEL 10/22: Hotel_05
# ================================================================================
#
# Calculating SHAP values...
#
# Configuration:
#   Detrending window: 7 days
#   Feature set: extended
#   Min training: 200 days
#
# Performance:
#   Test R2: 0.5496
#   Train R2: 0.9481
#   Overfitting gap: 0.3985
#
# Feature Categories:
#   Competitor lags: 50
#   Market aggregates: 4
#   Temporal basic: 4
#   Temporal cyclical: 6
#   Total features: 64
#
# Top 10 Features by SHAP Importance:
#   Rank  Feature                                            SHAP          XGB
#   --------------------------------------------------------------------------------
#   1     day_of_week                                        0.058876     0.109893
#   2     booking-us-the-lodge-at-jackson-hole-USD_lag_1_log_detrended 0.012488     0.043299
#   3     cos_day_of_week                                    0.011221     0.030579
#   4     booking-us-antler-inn-USD_lag_1_log_detrended      0.009506     0.070451
#   5     booking-us-snow-king-resort-USD_lag_1_log_detrended 0.007301     0.038403
#   6     booking-us-the-rockwell-inn-USD_lag_1_log_detrended 0.004829     0.029097
#   7     booking-us-painted-buffalo-inn-USD_lag_1_log_detrended 0.004804     0.032062
#   8     comp_min_log                                       0.004090     0.023994
#   9     sin_day_of_year                                    0.003429     0.026006
#   10    booking-us-the-rockwell-inn-USD_lag_5_log_detrended 0.003351     0.031519
#
# Saved: Hotel_05_feature_importance.csv
#
# ================================================================================
# HOTEL 11/22: Hotel_23
# ================================================================================
#
# Calculating SHAP values...
#
# Configuration:
#   Detrending window: 7 days
#   Feature set: simple
#   Min training: 200 days
#
# Performance:
#   Test R2: 0.4457
#   Train R2: 0.7089
#   Overfitting gap: 0.2632
#
# Feature Categories:
#   Competitor lags: 50
#   Market aggregates: 0
#   Temporal basic: 4
#   Temporal cyclical: 6
#   Total features: 60
#
# Top 10 Features by SHAP Importance:
#   Rank  Feature                                            SHAP          XGB
#   --------------------------------------------------------------------------------
#   1     booking-us-maui-coast-USD_lag_1_log_detrended      0.003596     0.236806
#   2     booking-us-kohea-kai-resort-maui-USD_lag_1_log_detrended 0.002819     0.205977
#   3     cos_day_of_week                                    0.001658     0.193914
#   4     booking-us-maui-beach-USD_lag_1_log_detrended      0.001164     0.177446
#   5     booking-us-castle-kamaole-sands-USD_lag_1_log_detrended 0.000567     0.185857
#   6     booking-us-aston-at-the-maui-banyan-USD_lag_4_log_detrended 0.000000     0.000000
#   7     booking-us-aston-kaanapali-shores-USD_lag_2_log_detrended 0.000000     0.000000
#   8     booking-us-aston-kaanapali-shores-USD_lag_1_log_detrended 0.000000     0.000000
#   9     booking-us-aston-kaanapali-shores-USD_lag_3_log_detrended 0.000000     0.000000
#   10    booking-us-aston-at-the-maui-banyan-USD_lag_5_log_detrended 0.000000     0.000000
#
# Saved: Hotel_23_feature_importance.csv
#
# ================================================================================
# HOTEL 12/22: Hotel_03
# ================================================================================
# Calculating SHAP values...
#
# Configuration:
#   Detrending window: 7 days
#   Feature set: simple
#   Min training: 250 days
#
# Performance:
#   Test R2: 0.4395
#   Train R2: 0.9309
#   Overfitting gap: 0.4914
#
# Feature Categories:
#   Competitor lags: 45
#   Market aggregates: 0
#   Temporal basic: 4
#   Temporal cyclical: 6
#   Total features: 55
#
# Top 10 Features by SHAP Importance:
#   Rank  Feature                                            SHAP          XGB
#   --------------------------------------------------------------------------------
#   1     booking-us-painted-buffalo-inn-USD_lag_1_log_detrended 0.027018     0.070381
#   2     day_of_week                                        0.026215     0.126600
#   3     cos_day_of_week                                    0.024434     0.058442
#   4     day_of_year                                        0.012168     0.059504
#   5     booking-us-virginian-lodge-USD_lag_1_log_detrended 0.006219     0.045557
#   6     sin_day_of_year                                    0.004364     0.037317
#   7     booking-us-the-lodge-at-jackson-hole-USD_lag_1_log_detrended 0.002840     0.046418
#   8     booking-us-snow-king-resort-USD_lag_4_log_detrended 0.002188     0.026190
#   9     booking-us-anvil-motel-USD_lag_1_log_detrended     0.002182     0.028887
#   10    booking-us-springhill-suites-by-marriott-jackson-hole-USD_lag_3_log_detrended 0.001779     0.028842
#
# Saved: Hotel_03_feature_importance.csv
#
# ================================================================================
# HOTEL 13/22: Hotel_14
# ================================================================================
#
# Calculating SHAP values...
#
# Configuration:
#   Detrending window: 7 days
#   Feature set: simple
#   Min training: 180 days
#
# Performance:
#   Test R2: 0.4358
#   Train R2: 0.7075
#   Overfitting gap: 0.2717
#
# Feature Categories:
#   Competitor lags: 25
#   Market aggregates: 0
#   Temporal basic: 4
#   Temporal cyclical: 6
#   Total features: 35
#
# Top 10 Features by SHAP Importance:
#   Rank  Feature                                            SHAP          XGB
#   --------------------------------------------------------------------------------
#   1     booking-us-kohea-kai-resort-maui-USD_lag_1_log_detrended 0.004662     0.291582
#   2     booking-us-castle-kamaole-sands-USD_lag_1_log_detrended 0.004011     0.267165
#   3     day_of_year                                        0.002873     0.223088
#   4     cos_day_of_week                                    0.002084     0.218164
#   5     booking-us-aqua-pacific-monarch-USD_lag_3_log_detrended 0.000000     0.000000
#   6     booking-us-aqua-pacific-monarch-USD_lag_1_log_detrended 0.000000     0.000000
#   7     booking-us-aqua-pacific-monarch-USD_lag_2_log_detrended 0.000000     0.000000
#   8     booking-us-castle-kamaole-sands-USD_lag_3_log_detrended 0.000000     0.000000
#   9     booking-us-castle-kamaole-sands-USD_lag_4_log_detrended 0.000000     0.000000
#   10    booking-us-aqua-pacific-monarch-USD_lag_5_log_detrended 0.000000     0.000000
#
# Saved: Hotel_14_feature_importance.csv
#
# ================================================================================
# HOTEL 14/22: Hotel_26
# ================================================================================
#
# Calculating SHAP values...
#
# Configuration:
#   Detrending window: 7 days
#   Feature set: extended
#   Min training: 250 days
#
# Performance:
#   Test R2: 0.4150
#   Train R2: 0.7398
#   Overfitting gap: 0.3248
#
# Feature Categories:
#   Competitor lags: 50
#   Market aggregates: 4
#   Temporal basic: 4
#   Temporal cyclical: 6
#   Total features: 64
#
# Top 10 Features by SHAP Importance:
#   Rank  Feature                                            SHAP          XGB
#   --------------------------------------------------------------------------------
#   1     booking-us-kona-coast-resort-USD_lag_1_log_detrended 0.029481     0.131080
#   2     cos_day_of_week                                    0.028310     0.053853
#   3     booking-us-royal-kona-resort-USD_lag_1_log_detrended 0.022194     0.065052
#   4     booking-us-outrigger-royal-sea-cliff-resort-USD_lag_1_log_detrended 0.008199     0.053714
#   5     comp_mean_log                                      0.006630     0.036975
#   6     booking-us-outrigger-kona-resort-and-spa-USD_lag_1_log_detrended 0.005034     0.036599
#   7     booking-us-holiday-inn-express-suites-kailua-kona-USD_lag_1_log_detrended 0.004104     0.033948
#   8     booking-us-outrigger-kona-resort-and-spa-USD_lag_2_log_detrended 0.003280     0.042249
#   9     comp_min_log                                       0.002488     0.024272
#   10    booking-us-kona-coast-resort-at-keauhou-gardens-8204-USD_lag_3_log_detrended 0.002379     0.021229
#
# Saved: Hotel_26_feature_importance.csv
#
# ================================================================================
# HOTEL 15/22: Hotel_07
# ================================================================================
#
# Calculating SHAP values...
#
# Configuration:
#   Detrending window: 7 days
#   Feature set: simple
#   Min training: 180 days
#
# Performance:
#   Test R2: 0.3865
#   Train R2: 0.8685
#   Overfitting gap: 0.4820
#
# Feature Categories:
#   Competitor lags: 40
#   Market aggregates: 0
#   Temporal basic: 4
#   Temporal cyclical: 6
#   Total features: 50
#
# Top 10 Features by SHAP Importance:
#   Rank  Feature                                            SHAP          XGB
#   --------------------------------------------------------------------------------
#   1     cos_day_of_year                                    0.012619     0.082396
#   2     day_of_week                                        0.011451     0.104864
#   3     cos_day_of_week                                    0.008668     0.189055
#   4     booking-us-laquinta-by-wyndham-parker-USD_lag_1_log_detrended 0.005090     0.069789
#   5     booking-us-springhill-suites-denver-parker-USD_lag_1_log_detrended 0.002759     0.073401
#   6     booking-us-springhill-suites-denver-parker-USD_lag_4_log_detrended 0.001809     0.047183
#   7     booking-us-towneplace-suites-by-marriott-denver-south-lone-tree-USD_lag_1_log_detrended 0.001575     0.043320
#   8     booking-us-hilton-garden-inn-denver-south-meridian-USD_lag_3_log_detrended 0.001320     0.047245
#   9     booking-us-hampton-inn-suites-parker-USD_lag_5_log_detrended 0.001189     0.045782
#   10    booking-us-best-western-inn-and-suites-of-castle-rock-USD_lag_5_log_detrended 0.001151     0.046621
#
# Saved: Hotel_07_feature_importance.csv
#
# ================================================================================
# HOTEL 16/22: Hotel_28
# ================================================================================
#
# Calculating SHAP values...
#
# Configuration:
#   Detrending window: 7 days
#   Feature set: extended
#   Min training: 180 days
#
# Performance:
#   Test R2: 0.3664
#   Train R2: 0.7446
#   Overfitting gap: 0.3782
#
# Feature Categories:
#   Competitor lags: 30
#   Market aggregates: 4
#   Temporal basic: 4
#   Temporal cyclical: 6
#   Total features: 44
#
# Top 10 Features by SHAP Importance:
#   Rank  Feature                                            SHAP          XGB
#   --------------------------------------------------------------------------------
#   1     booking-at-gamshof-EUR_lag_1_log_detrended         0.022533     0.124340
#   2     day_of_week                                        0.021181     0.045171
#   3     cos_day_of_week                                    0.013459     0.027224
#   4     day_of_year                                        0.013342     0.029290
#   5     booking-at-restaurant-seebichl-EUR_lag_2_log_detrended 0.009056     0.042444
#   6     booking-at-gasthof-eggerwirt-EUR_lag_1_log_detrended 0.007882     0.033417
#   7     booking-at-gamshof-EUR_lag_5_log_detrended         0.006872     0.031250
#   8     booking-at-gamshof-EUR_lag_3_log_detrended         0.006570     0.070553
#   9     booking-at-garni-entstrasser-EUR_lag_1_log_detrended 0.003485     0.018530
#   10    booking-at-gamshof-EUR_lag_4_log_detrended         0.003456     0.032104
#
# Saved: Hotel_28_feature_importance.csv
#
# ================================================================================
# HOTEL 17/22: Hotel_21
# ================================================================================
#
# Calculating SHAP values...
#
# Configuration:
#   Detrending window: 7 days
#   Feature set: simple
#   Min training: 250 days
#
# Performance:
#   Test R2: 0.3145
#   Train R2: 0.7391
#   Overfitting gap: 0.4245
#
# Feature Categories:
#   Competitor lags: 50
#   Market aggregates: 0
#   Temporal basic: 4
#   Temporal cyclical: 6
#   Total features: 60
#
# Top 10 Features by SHAP Importance:
#   Rank  Feature                                            SHAP          XGB
#   --------------------------------------------------------------------------------
#   1     booking-us-aqua-palms-spa-USD_lag_1_log_detrended  0.033562     0.074145
#   2     booking-us-la-croix-USD_lag_1_log_detrended        0.026560     0.084261
#   3     cos_day_of_week                                    0.018385     0.033928
#   4     booking-us-doubletree-alana-waikiki-USD_lag_1_log_detrended 0.012205     0.035641
#   5     booking-us-ramada-plaza-waikiki-USD_lag_1_log_detrended 0.009821     0.050212
#   6     booking-us-ohana-east-oahu-USD_lag_1_log_detrended 0.006843     0.038994
#   7     cos_day_of_year                                    0.005825     0.031192
#   8     day_of_year                                        0.005386     0.032511
#   9     booking-us-castle-queen-kapiolani-USD_lag_1_log_detrended 0.004870     0.031746
#   10    booking-us-aqua-palms-spa-USD_lag_4_log_detrended  0.004503     0.028367
#
# Saved: Hotel_21_feature_importance.csv
#
# ================================================================================
# HOTEL 18/22: Hotel_30
# ================================================================================
# Calculating SHAP values...
#
# Configuration:
#   Detrending window: 7 days
#   Feature set: extended
#   Min training: 200 days
#
# Performance:
#   Test R2: 0.2967
#   Train R2: 0.7528
#   Overfitting gap: 0.4561
#
# Feature Categories:
#   Competitor lags: 15
#   Market aggregates: 4
#   Temporal basic: 4
#   Temporal cyclical: 6
#   Total features: 29
#
# Top 10 Features by SHAP Importance:
#   Rank  Feature                                            SHAP          XGB
#   --------------------------------------------------------------------------------
#   1     day_of_week                                        0.055285     0.214093
#   2     sin_day_of_week                                    0.006772     0.102162
#   3     booking-fr-ibis-styles-paris-boulogne-marcel-sembat-EUR_lag_4_log_detrended 0.006676     0.041764
#   4     booking-fr-ibis-styles-paris-boulogne-marcel-sembat-EUR_lag_1_log_detrended 0.006662     0.039020
#   5     booking-fr-villa-sorel-EUR_lag_4_log_detrended     0.006593     0.046562
#   6     booking-fr-villa-sorel-EUR_lag_2_log_detrended     0.005756     0.033486
#   7     booking-fr-villa-sorel-EUR_lag_1_log_detrended     0.005712     0.041610
#   8     booking-fr-ibis-styles-paris-boulogne-marcel-sembat-EUR_lag_3_log_detrended 0.004551     0.036897
#   9     booking-fr-villa-sorel-EUR_lag_5_log_detrended     0.004021     0.051363
#   10    day_of_year                                        0.002735     0.027763
#
# Saved: Hotel_30_feature_importance.csv
#
# ================================================================================
# HOTEL 19/22: Hotel_10
# ================================================================================
#
# Calculating SHAP values...
#
# Configuration:
#   Detrending window: 7 days
#   Feature set: simple
#   Min training: 180 days
#
# Performance:
#   Test R2: 0.2933
#   Train R2: 0.6517
#   Overfitting gap: 0.3585
#
# Feature Categories:
#   Competitor lags: 45
#   Market aggregates: 0
#   Temporal basic: 4
#   Temporal cyclical: 6
#   Total features: 55
#
# Top 10 Features by SHAP Importance:
#   Rank  Feature                                            SHAP          XGB
#   --------------------------------------------------------------------------------
#   1     booking-es-apartament-home-bike-girona-EUR_lag_1_log_detrended 0.000000     0.000000
#   2     booking-es-apartament-home-bike-girona-EUR_lag_2_log_detrended 0.000000     0.000000
#   3     booking-es-apartament-home-bike-girona-EUR_lag_3_log_detrended 0.000000     0.000000
#   4     booking-es-apartament-home-bike-girona-EUR_lag_4_log_detrended 0.000000     0.000000
#   5     booking-es-apartament-home-bike-girona-EUR_lag_5_log_detrended 0.000000     0.000000
#   6     booking-es-bravissimo-calderers-12-EUR_lag_1_log_detrended 0.000000     0.000000
#   7     booking-es-bravissimo-calderers-12-EUR_lag_2_log_detrended 0.000000     0.000000
#   8     booking-es-bravissimo-calderers-12-EUR_lag_3_log_detrended 0.000000     0.000000
#   9     booking-es-bravissimo-calderers-12-EUR_lag_4_log_detrended 0.000000     0.000000
#   10    booking-es-bravissimo-calderers-12-EUR_lag_5_log_detrended 0.000000     0.000000
#
# Saved: Hotel_10_feature_importance.csv
#
# ================================================================================
# HOTEL 20/22: Hotel_34
# ================================================================================
#
# Calculating SHAP values...
#
# Configuration:
#   Detrending window: 7 days
#   Feature set: simple
#   Min training: 180 days
#
# Performance:
#   Test R2: 0.2604
#   Train R2: 0.7665
#   Overfitting gap: 0.5061
#
# Feature Categories:
#   Competitor lags: 35
#   Market aggregates: 0
#   Temporal basic: 4
#   Temporal cyclical: 6
#   Total features: 45
#
# Top 10 Features by SHAP Importance:
#   Rank  Feature                                            SHAP          XGB
#   --------------------------------------------------------------------------------
#   1     cos_day_of_week                                    0.022551     0.083954
#   2     day_of_week                                        0.019264     0.118480
#   3     sin_day_of_year                                    0.005984     0.040716
#   4     sin_day_of_week                                    0.005746     0.106371
#   5     booking-us-the-chateaux-deer-valley-USD_lag_5_log_detrended 0.005719     0.056053
#   6     booking-us-steineriksenlodgedeervalley-USD_lag_5_log_detrended 0.004448     0.041119
#   7     booking-us-escala-lodges-USD_lag_5_log_detrended   0.003351     0.038249
#   8     day_of_year                                        0.001867     0.049459
#   9     booking-us-the-chateaux-deer-valley-USD_lag_2_log_detrended 0.001800     0.034798
#   10    booking-us-waldorf-astoria-park-city-USD_lag_3_log_detrended 0.001079     0.042070
#
# Saved: Hotel_34_feature_importance.csv
#
# ================================================================================
# HOTEL 21/22: Hotel_01
# ================================================================================
#
# Calculating SHAP values...
#
# Configuration:
#   Detrending window: 7 days
#   Feature set: simple
#   Min training: 180 days
#
# Performance:
#   Test R2: 0.1001
#   Train R2: 0.8479
#   Overfitting gap: 0.7477
#
# Feature Categories:
#   Competitor lags: 25
#   Market aggregates: 0
#   Temporal basic: 4
#   Temporal cyclical: 6
#   Total features: 35
#
# Top 10 Features by SHAP Importance:
#   Rank  Feature                                            SHAP          XGB
#   --------------------------------------------------------------------------------
#   1     cos_day_of_week                                    0.032426     0.166287
#   2     day_of_week                                        0.021729     0.173451
#   3     booking-us-relais-amp-chateaux-camden-harbour-inn-USD_lag_1_log_detrended 0.006576     0.099978
#   4     booking-us-whitehall-USD_lag_1_log_detrended       0.006566     0.064719
#   5     day_of_year                                        0.004826     0.086784
#   6     booking-us-navigator-motor-inn-USD_lag_3_log_detrended 0.003953     0.063744
#   7     booking-us-relais-amp-chateaux-camden-harbour-inn-USD_lag_3_log_detrended 0.003361     0.065667
#   8     booking-us-navigator-motor-inn-USD_lag_4_log_detrended 0.003171     0.058630
#   9     booking-us-relais-amp-chateaux-camden-harbour-inn-USD_lag_4_log_detrended 0.002745     0.059652
#   10    booking-us-16-bay-view-USD_lag_1_log_detrended     0.001781     0.056330
#
# Saved: Hotel_01_feature_importance.csv
#
# ================================================================================
# HOTEL 22/22: Hotel_24
# ================================================================================
#
# Calculating SHAP values...
#
# Configuration:
#   Detrending window: 7 days
#   Feature set: extended
#   Min training: 200 days
#
# Performance:
#   Test R2: -0.2555
#   Train R2: 0.8109
#   Overfitting gap: 1.0664
#
# Feature Categories:
#   Competitor lags: 50
#   Market aggregates: 4
#   Temporal basic: 4
#   Temporal cyclical: 6
#   Total features: 64
#
# Top 10 Features by SHAP Importance:
#   Rank  Feature                                            SHAP          XGB
#   --------------------------------------------------------------------------------
#   1     cos_day_of_week                                    0.045125     0.030908
#   2     booking-us-waikiki-resort-USD_lag_1_log_detrended  0.026775     0.031942
#   3     booking-us-ohana-east-oahu-USD_lag_1_log_detrended 0.024765     0.049245
#   4     booking-us-ilima-USD_lag_1_log_detrended           0.022626     0.032076
#   5     booking-us-white-sands-honolulu-USD_lag_1_log_detrended 0.020941     0.038216
#   6     day_of_week                                        0.019807     0.096817
#   7     booking-us-aqua-aloha-surf-spa-USD_lag_1_log_detrended 0.017270     0.015484
#   8     booking-us-ohana-waikiki-malia-USD_lag_3_log_detrended 0.015968     0.017797
#   9     booking-us-waikiki-resort-USD_lag_4_log_detrended  0.013072     0.033792
#   10    booking-us-waikiki-sand-villa-USD_lag_4_log_detrended 0.012815     0.054353
#
# Saved: Hotel_24_feature_importance.csv
#
# ================================================================================
# SUMMARY: FEATURE IMPORTANCE PATTERNS
# ================================================================================
#
# Average Feature Counts:
#   Total features: 48.6 (std 11.5)
#   Competitor lags: 37.5 (std 11.3)
#   Market aggregates: 1.1 (std 1.8)
#   Temporal: 10.0 (std 0.0)
#
# Most Important Features (Top feature per hotel):
#   day_of_week: 9 hotels
#   cos_day_of_week: 4 hotels
#   sin_day_of_week: 1 hotels
#   booking-us-maui-coast-USD_lag_1_log_detrended: 1 hotels
#   booking-us-painted-buffalo-inn-USD_lag_1_log_detrended: 1 hotels
#   booking-us-kohea-kai-resort-maui-USD_lag_1_log_detrended: 1 hotels
#   booking-us-kona-coast-resort-USD_lag_1_log_detrended: 1 hotels
#   cos_day_of_year: 1 hotels
#   booking-at-gamshof-EUR_lag_1_log_detrended: 1 hotels
#   booking-us-aqua-palms-spa-USD_lag_1_log_detrended: 1 hotels
#
# Correlation: Feature Count vs Performance
#   Correlation(n_features, test_r2): -0.155
#
# ================================================================================
# FEATURE ANALYSIS COMPLETE!
# ================================================================================
#
# Generated files:
#   feature_analysis_summary.csv - Summary for all hotels
#   complete_feature_lists.json - Exact features per hotel
#   [hotel_id]_feature_importance.csv - SHAP values per hotel
#
# Location: ..\models\adaptive_log_method/
# ================================================================================
