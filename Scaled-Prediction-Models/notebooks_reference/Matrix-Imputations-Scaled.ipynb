# %%
import pandas as pd
import numpy as np
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

data_path = Path('../data/full-data/raw')
output_path = Path('../data/full-data/processed')
output_path.mkdir(parents=True, exist_ok=True)

mapping_df = pd.read_csv('../data/full-data/hotel_mapping.csv')
hotel_list = mapping_df['masked_id'].tolist()

print(f"Processing {len(hotel_list)} focal hotels for Matrix Completion")

summary_results = []

for hotel_masked_id in hotel_list:
    print(f"\n{'='*80}")
    print(f"Processing: {hotel_masked_id}")
    print(f"{'='*80}")
    
    try:
        focal_file = data_path / f'{hotel_masked_id}_focal.csv'
        if not focal_file.exists():
            print(f"Focal file not found, skipping...")
            continue
            
        focal = pd.read_csv(focal_file)
        focal['stay_date'] = pd.to_datetime(focal['stay_date'])
        focal = focal.groupby('stay_date')['price'].min().reset_index()
        focal.columns = ['date', 'base_rate']
        focal = focal.sort_values('date').reset_index(drop=True)
        
        print(f"Focal: {len(focal)} days ({focal['date'].min()} to {focal['date'].max()})")
        
        comp_file = data_path / f'{hotel_masked_id}_competitors.csv'
        if not comp_file.exists():
            print(f"Competitor file not found, skipping...")
            continue
            
        compset = pd.read_csv(comp_file)
        compset['stay_date'] = pd.to_datetime(compset['stay_date'])
        compset = compset.groupby(['stay_date', 'hotel_id'])['price'].min().reset_index()
        compset.columns = ['date', 'hotel_id', 'competitor_price']
        
        num_competitors = compset['hotel_id'].nunique()
        print(f"Compset: {num_competitors} hotels")
        
        comp_matrix = compset.pivot(index='date', columns='hotel_id', values='competitor_price')
        merged = focal[['date', 'base_rate']].merge(comp_matrix, on='date', how='inner')
        merged = merged.sort_values('date').reset_index(drop=True)
        
        # Store original column names BEFORE creating matrix
        original_hotel_names = ['base_rate'] + list(comp_matrix.columns)
        
        price_matrix = merged.drop('date', axis=1).values
        dates = merged['date'].values
        
        missing_count = np.isnan(price_matrix).sum()
        missing_pct = 100 * missing_count / price_matrix.size
        
        print(f"Matrix: {price_matrix.shape}")
        print(f"Missing: {missing_count} / {price_matrix.size} ({missing_pct:.1f}%)")
        
        try:
            from fancyimpute import SoftImpute
            max_rank = min(3, min(price_matrix.shape) - 1)
            imputer = SoftImpute(max_rank=max_rank, verbose=False)
            completed_matrix = imputer.fit_transform(price_matrix)
            method_used = "Soft-Impute"
            print(f"Method: Soft-Impute (max_rank={max_rank})")
        except ImportError:
            from sklearn.experimental import enable_iterative_imputer
            from sklearn.impute import IterativeImputer
            from sklearn.linear_model import BayesianRidge
            imputer = IterativeImputer(estimator=BayesianRidge(), max_iter=10, random_state=42, verbose=0)
            completed_matrix = imputer.fit_transform(price_matrix)
            method_used = "IterativeImputer"
            print("Method: IterativeImputer")
        
        remaining_missing = np.isnan(completed_matrix).sum()
        if remaining_missing > 0:
            for i in range(completed_matrix.shape[1]):
                col_mean = np.nanmean(completed_matrix[:, i])
                if np.isnan(col_mean):
                    col_mean = np.nanmean(completed_matrix)
                completed_matrix[np.isnan(completed_matrix[:, i]), i] = col_mean
        
        if (completed_matrix < 0).sum() > 0:
            completed_matrix = np.maximum(completed_matrix, 0)
        
        # FIX: Check if imputer dropped columns (all NaN) and adjust column names
        if completed_matrix.shape[1] != len(original_hotel_names):
            print(f"Warning: Imputer dropped {len(original_hotel_names) - completed_matrix.shape[1]} column(s) (all NaN)")
            # Find which columns survived (not all NaN)
            survived_cols = []
            for col_idx, col_name in enumerate(original_hotel_names):
                col_data = price_matrix[:, col_idx]
                if not np.all(np.isnan(col_data)):
                    survived_cols.append(col_name)
            hotel_names = survived_cols
            print(f"Adjusted to {len(hotel_names)} columns: {hotel_names}")
        else:
            hotel_names = original_hotel_names
        
        # Use adjusted hotel_names for correlation calculation
        # Need to recalculate with only survived columns
        survived_indices = [i for i, col in enumerate(original_hotel_names) if col in hotel_names]
        price_matrix_survived = price_matrix[:, survived_indices]
        
        original_df = pd.DataFrame(price_matrix_survived, columns=hotel_names)
        completed_df_temp = pd.DataFrame(completed_matrix, columns=hotel_names)
        original_corr = original_df.corr()
        completed_corr = completed_df_temp.corr()
        corr_diff = np.abs(original_corr - completed_corr)
        valid_corr = ~(original_corr.isna() | completed_corr.isna())
        avg_corr_diff = corr_diff[valid_corr].mean().mean()
        corr_preserved = (1 - avg_corr_diff) * 100
        
        print(f"Correlation preserved: {corr_preserved:.1f}%")
        
        completed_df = pd.DataFrame(completed_matrix, columns=hotel_names)
        completed_df.insert(0, 'date', dates)
        
        completed_df.to_csv(output_path / f'{hotel_masked_id}_matrix_completion_imputed.csv', index=False)
        
        focal_completed = completed_df[['date', 'base_rate']].copy()
        focal_completed.to_csv(output_path / f'{hotel_masked_id}_focal_matrix_completion.csv', index=False)
        
        comp_completed = completed_df.drop('base_rate', axis=1).copy()
        comp_melted = comp_completed.melt(id_vars='date', var_name='hotel_id', value_name='competitor_price')
        comp_melted.to_csv(output_path / f'{hotel_masked_id}_competitors_matrix_completion.csv', index=False)
        
        comp_matrix_completed = comp_completed.set_index('date').T
        comp_matrix_completed.to_csv(output_path / f'{hotel_masked_id}_competitor_price_matrix.csv')
        
        print(f"Saved: 4 output files")
        
        summary_results.append({
            'hotel_id': hotel_masked_id,
            'matrix_rows': price_matrix.shape[0],
            'matrix_cols': len(hotel_names),
            'num_competitors': len(hotel_names) - 1,
            'missing_values': missing_count,
            'missing_pct': missing_pct,
            'correlation_preserved_pct': corr_preserved,
            'method': method_used,
            'date_start': focal['date'].min(),
            'date_end': focal['date'].max(),
            'status': 'Success'
        })
        
    except Exception as e:
        print(f"Error: {str(e)}")
        summary_results.append({
            'hotel_id': hotel_masked_id,
            'matrix_rows': 0,
            'matrix_cols': 0,
            'num_competitors': 0,
            'missing_values': 0,
            'missing_pct': 0,
            'correlation_preserved_pct': 0,
            'method': 'Failed',
            'date_start': None,
            'date_end': None,
            'status': f'Failed: {str(e)}'
        })

summary_df = pd.DataFrame(summary_results)
summary_df.to_csv(output_path / 'matrix_completion_summary.csv', index=False)

print(f"\n{'='*80}")
print("MATRIX COMPLETION SUMMARY")
print(f"{'='*80}")
print(f"\nTotal hotels processed: {len(hotel_list)}")
print(f"Successful: {len(summary_df[summary_df['status'] == 'Success'])}")
print(f"Failed: {len(summary_df[summary_df['status'] != 'Success'])}")

success_df = summary_df[summary_df['status'] == 'Success']
if len(success_df) > 0:
    print(f"\nAverage matrix size: {success_df['matrix_rows'].mean():.0f} rows × {success_df['matrix_cols'].mean():.1f} cols")
    print(f"Average competitors: {success_df['num_competitors'].mean():.1f}")
    print(f"Average missing: {success_df['missing_pct'].mean():.2f}%")
    print(f"Average correlation preserved: {success_df['correlation_preserved_pct'].mean():.1f}%")

print(f"\nSummary saved: matrix_completion_summary.csv")
print(summary_df[['hotel_id', 'matrix_rows', 'num_competitors', 'missing_pct', 'correlation_preserved_pct', 'status']])
# Out:
# Processing 44 focal hotels for Matrix Completion
#
# ================================================================================
# Processing: Hotel_01
# ================================================================================
# Focal: 563 days (2025-03-27 00:00:00 to 2026-10-10 00:00:00)
# Compset: 5 hotels
# Matrix: (559, 6)
# Missing: 859 / 3354 (25.6%)
# Method: IterativeImputer
# Correlation preserved: 86.3%
# Saved: 4 output files
#
# ================================================================================
# Processing: Hotel_02
# ================================================================================
# Focal: 438 days (2025-07-29 00:00:00 to 2026-10-09 00:00:00)
# Compset: 4 hotels
# Matrix: (430, 5)
# Missing: 85 / 2150 (4.0%)
# Method: IterativeImputer
# Correlation preserved: 97.1%
# Saved: 4 output files
#
# ================================================================================
# Processing: Hotel_03
# ================================================================================
# Focal: 401 days (2024-11-26 00:00:00 to 2025-12-31 00:00:00)
# Compset: 9 hotels
# Matrix: (401, 10)
# Missing: 760 / 4010 (19.0%)
# Method: IterativeImputer
# Correlation preserved: 96.5%
# Saved: 4 output files
#
# ================================================================================
# Processing: Hotel_04
# ================================================================================
# Focal: 632 days (2025-01-16 00:00:00 to 2026-10-09 00:00:00)
# Compset: 4 hotels
# Matrix: (625, 5)
# Missing: 406 / 3125 (13.0%)
# Method: IterativeImputer
# Correlation preserved: 84.3%
# Saved: 4 output files
#
# ================================================================================
# Processing: Hotel_05
# ================================================================================
# Focal: 683 days (2024-11-26 00:00:00 to 2026-10-09 00:00:00)
# Compset: 10 hotels
# Matrix: (680, 11)
# Missing: 1481 / 7480 (19.8%)
# Method: IterativeImputer
# Correlation preserved: 97.4%
# Saved: 4 output files
#
# ================================================================================
# Processing: Hotel_06
# ================================================================================
# Focal: 378 days (2025-09-18 00:00:00 to 2026-09-30 00:00:00)
# Compset: 6 hotels
# Matrix: (378, 7)
# Missing: 198 / 2646 (7.5%)
# Method: IterativeImputer
# Correlation preserved: 98.8%
# Saved: 4 output files
#
# ================================================================================
# Processing: Hotel_07
# ================================================================================
# Focal: 683 days (2024-11-26 00:00:00 to 2026-10-09 00:00:00)
# Compset: 9 hotels
# Matrix: (680, 10)
# Missing: 1031 / 6800 (15.2%)
# Method: IterativeImputer
# Warning: Imputer dropped 1 column(s) (all NaN)
# Adjusted to 9 columns: ['base_rate', 'booking-us-best-western-inn-and-suites-of-castle-rock-USD', 'booking-us-hampton-inn-denver-tech-center-south-USD', 'booking-us-hampton-inn-suites-parker-USD', 'booking-us-hilton-garden-inn-denver-south-meridian-USD', 'booking-us-hyatt-place-denver-south-47-park-meadows-USD', 'booking-us-laquinta-by-wyndham-parker-USD', 'booking-us-springhill-suites-denver-parker-USD', 'booking-us-towneplace-suites-by-marriott-denver-south-lone-tree-USD']
# Correlation preserved: 96.4%
# Saved: 4 output files
#
# ================================================================================
# Processing: Hotel_08
# ================================================================================
# Focal: 684 days (2024-11-26 00:00:00 to 2026-10-10 00:00:00)
# Competitor file not found, skipping...
#
# ================================================================================
# Processing: Hotel_09
# ================================================================================
# Focal: 44 days (2025-09-15 00:00:00 to 2025-11-01 00:00:00)
# Compset: 5 hotels
# Matrix: (44, 6)
# Missing: 88 / 264 (33.3%)
# Method: IterativeImputer
# Correlation preserved: 93.1%
# Saved: 4 output files
#
# ================================================================================
# Processing: Hotel_10
# ================================================================================
# Focal: 611 days (2025-02-07 00:00:00 to 2026-10-10 00:00:00)
# Compset: 9 hotels
# Matrix: (607, 10)
# Missing: 2866 / 6070 (47.2%)
# Method: IterativeImputer
# Correlation preserved: 81.7%
# Saved: 4 output files
#
# ================================================================================
# Processing: Hotel_11
# ================================================================================
# Focal: 483 days (2025-06-15 00:00:00 to 2026-10-10 00:00:00)
# Competitor file not found, skipping...
#
# ================================================================================
# Processing: Hotel_12
# ================================================================================
# Focal: 448 days (2025-07-20 00:00:00 to 2026-10-10 00:00:00)
# Compset: 9 hotels
# Matrix: (444, 10)
# Missing: 691 / 4440 (15.6%)
# Method: IterativeImputer
# Correlation preserved: 94.3%
# Saved: 4 output files
#
# ================================================================================
# Processing: Hotel_13
# ================================================================================
# Focal: 622 days (2025-01-25 00:00:00 to 2026-10-08 00:00:00)
# Compset: 9 hotels
# Matrix: (620, 10)
# Missing: 1987 / 6200 (32.0%)
# Method: IterativeImputer
# Correlation preserved: 93.6%
# Saved: 4 output files
#
# ================================================================================
# Processing: Hotel_14
# ================================================================================
# Focal: 684 days (2024-11-25 00:00:00 to 2026-10-09 00:00:00)
# Compset: 5 hotels
# Matrix: (681, 6)
# Missing: 518 / 4086 (12.7%)
# Method: IterativeImputer
# Correlation preserved: 96.0%
# Saved: 4 output files
#
# ================================================================================
# Processing: Hotel_15
# ================================================================================
# Focal: 405 days (2025-08-22 00:00:00 to 2026-09-30 00:00:00)
# Compset: 5 hotels
# Matrix: (405, 6)
# Missing: 213 / 2430 (8.8%)
# Method: IterativeImputer
# Correlation preserved: 97.5%
# Saved: 4 output files
#
# ================================================================================
# Processing: Hotel_16
# ================================================================================
# Focal file not found, skipping...
#
# ================================================================================
# Processing: Hotel_17
# ================================================================================
# Focal: 598 days (2025-01-11 00:00:00 to 2026-08-31 00:00:00)
# Compset: 8 hotels
# Matrix: (598, 9)
# Missing: 1038 / 5382 (19.3%)
# Method: IterativeImputer
# Correlation preserved: 92.3%
# Saved: 4 output files
#
# ================================================================================
# Processing: Hotel_18
# ================================================================================
# Focal: 377 days (2025-09-28 00:00:00 to 2026-10-09 00:00:00)
# Compset: 6 hotels
# Matrix: (374, 7)
# Missing: 130 / 2618 (5.0%)
# Method: IterativeImputer
# Correlation preserved: 93.4%
# Saved: 4 output files
#
# ================================================================================
# Processing: Hotel_19
# ================================================================================
# Focal: 53 days (2025-09-04 00:00:00 to 2025-10-26 00:00:00)
# Compset: 6 hotels
# Matrix: (53, 7)
# Missing: 238 / 371 (64.2%)
# Method: IterativeImputer
# Warning: Imputer dropped 1 column(s) (all NaN)
# Adjusted to 6 columns: ['base_rate', 'booking-us-inn-on-carleton-USD', 'booking-us-normandie-oceanfront-motor-inn-USD', 'booking-us-portland-regency-USD', 'booking-us-the-francis-USD', 'booking-us-the-nonantum-resort-USD']
# Correlation preserved: 75.8%
# Saved: 4 output files
#
# ================================================================================
# Processing: Hotel_20
# ================================================================================
# Focal: 201 days (2025-09-04 00:00:00 to 2026-10-10 00:00:00)
# Compset: 8 hotels
# Matrix: (197, 9)
# Missing: 704 / 1773 (39.7%)
# Method: IterativeImputer
# Correlation preserved: 84.4%
# Saved: 4 output files
#
# ================================================================================
# Processing: Hotel_21
# ================================================================================
# Focal: 645 days (2024-11-25 00:00:00 to 2026-08-31 00:00:00)
# Compset: 10 hotels
# Matrix: (645, 11)
# Missing: 525 / 7095 (7.4%)
# Method: IterativeImputer
# Correlation preserved: 91.9%
# Saved: 4 output files
#
# ================================================================================
# Processing: Hotel_22
# ================================================================================
# Focal: 675 days (2024-11-25 00:00:00 to 2026-09-30 00:00:00)
# Compset: 9 hotels
# Matrix: (675, 10)
# Missing: 570 / 6750 (8.4%)
# Method: IterativeImputer
# Correlation preserved: 94.8%
# Saved: 4 output files
#
# ================================================================================
# Processing: Hotel_23
# ================================================================================
# Focal: 684 days (2024-11-25 00:00:00 to 2026-10-09 00:00:00)
# Compset: 10 hotels
# Matrix: (681, 11)
# Missing: 1271 / 7491 (17.0%)
# Method: IterativeImputer
# Correlation preserved: 95.8%
# Saved: 4 output files
#
# ================================================================================
# Processing: Hotel_24
# ================================================================================
# Focal: 614 days (2024-11-25 00:00:00 to 2026-07-31 00:00:00)
# Compset: 10 hotels
# Matrix: (614, 11)
# Missing: 614 / 6754 (9.1%)
# Method: IterativeImputer
# Correlation preserved: 92.3%
# Saved: 4 output files
#
# ================================================================================
# Processing: Hotel_25
# ================================================================================
# Focal: 674 days (2024-11-26 00:00:00 to 2026-09-30 00:00:00)
# Compset: 10 hotels
# Matrix: (674, 11)
# Missing: 1376 / 7414 (18.6%)
# Method: IterativeImputer
# Correlation preserved: 91.9%
# Saved: 4 output files
#
# ================================================================================
# Processing: Hotel_26
# ================================================================================
# Focal: 675 days (2024-11-25 00:00:00 to 2026-09-30 00:00:00)
# Compset: 10 hotels
# Matrix: (675, 11)
# Missing: 2391 / 7425 (32.2%)
# Method: IterativeImputer
# Correlation preserved: 86.6%
# Saved: 4 output files
#
# ================================================================================
# Processing: Hotel_27
# ================================================================================
# Focal: 446 days (2025-07-22 00:00:00 to 2026-10-10 00:00:00)
# Compset: 5 hotels
# Matrix: (430, 6)
# Missing: 645 / 2580 (25.0%)
# Method: IterativeImputer
# Correlation preserved: 94.1%
# Saved: 4 output files
#
# ================================================================================
# Processing: Hotel_28
# ================================================================================
# Focal: 604 days (2025-02-14 00:00:00 to 2026-10-10 00:00:00)
# Compset: 6 hotels
# Matrix: (600, 7)
# Missing: 2392 / 4200 (57.0%)
# Method: IterativeImputer
# Correlation preserved: 87.8%
# Saved: 4 output files
#
# ================================================================================
# Processing: Hotel_29
# ================================================================================
# Focal: 211 days (2025-07-11 00:00:00 to 2026-02-06 00:00:00)
# Compset: 10 hotels
# Matrix: (167, 11)
# Missing: 762 / 1837 (41.5%)
# Method: IterativeImputer
# Correlation preserved: 89.6%
# Saved: 4 output files
#
# ================================================================================
# Processing: Hotel_30
# ================================================================================
# Focal: 684 days (2024-11-26 00:00:00 to 2026-10-10 00:00:00)
# Compset: 3 hotels
# Matrix: (680, 4)
# Missing: 324 / 2720 (11.9%)
# Method: IterativeImputer
# Correlation preserved: 99.0%
# Saved: 4 output files
#
# ================================================================================
# Processing: Hotel_31
# ================================================================================
# Focal: 685 days (2024-11-25 00:00:00 to 2026-10-10 00:00:00)
# Compset: 6 hotels
# Matrix: (681, 7)
# Missing: 573 / 4767 (12.0%)
# Method: IterativeImputer
# Correlation preserved: 94.6%
# Saved: 4 output files
#
# ================================================================================
# Processing: Hotel_32
# ================================================================================
# Focal: 602 days (2025-01-27 00:00:00 to 2026-09-20 00:00:00)
# Compset: 5 hotels
# Matrix: (602, 6)
# Missing: 392 / 3612 (10.9%)
# Method: IterativeImputer
# Correlation preserved: 88.1%
# Saved: 4 output files
#
# ================================================================================
# Processing: Hotel_33
# ================================================================================
# Focal: 684 days (2024-11-26 00:00:00 to 2026-10-10 00:00:00)
# Compset: 6 hotels
# Matrix: (680, 7)
# Missing: 659 / 4760 (13.8%)
# Method: IterativeImputer
# Correlation preserved: 90.7%
# Saved: 4 output files
#
# ================================================================================
# Processing: Hotel_34
# ================================================================================
# Focal: 611 days (2025-02-06 00:00:00 to 2026-10-09 00:00:00)
# Compset: 7 hotels
# Matrix: (608, 8)
# Missing: 916 / 4864 (18.8%)
# Method: IterativeImputer
# Correlation preserved: 96.9%
# Saved: 4 output files
#
# ================================================================================
# Processing: Hotel_35
# ================================================================================
# Focal: 402 days (2025-09-04 00:00:00 to 2026-10-10 00:00:00)
# Compset: 8 hotels
# Matrix: (398, 9)
# Missing: 336 / 3582 (9.4%)
# Method: IterativeImputer
# Correlation preserved: 97.4%
# Saved: 4 output files
#
# ================================================================================
# Processing: Hotel_36
# ================================================================================
# Focal: 683 days (2024-11-26 00:00:00 to 2026-10-09 00:00:00)
# Compset: 6 hotels
# Matrix: (680, 7)
# Missing: 1026 / 4760 (21.6%)
# Method: IterativeImputer
# Correlation preserved: 98.4%
# Saved: 4 output files
#
# ================================================================================
# Processing: Hotel_37
# ================================================================================
# Focal: 402 days (2025-09-04 00:00:00 to 2026-10-10 00:00:00)
# Compset: 5 hotels
# Matrix: (398, 6)
# Missing: 264 / 2388 (11.1%)
# Method: IterativeImputer
# Correlation preserved: 95.0%
# Saved: 4 output files
#
# ================================================================================
# Processing: Hotel_38
# ================================================================================
# Focal: 362 days (2025-08-13 00:00:00 to 2026-08-09 00:00:00)
# Compset: 7 hotels
# Matrix: (362, 8)
# Missing: 116 / 2896 (4.0%)
# Method: IterativeImputer
# Correlation preserved: 99.6%
# Saved: 4 output files
#
# ================================================================================
# Processing: Hotel_39
# ================================================================================
# Focal: 355 days (2025-07-02 00:00:00 to 2026-06-24 00:00:00)
# Compset: 10 hotels
# Matrix: (355, 11)
# Missing: 313 / 3905 (8.0%)
# Method: IterativeImputer
# Correlation preserved: 94.6%
# Saved: 4 output files
#
# ================================================================================
# Processing: Hotel_40
# ================================================================================
# Focal: 450 days (2025-07-18 00:00:00 to 2026-10-10 00:00:00)
# Compset: 7 hotels
# Matrix: (446, 8)
# Missing: 534 / 3568 (15.0%)
# Method: IterativeImputer
# Correlation preserved: 91.3%
# Saved: 4 output files
#
# ================================================================================
# Processing: Hotel_41
# ================================================================================
# Focal: 445 days (2025-07-23 00:00:00 to 2026-10-10 00:00:00)
# Compset: 6 hotels
# Matrix: (430, 7)
# Missing: 600 / 3010 (19.9%)
# Method: IterativeImputer
# Correlation preserved: 92.0%
# Saved: 4 output files
#
# ================================================================================
# Processing: Hotel_42
# ================================================================================
# Focal: 387 days (2025-08-31 00:00:00 to 2026-09-21 00:00:00)
# Competitor file not found, skipping...
#
# ================================================================================
# Processing: Hotel_43
# ================================================================================
# Focal: 622 days (2025-01-25 00:00:00 to 2026-10-08 00:00:00)
# Competitor file not found, skipping...
#
# ================================================================================
# Processing: Hotel_44
# ================================================================================
# Focal: 684 days (2024-11-26 00:00:00 to 2026-10-10 00:00:00)
# Competitor file not found, skipping...
#
# ================================================================================
# MATRIX COMPLETION SUMMARY
# ================================================================================
#
# Total hotels processed: 44
# Successful: 38
# Failed: 0
#
# Average matrix size: 507 rows × 8.1 cols
# Average competitors: 7.1
# Average missing: 19.85%
# Average correlation preserved: 92.7%
#
# Summary saved: matrix_completion_summary.csv
#     hotel_id  matrix_rows  num_competitors  missing_pct  \
# 0   Hotel_01          559                5    25.611210
# 1   Hotel_02          430                4     3.953488
# 2   Hotel_03          401                9    18.952618
# 3   Hotel_04          625                4    12.992000
# 4   Hotel_05          680               10    19.799465
# 5   Hotel_06          378                6     7.482993
# 6   Hotel_07          680                8    15.161765
# 7   Hotel_09           44                5    33.333333
# 8   Hotel_10          607                9    47.215815
# 9   Hotel_12          444                9    15.563063
# 10  Hotel_13          620                9    32.048387
# 11  Hotel_14          681                5    12.677435
# 12  Hotel_15          405                5     8.765432
# 13  Hotel_17          598                8    19.286511
# 14  Hotel_18          374                6     4.965623
# 15  Hotel_19           53                5    64.150943
# 16  Hotel_20          197                8    39.706712
# 17  Hotel_21          645               10     7.399577
# 18  Hotel_22          675                9     8.444444
# 19  Hotel_23          681               10    16.967027
# 20  Hotel_24          614               10     9.090909
# 21  Hotel_25          674               10    18.559482
# 22  Hotel_26          675               10    32.202020
# 23  Hotel_27          430                5    25.000000
# 24  Hotel_28          600                6    56.952381
# 25  Hotel_29          167               10    41.480675
# 26  Hotel_30          680                3    11.911765
# 27  Hotel_31          681                6    12.020138
# 28  Hotel_32          602                5    10.852713
# 29  Hotel_33          680                6    13.844538
# 30  Hotel_34          608                7    18.832237
# 31  Hotel_35          398                8     9.380235
# 32  Hotel_36          680                6    21.554622
# 33  Hotel_37          398                5    11.055276
# 34  Hotel_38          362                7     4.005525
# 35  Hotel_39          355               10     8.015365
# 36  Hotel_40          446                7    14.966368
# 37  Hotel_41          430                6    19.933555
#
#     correlation_preserved_pct   status
# 0                   86.325053  Success
# 1                   97.056155  Success
# 2                   96.516912  Success
# 3                   84.303397  Success
# 4                   97.394095  Success
# 5                   98.803591  Success
# 6                   96.429577  Success
# 7                   93.059124  Success
# 8                   81.654173  Success
# 9                   94.281706  Success
# 10                  93.640341  Success
# 11                  95.995501  Success
# 12                  97.537033  Success
# 13                  92.333627  Success
# 14                  93.360066  Success
# 15                  75.841141  Success
# 16                  84.376204  Success
# 17                  91.871844  Success
# 18                  94.781490  Success
# 19                  95.848568  Success
# 20                  92.321296  Success
# 21                  91.916018  Success
# 22                  86.552660  Success
# 23                  94.100062  Success
# 24                  87.832414  Success
# 25                  89.571163  Success
# 26                  98.975614  Success
# 27                  94.573405  Success
# 28                  88.067180  Success
# 29                  90.668690  Success
# 30                  96.907844  Success
# 31                  97.410251  Success
# 32                  98.350114  Success
# 33                  94.984323  Success
# 34                  99.645497  Success
# 35                  94.558180  Success
# 36                  91.293662  Success
# 37                  92.049961  Success
