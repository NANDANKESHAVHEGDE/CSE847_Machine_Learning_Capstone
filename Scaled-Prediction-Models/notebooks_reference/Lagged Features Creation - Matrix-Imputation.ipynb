# %%
import pandas as pd
import numpy as np
from pathlib import Path
import json
import warnings
warnings.filterwarnings('ignore')

data_path = Path('../data/full-data/processed')
output_path = Path('../data/full-data/processed')

mapping_df = pd.read_csv('../data/full-data/hotel_mapping.csv')
hotel_list = mapping_df['masked_id'].tolist()

print(f"Creating lagged features for {len(hotel_list)} focal hotels")

summary_results = []

for hotel_masked_id in hotel_list:
    print(f"\n{'='*80}")
    print(f"Processing: {hotel_masked_id}")
    print(f"{'='*80}")
    
    try:
        focal_file = data_path / f'{hotel_masked_id}_focal_matrix_completion.csv'
        if not focal_file.exists():
            print(f"Focal file not found, skipping...")
            continue
        
        focal = pd.read_csv(focal_file)
        focal['date'] = pd.to_datetime(focal['date'])
        
        print(f"Focal: {len(focal)} rows ({focal['date'].min()} to {focal['date'].max()})")
        
        comp_matrix_file = data_path / f'{hotel_masked_id}_competitor_price_matrix.csv'
        if not comp_matrix_file.exists():
            print(f"Competitor matrix not found, skipping...")
            continue
        
        comp_matrix = pd.read_csv(comp_matrix_file, index_col=0)
        comp_matrix.columns = pd.to_datetime(comp_matrix.columns)
        
        print(f"Competitor matrix: {comp_matrix.shape}")
        
        merged_data = []
        for date in focal['date']:
            row = {'date': date, 'base_rate': focal[focal['date'] == date]['base_rate'].values[0]}
            if date in comp_matrix.columns:
                for hotel in comp_matrix.index:
                    row[hotel] = comp_matrix.loc[hotel, date]
            merged_data.append(row)
        
        df_final = pd.DataFrame(merged_data)
        
        df_final['day_of_week'] = df_final['date'].dt.dayofweek
        df_final['month'] = df_final['date'].dt.month
        df_final['is_weekend'] = (df_final['day_of_week'] >= 5).astype(int)
        
        print(f"After merge: {df_final.shape}")
        
        price_columns = [col for col in df_final.columns if col not in ['date', 'day_of_week', 'month', 'is_weekend']]
        
        final_lags = [1, 2, 3, 4, 5]
        
        df_lagged = df_final.copy()
        for col in price_columns:
            for lag in final_lags:
                df_lagged[f'{col}_lag_{lag}'] = df_lagged[col].shift(lag)
        
        print(f"After lagging: {df_lagged.shape}")
        print(f"Missing values: {df_lagged.isnull().sum().sum()}")
        
        df_lagged_clean = df_lagged.dropna()
        print(f"After dropping NaN: {df_lagged_clean.shape}")
        print(f"Data retention: {len(df_lagged_clean)/len(df_final)*100:.1f}%")
        
        df_with_temporal = df_lagged_clean.copy()
        df_with_temporal['day_of_year'] = df_with_temporal['date'].dt.dayofyear
        df_with_temporal['sin_day_of_week'] = np.sin(2 * np.pi * df_with_temporal['day_of_week'] / 7)
        df_with_temporal['cos_day_of_week'] = np.cos(2 * np.pi * df_with_temporal['day_of_week'] / 7)
        df_with_temporal['sin_month'] = np.sin(2 * np.pi * df_with_temporal['month'] / 12)
        df_with_temporal['cos_month'] = np.cos(2 * np.pi * df_with_temporal['month'] / 12)
        df_with_temporal['sin_day_of_year'] = np.sin(2 * np.pi * df_with_temporal['day_of_year'] / 365)
        df_with_temporal['cos_day_of_year'] = np.cos(2 * np.pi * df_with_temporal['day_of_year'] / 365)
        
        print(f"Final shape: {df_with_temporal.shape}")
        
        df_with_temporal.to_csv(output_path / f'{hotel_masked_id}_lagged_dataset.csv', index=False)
        
        total_observations = len(df_with_temporal)
        total_features = len(df_with_temporal.columns) - 1
        lag_features = len([col for col in df_with_temporal.columns if 'lag' in col])
        temporal_features = 7
        
        lag_metadata = {
            'hotel_id': hotel_masked_id,
            'imputation_method': 'matrix_completion',
            'selected_lags': final_lags,
            'focal_column': 'base_rate',
            'total_lag_features': lag_features,
            'temporal_features': ['sin_day_of_week', 'cos_day_of_week', 'sin_month', 'cos_month', 
                                  'sin_day_of_year', 'cos_day_of_year', 'is_weekend'],
            'final_observations': total_observations,
            'original_observations': len(df_final),
            'data_retention_pct': round(len(df_with_temporal)/len(df_final)*100, 1),
            'feature_summary': {
                'total_features': total_features,
                'lag_features': lag_features,
                'temporal_features': temporal_features,
                'price_features': len(price_columns)
            }
        }
        
        with open(output_path / f'{hotel_masked_id}_lag_metadata.json', 'w') as f:
            json.dump(lag_metadata, f, indent=2)
        
        print(f"Saved: lagged dataset and metadata")
        
        summary_results.append({
            'hotel_id': hotel_masked_id,
            'original_rows': len(df_final),
            'final_rows': total_observations,
            'rows_lost': len(df_final) - total_observations,
            'data_retention_pct': round(len(df_with_temporal)/len(df_final)*100, 1),
            'total_features': total_features,
            'lag_features': lag_features,
            'price_columns': len(price_columns),
            'num_competitors': len(price_columns) - 1,
            'status': 'Success'
        })
        
    except Exception as e:
        print(f"Error: {str(e)}")
        summary_results.append({
            'hotel_id': hotel_masked_id,
            'original_rows': 0,
            'final_rows': 0,
            'rows_lost': 0,
            'data_retention_pct': 0,
            'total_features': 0,
            'lag_features': 0,
            'price_columns': 0,
            'num_competitors': 0,
            'status': f'Failed: {str(e)}'
        })

summary_df = pd.DataFrame(summary_results)
summary_df.to_csv(output_path / 'lagged_features_summary.csv', index=False)

print(f"\n{'='*80}")
print("LAGGED FEATURES SUMMARY")
print(f"{'='*80}")
print(f"\nTotal hotels processed: {len(hotel_list)}")
print(f"Successful: {len(summary_df[summary_df['status'] == 'Success'])}")
print(f"Failed: {len(summary_df[summary_df['status'] != 'Success'])}")

success_df = summary_df[summary_df['status'] == 'Success']
if len(success_df) > 0:
    print(f"\nAverage original rows: {success_df['original_rows'].mean():.0f}")
    print(f"Average final rows: {success_df['final_rows'].mean():.0f}")
    print(f"Average rows lost to lagging: {success_df['rows_lost'].mean():.1f}")
    print(f"Average data retention: {success_df['data_retention_pct'].mean():.1f}%")
    print(f"Average total features: {success_df['total_features'].mean():.0f}")
    print(f"Average lag features: {success_df['lag_features'].mean():.0f}")
    print(f"Average competitors: {success_df['num_competitors'].mean():.1f}")

print(f"\nSummary saved: lagged_features_summary.csv")
print(summary_df[['hotel_id', 'original_rows', 'final_rows', 'data_retention_pct', 'total_features', 'lag_features', 'status']])
# Out:
# Creating lagged features for 44 focal hotels
#
# ================================================================================
# Processing: Hotel_01
# ================================================================================
# Focal: 559 rows (2025-03-27 00:00:00 to 2026-10-06 00:00:00)
# Competitor matrix: (5, 559)
# After merge: (559, 10)
# After lagging: (559, 40)
# Missing values: 90
# After dropping NaN: (554, 40)
# Data retention: 99.1%
# Final shape: (554, 47)
# Saved: lagged dataset and metadata
#
# ================================================================================
# Processing: Hotel_02
# ================================================================================
# Focal: 430 rows (2025-08-03 00:00:00 to 2026-10-06 00:00:00)
# Competitor matrix: (4, 430)
# After merge: (430, 9)
# After lagging: (430, 34)
# Missing values: 75
# After dropping NaN: (425, 34)
# Data retention: 98.8%
# Final shape: (425, 41)
# Saved: lagged dataset and metadata
#
# ================================================================================
# Processing: Hotel_03
# ================================================================================
# Focal: 401 rows (2024-11-26 00:00:00 to 2025-12-31 00:00:00)
# Competitor matrix: (9, 401)
# After merge: (401, 14)
# After lagging: (401, 64)
# Missing values: 150
# After dropping NaN: (396, 64)
# Data retention: 98.8%
# Final shape: (396, 71)
# Saved: lagged dataset and metadata
#
# ================================================================================
# Processing: Hotel_04
# ================================================================================
# Focal: 625 rows (2025-01-20 00:00:00 to 2026-10-06 00:00:00)
# Competitor matrix: (4, 625)
# After merge: (625, 9)
# After lagging: (625, 34)
# Missing values: 75
# After dropping NaN: (620, 34)
# Data retention: 99.2%
# Final shape: (620, 41)
# Saved: lagged dataset and metadata
#
# ================================================================================
# Processing: Hotel_05
# ================================================================================
# Focal: 680 rows (2024-11-26 00:00:00 to 2026-10-06 00:00:00)
# Competitor matrix: (10, 680)
# After merge: (680, 15)
# After lagging: (680, 70)
# Missing values: 165
# After dropping NaN: (675, 70)
# Data retention: 99.3%
# Final shape: (675, 77)
# Saved: lagged dataset and metadata
#
# ================================================================================
# Processing: Hotel_06
# ================================================================================
# Focal: 378 rows (2025-09-18 00:00:00 to 2026-09-30 00:00:00)
# Competitor matrix: (6, 378)
# After merge: (378, 11)
# After lagging: (378, 46)
# Missing values: 105
# After dropping NaN: (373, 46)
# Data retention: 98.7%
# Final shape: (373, 53)
# Saved: lagged dataset and metadata
#
# ================================================================================
# Processing: Hotel_07
# ================================================================================
# Focal: 680 rows (2024-11-26 00:00:00 to 2026-10-06 00:00:00)
# Competitor matrix: (8, 680)
# After merge: (680, 13)
# After lagging: (680, 58)
# Missing values: 135
# After dropping NaN: (675, 58)
# Data retention: 99.3%
# Final shape: (675, 65)
# Saved: lagged dataset and metadata
#
# ================================================================================
# Processing: Hotel_08
# ================================================================================
# Focal file not found, skipping...
#
# ================================================================================
# Processing: Hotel_09
# ================================================================================
# Focal: 44 rows (2025-09-15 00:00:00 to 2025-11-01 00:00:00)
# Competitor matrix: (5, 44)
# After merge: (44, 10)
# After lagging: (44, 40)
# Missing values: 90
# After dropping NaN: (39, 40)
# Data retention: 88.6%
# Final shape: (39, 47)
# Saved: lagged dataset and metadata
#
# ================================================================================
# Processing: Hotel_10
# ================================================================================
# Focal: 607 rows (2025-02-07 00:00:00 to 2026-10-06 00:00:00)
# Competitor matrix: (9, 607)
# After merge: (607, 14)
# After lagging: (607, 64)
# Missing values: 150
# After dropping NaN: (602, 64)
# Data retention: 99.2%
# Final shape: (602, 71)
# Saved: lagged dataset and metadata
#
# ================================================================================
# Processing: Hotel_11
# ================================================================================
# Focal file not found, skipping...
#
# ================================================================================
# Processing: Hotel_12
# ================================================================================
# Focal: 444 rows (2025-07-20 00:00:00 to 2026-10-06 00:00:00)
# Competitor matrix: (9, 444)
# After merge: (444, 14)
# After lagging: (444, 64)
# Missing values: 150
# After dropping NaN: (439, 64)
# Data retention: 98.9%
# Final shape: (439, 71)
# Saved: lagged dataset and metadata
#
# ================================================================================
# Processing: Hotel_13
# ================================================================================
# Focal: 620 rows (2025-01-25 00:00:00 to 2026-10-06 00:00:00)
# Competitor matrix: (9, 620)
# After merge: (620, 14)
# After lagging: (620, 64)
# Missing values: 150
# After dropping NaN: (615, 64)
# Data retention: 99.2%
# Final shape: (615, 71)
# Saved: lagged dataset and metadata
#
# ================================================================================
# Processing: Hotel_14
# ================================================================================
# Focal: 681 rows (2024-11-25 00:00:00 to 2026-10-06 00:00:00)
# Competitor matrix: (5, 681)
# After merge: (681, 10)
# After lagging: (681, 40)
# Missing values: 90
# After dropping NaN: (676, 40)
# Data retention: 99.3%
# Final shape: (676, 47)
# Saved: lagged dataset and metadata
#
# ================================================================================
# Processing: Hotel_15
# ================================================================================
# Focal: 405 rows (2025-08-22 00:00:00 to 2026-09-30 00:00:00)
# Competitor matrix: (5, 405)
# After merge: (405, 10)
# After lagging: (405, 40)
# Missing values: 90
# After dropping NaN: (400, 40)
# Data retention: 98.8%
# Final shape: (400, 47)
# Saved: lagged dataset and metadata
#
# ================================================================================
# Processing: Hotel_16
# ================================================================================
# Focal file not found, skipping...
#
# ================================================================================
# Processing: Hotel_17
# ================================================================================
# Focal: 598 rows (2025-01-11 00:00:00 to 2026-08-31 00:00:00)
# Competitor matrix: (8, 598)
# After merge: (598, 13)
# After lagging: (598, 58)
# Missing values: 135
# After dropping NaN: (593, 58)
# Data retention: 99.2%
# Final shape: (593, 65)
# Saved: lagged dataset and metadata
#
# ================================================================================
# Processing: Hotel_18
# ================================================================================
# Focal: 374 rows (2025-09-28 00:00:00 to 2026-10-06 00:00:00)
# Competitor matrix: (6, 374)
# After merge: (374, 11)
# After lagging: (374, 46)
# Missing values: 105
# After dropping NaN: (369, 46)
# Data retention: 98.7%
# Final shape: (369, 53)
# Saved: lagged dataset and metadata
#
# ================================================================================
# Processing: Hotel_19
# ================================================================================
# Focal: 53 rows (2025-09-04 00:00:00 to 2025-10-26 00:00:00)
# Competitor matrix: (5, 53)
# After merge: (53, 10)
# After lagging: (53, 40)
# Missing values: 90
# After dropping NaN: (48, 40)
# Data retention: 90.6%
# Final shape: (48, 47)
# Saved: lagged dataset and metadata
#
# ================================================================================
# Processing: Hotel_20
# ================================================================================
# Focal: 197 rows (2025-09-04 00:00:00 to 2026-10-06 00:00:00)
# Competitor matrix: (8, 197)
# After merge: (197, 13)
# After lagging: (197, 58)
# Missing values: 135
# After dropping NaN: (192, 58)
# Data retention: 97.5%
# Final shape: (192, 65)
# Saved: lagged dataset and metadata
#
# ================================================================================
# Processing: Hotel_21
# ================================================================================
# Focal: 645 rows (2024-11-25 00:00:00 to 2026-08-31 00:00:00)
# Competitor matrix: (10, 645)
# After merge: (645, 15)
# After lagging: (645, 70)
# Missing values: 165
# After dropping NaN: (640, 70)
# Data retention: 99.2%
# Final shape: (640, 77)
# Saved: lagged dataset and metadata
#
# ================================================================================
# Processing: Hotel_22
# ================================================================================
# Focal: 675 rows (2024-11-25 00:00:00 to 2026-09-30 00:00:00)
# Competitor matrix: (9, 675)
# After merge: (675, 14)
# After lagging: (675, 64)
# Missing values: 150
# After dropping NaN: (670, 64)
# Data retention: 99.3%
# Final shape: (670, 71)
# Saved: lagged dataset and metadata
#
# ================================================================================
# Processing: Hotel_23
# ================================================================================
# Focal: 681 rows (2024-11-25 00:00:00 to 2026-10-06 00:00:00)
# Competitor matrix: (10, 681)
# After merge: (681, 15)
# After lagging: (681, 70)
# Missing values: 165
# After dropping NaN: (676, 70)
# Data retention: 99.3%
# Final shape: (676, 77)
# Saved: lagged dataset and metadata
#
# ================================================================================
# Processing: Hotel_24
# ================================================================================
# Focal: 614 rows (2024-11-25 00:00:00 to 2026-07-31 00:00:00)
# Competitor matrix: (10, 614)
# After merge: (614, 15)
# After lagging: (614, 70)
# Missing values: 165
# After dropping NaN: (609, 70)
# Data retention: 99.2%
# Final shape: (609, 77)
# Saved: lagged dataset and metadata
#
# ================================================================================
# Processing: Hotel_25
# ================================================================================
# Focal: 674 rows (2024-11-26 00:00:00 to 2026-09-30 00:00:00)
# Competitor matrix: (10, 674)
# After merge: (674, 15)
# After lagging: (674, 70)
# Missing values: 165
# After dropping NaN: (669, 70)
# Data retention: 99.3%
# Final shape: (669, 77)
# Saved: lagged dataset and metadata
#
# ================================================================================
# Processing: Hotel_26
# ================================================================================
# Focal: 675 rows (2024-11-25 00:00:00 to 2026-09-30 00:00:00)
# Competitor matrix: (10, 675)
# After merge: (675, 15)
# After lagging: (675, 70)
# Missing values: 165
# After dropping NaN: (670, 70)
# Data retention: 99.3%
# Final shape: (670, 77)
# Saved: lagged dataset and metadata
#
# ================================================================================
# Processing: Hotel_27
# ================================================================================
# Focal: 430 rows (2025-08-03 00:00:00 to 2026-10-06 00:00:00)
# Competitor matrix: (5, 430)
# After merge: (430, 10)
# After lagging: (430, 40)
# Missing values: 90
# After dropping NaN: (425, 40)
# Data retention: 98.8%
# Final shape: (425, 47)
# Saved: lagged dataset and metadata
#
# ================================================================================
# Processing: Hotel_28
# ================================================================================
# Focal: 600 rows (2025-02-14 00:00:00 to 2026-10-06 00:00:00)
# Competitor matrix: (6, 600)
# After merge: (600, 11)
# After lagging: (600, 46)
# Missing values: 105
# After dropping NaN: (595, 46)
# Data retention: 99.2%
# Final shape: (595, 53)
# Saved: lagged dataset and metadata
#
# ================================================================================
# Processing: Hotel_29
# ================================================================================
# Focal: 167 rows (2025-07-25 00:00:00 to 2026-01-07 00:00:00)
# Competitor matrix: (10, 167)
# After merge: (167, 15)
# After lagging: (167, 70)
# Missing values: 165
# After dropping NaN: (162, 70)
# Data retention: 97.0%
# Final shape: (162, 77)
# Saved: lagged dataset and metadata
#
# ================================================================================
# Processing: Hotel_30
# ================================================================================
# Focal: 680 rows (2024-11-26 00:00:00 to 2026-10-06 00:00:00)
# Competitor matrix: (3, 680)
# After merge: (680, 8)
# After lagging: (680, 28)
# Missing values: 60
# After dropping NaN: (675, 28)
# Data retention: 99.3%
# Final shape: (675, 35)
# Saved: lagged dataset and metadata
#
# ================================================================================
# Processing: Hotel_31
# ================================================================================
# Focal: 681 rows (2024-11-25 00:00:00 to 2026-10-06 00:00:00)
# Competitor matrix: (6, 681)
# After merge: (681, 11)
# After lagging: (681, 46)
# Missing values: 105
# After dropping NaN: (676, 46)
# Data retention: 99.3%
# Final shape: (676, 53)
# Saved: lagged dataset and metadata
#
# ================================================================================
# Processing: Hotel_32
# ================================================================================
# Focal: 602 rows (2025-01-27 00:00:00 to 2026-09-20 00:00:00)
# Competitor matrix: (5, 602)
# After merge: (602, 10)
# After lagging: (602, 40)
# Missing values: 90
# After dropping NaN: (597, 40)
# Data retention: 99.2%
# Final shape: (597, 47)
# Saved: lagged dataset and metadata
#
# ================================================================================
# Processing: Hotel_33
# ================================================================================
# Focal: 680 rows (2024-11-26 00:00:00 to 2026-10-06 00:00:00)
# Competitor matrix: (6, 680)
# After merge: (680, 11)
# After lagging: (680, 46)
# Missing values: 105
# After dropping NaN: (675, 46)
# Data retention: 99.3%
# Final shape: (675, 53)
# Saved: lagged dataset and metadata
#
# ================================================================================
# Processing: Hotel_34
# ================================================================================
# Focal: 608 rows (2025-02-06 00:00:00 to 2026-10-06 00:00:00)
# Competitor matrix: (7, 608)
# After merge: (608, 12)
# After lagging: (608, 52)
# Missing values: 120
# After dropping NaN: (603, 52)
# Data retention: 99.2%
# Final shape: (603, 59)
# Saved: lagged dataset and metadata
#
# ================================================================================
# Processing: Hotel_35
# ================================================================================
# Focal: 398 rows (2025-09-04 00:00:00 to 2026-10-06 00:00:00)
# Competitor matrix: (8, 398)
# After merge: (398, 13)
# After lagging: (398, 58)
# Missing values: 135
# After dropping NaN: (393, 58)
# Data retention: 98.7%
# Final shape: (393, 65)
# Saved: lagged dataset and metadata
#
# ================================================================================
# Processing: Hotel_36
# ================================================================================
# Focal: 680 rows (2024-11-26 00:00:00 to 2026-10-06 00:00:00)
# Competitor matrix: (6, 680)
# After merge: (680, 11)
# After lagging: (680, 46)
# Missing values: 105
# After dropping NaN: (675, 46)
# Data retention: 99.3%
# Final shape: (675, 53)
# Saved: lagged dataset and metadata
#
# ================================================================================
# Processing: Hotel_37
# ================================================================================
# Focal: 398 rows (2025-09-04 00:00:00 to 2026-10-06 00:00:00)
# Competitor matrix: (5, 398)
# After merge: (398, 10)
# After lagging: (398, 40)
# Missing values: 90
# After dropping NaN: (393, 40)
# Data retention: 98.7%
# Final shape: (393, 47)
# Saved: lagged dataset and metadata
#
# ================================================================================
# Processing: Hotel_38
# ================================================================================
# Focal: 362 rows (2025-08-13 00:00:00 to 2026-08-09 00:00:00)
# Competitor matrix: (7, 362)
# After merge: (362, 12)
# After lagging: (362, 52)
# Missing values: 120
# After dropping NaN: (357, 52)
# Data retention: 98.6%
# Final shape: (357, 59)
# Saved: lagged dataset and metadata
#
# ================================================================================
# Processing: Hotel_39
# ================================================================================
# Focal: 355 rows (2025-07-02 00:00:00 to 2026-06-24 00:00:00)
# Competitor matrix: (10, 355)
# After merge: (355, 15)
# After lagging: (355, 70)
# Missing values: 165
# After dropping NaN: (350, 70)
# Data retention: 98.6%
# Final shape: (350, 77)
# Saved: lagged dataset and metadata
#
# ================================================================================
# Processing: Hotel_40
# ================================================================================
# Focal: 446 rows (2025-07-18 00:00:00 to 2026-10-06 00:00:00)
# Competitor matrix: (7, 446)
# After merge: (446, 12)
# After lagging: (446, 52)
# Missing values: 120
# After dropping NaN: (441, 52)
# Data retention: 98.9%
# Final shape: (441, 59)
# Saved: lagged dataset and metadata
#
# ================================================================================
# Processing: Hotel_41
# ================================================================================
# Focal: 430 rows (2025-08-03 00:00:00 to 2026-10-06 00:00:00)
# Competitor matrix: (6, 430)
# After merge: (430, 11)
# After lagging: (430, 46)
# Missing values: 105
# After dropping NaN: (425, 46)
# Data retention: 98.8%
# Final shape: (425, 53)
# Saved: lagged dataset and metadata
#
# ================================================================================
# Processing: Hotel_42
# ================================================================================
# Focal file not found, skipping...
#
# ================================================================================
# Processing: Hotel_43
# ================================================================================
# Focal file not found, skipping...
#
# ================================================================================
# Processing: Hotel_44
# ================================================================================
# Focal file not found, skipping...
#
# ================================================================================
# LAGGED FEATURES SUMMARY
# ================================================================================
#
# Total hotels processed: 44
# Successful: 38
# Failed: 0
#
# Average original rows: 507
# Average final rows: 502
# Average rows lost to lagging: 5.0
# Average data retention: 98.5%
# Average total features: 59
# Average lag features: 41
# Average competitors: 7.1
#
# Summary saved: lagged_features_summary.csv
#     hotel_id  original_rows  final_rows  data_retention_pct  total_features  \
# 0   Hotel_01            559         554                99.1              46
# 1   Hotel_02            430         425                98.8              40
# 2   Hotel_03            401         396                98.8              70
# 3   Hotel_04            625         620                99.2              40
# 4   Hotel_05            680         675                99.3              76
# 5   Hotel_06            378         373                98.7              52
# 6   Hotel_07            680         675                99.3              64
# 7   Hotel_09             44          39                88.6              46
# 8   Hotel_10            607         602                99.2              70
# 9   Hotel_12            444         439                98.9              70
# 10  Hotel_13            620         615                99.2              70
# 11  Hotel_14            681         676                99.3              46
# 12  Hotel_15            405         400                98.8              46
# 13  Hotel_17            598         593                99.2              64
# 14  Hotel_18            374         369                98.7              52
# 15  Hotel_19             53          48                90.6              46
# 16  Hotel_20            197         192                97.5              64
# 17  Hotel_21            645         640                99.2              76
# 18  Hotel_22            675         670                99.3              70
# 19  Hotel_23            681         676                99.3              76
# 20  Hotel_24            614         609                99.2              76
# 21  Hotel_25            674         669                99.3              76
# 22  Hotel_26            675         670                99.3              76
# 23  Hotel_27            430         425                98.8              46
# 24  Hotel_28            600         595                99.2              52
# 25  Hotel_29            167         162                97.0              76
# 26  Hotel_30            680         675                99.3              34
# 27  Hotel_31            681         676                99.3              52
# 28  Hotel_32            602         597                99.2              46
# 29  Hotel_33            680         675                99.3              52
# 30  Hotel_34            608         603                99.2              58
# 31  Hotel_35            398         393                98.7              64
# 32  Hotel_36            680         675                99.3              52
# 33  Hotel_37            398         393                98.7              46
# 34  Hotel_38            362         357                98.6              58
# 35  Hotel_39            355         350                98.6              76
# 36  Hotel_40            446         441                98.9              58
# 37  Hotel_41            430         425                98.8              52
#
#     lag_features   status
# 0             30  Success
# 1             25  Success
# 2             50  Success
# 3             27  Success
# 4             55  Success
# 5             36  Success
# 6             45  Success
# 7             30  Success
# 8             50  Success
# 9             50  Success
# 10            50  Success
# 11            30  Success
# 12            30  Success
# 13            45  Success
# 14            35  Success
# 15            30  Success
# 16            45  Success
# 17            55  Success
# 18            50  Success
# 19            55  Success
# 20            55  Success
# 21            55  Success
# 22            55  Success
# 23            30  Success
# 24            35  Success
# 25            55  Success
# 26            20  Success
# 27            35  Success
# 28            30  Success
# 29            35  Success
# 30            40  Success
# 31            45  Success
# 32            35  Success
# 33            30  Success
# 34            40  Success
# 35            55  Success
# 36            40  Success
# 37            35  Success
