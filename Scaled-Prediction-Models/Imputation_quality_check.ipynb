# %%
"""
Imputation Quality Validation Script - FINAL VERSION
=====================================================

Validates imputation quality by comparing:
- PRE: /raw/Hotel_XX_competitors.csv (with NaNs)
- POST: /processed/Hotel_XX_competitors_matrix_completion.csv (filled)

Compares the 'price' column (pre) with 'competitor_price' column (post)
"""

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ks_2samp, spearmanr
from pathlib import Path
import json
import warnings
warnings.filterwarnings('ignore')

# ============================================================================
# Configuration
# ============================================================================

RAW_DATA_DIR = "../data/full-data/raw"
PROCESSED_DATA_DIR = "../data/full-data/processed"
OUTPUT_DIR = "imputation_validation_results"

# Create output directory
Path(OUTPUT_DIR).mkdir(exist_ok=True)

# ============================================================================
# Main Validation Function
# ============================================================================

def validate_hotel_imputation(hotel_id):
    """
    Validate imputation quality for a single hotel
    
    Parameters:
    -----------
    hotel_id : str
        Hotel identifier (e.g., 'Hotel_01', 'Hotel_02')
    """
    
    print(f"\n{'='*70}")
    print(f"Validating: {hotel_id}")
    print(f"{'='*70}")
    
    # -------------------------------------------------------------------------
    # 1. Load Data
    # -------------------------------------------------------------------------
    
    try:
        # PRE-imputation: Raw competitor data with NaNs
        # Columns: hotel_id, stay_date, price, can_check_in, min_length_of_stay
        pre_file = f"{RAW_DATA_DIR}/{hotel_id}_competitors.csv"
        
        if not Path(pre_file).exists():
            print(f"✗ Pre-imputation file not found: {pre_file}")
            return None
            
        pre_data = pd.read_csv(pre_file)
        
        # POST-imputation: Matrix completion imputed (long format)
        # Columns: date, hotel_id, competitor_price
        post_file = f"{PROCESSED_DATA_DIR}/{hotel_id}_competitors_matrix_completion.csv"
        
        if not Path(post_file).exists():
            print(f"✗ Post-imputation file not found: {post_file}")
            return None
        
        post_data = pd.read_csv(post_file)
        
        print(f"✓ Loaded pre-imputation: {len(pre_data)} rows")
        print(f"✓ Loaded post-imputation: {len(post_data)} rows")
        
    except Exception as e:
        print(f"✗ Error loading files: {e}")
        return None
    
    # -------------------------------------------------------------------------
    # 2. Align Data by Date
    # -------------------------------------------------------------------------
    
    # Ensure dates are datetime
    pre_data['date'] = pd.to_datetime(pre_data['stay_date'])
    post_data['date'] = pd.to_datetime(post_data['date'])
    
    # Find common dates and hotels
    common_dates = set(pre_data['date']).intersection(set(post_data['date']))
    common_hotels = set(pre_data['hotel_id']).intersection(set(post_data['hotel_id']))
    
    print(f"✓ Common dates: {len(common_dates)}")
    print(f"✓ Common competitors: {len(common_hotels)}")
    
    # Filter to common dates and hotels
    pre_filtered = pre_data[pre_data['date'].isin(common_dates) & 
                            pre_data['hotel_id'].isin(common_hotels)].copy()
    post_filtered = post_data[post_data['date'].isin(common_dates) & 
                              post_data['hotel_id'].isin(common_hotels)].copy()
    
    print(f"✓ Aligned datasets: {len(pre_filtered)} rows each")
    
    # -------------------------------------------------------------------------
    # 3. Missing Data Summary
    # -------------------------------------------------------------------------
    
    print(f"\n{'Missing Data Summary':-^70}")
    
    # Use 'price' from pre, 'competitor_price' from post
    missing_pre = pre_filtered['price'].isnull().sum()
    missing_post = post_filtered['competitor_price'].isnull().sum()
    
    total_cells = len(pre_filtered)
    pct_missing_pre = (missing_pre / total_cells) * 100
    pct_missing_post = (missing_post / total_cells) * 100
    
    print(f"Total rows: {total_cells:,}")
    print(f"Missing before: {missing_pre:,} ({pct_missing_pre:.1f}%)")
    print(f"Missing after: {missing_post:,} ({pct_missing_post:.1f}%)")
    print(f"Values imputed: {missing_pre - missing_post:,}")
    
    if missing_post > 0:
        print(f"⚠️  Warning: {missing_post} values still missing!")
    
    results = {
        'hotel_id': hotel_id,
        'n_rows': len(pre_filtered),
        'n_competitors': len(common_hotels),
        'total_cells': total_cells,
        'missing_before': int(missing_pre),
        'missing_after': int(missing_post),
        'pct_missing': float(pct_missing_pre),
        'n_imputed': int(missing_pre - missing_post)
    }
    
    # -------------------------------------------------------------------------
    # 4. Distribution Comparison
    # -------------------------------------------------------------------------
    
    print(f"\n{'Distribution Preservation (KS Test)':-^70}")
    
    # Get non-null values
    pre_vals = pre_filtered['price'].dropna()
    post_vals = post_filtered['competitor_price'].dropna()
    
    print(f"Sample sizes:")
    print(f"  Pre (observed): {len(pre_vals)}")
    print(f"  Post (all): {len(post_vals)}")
    
    # Basic statistics
    pre_mean = pre_vals.mean()
    post_mean = post_vals.mean()
    mean_delta = post_mean - pre_mean
    
    pre_std = pre_vals.std()
    post_std = post_vals.std()
    std_delta = post_std - pre_std
    
    pre_median = pre_vals.median()
    post_median = post_vals.median()
    median_delta = post_median - pre_median
    
    print(f"\n{'Statistic':<15s} {'Pre':<15s} {'Post':<15s} {'Delta':<15s}")
    print("-" * 70)
    print(f"{'Mean':<15s} ${pre_mean:<14.2f} ${post_mean:<14.2f} ${mean_delta:+14.2f}")
    print(f"{'Median':<15s} ${pre_median:<14.2f} ${post_median:<14.2f} ${median_delta:+14.2f}")
    print(f"{'Std Dev':<15s} ${pre_std:<14.2f} ${post_std:<14.2f} ${std_delta:+14.2f}")
    print(f"{'Min':<15s} ${pre_vals.min():<14.2f} ${post_vals.min():<14.2f}")
    print(f"{'Max':<15s} ${pre_vals.max():<14.2f} ${post_vals.max():<14.2f}")
    
    # KS Test
    ks_stat, ks_pval = ks_2samp(pre_vals, post_vals)
    
    print(f"\nKolmogorov-Smirnov Test:")
    print(f"  KS Statistic: {ks_stat:.4f}")
    print(f"  p-value: {ks_pval:.4f}")
    
    if ks_pval > 0.05:
        print(f"  Result: Distributions SIMILAR ✓ (p > 0.05)")
        ks_significant = False
    else:
        print(f"  Result: Distributions DIFFER ⚠️ (p < 0.05)")
        ks_significant = True
    
    results['distribution_stats'] = {
        'pre_mean': float(pre_mean),
        'post_mean': float(post_mean),
        'mean_delta': float(mean_delta),
        'pre_std': float(pre_std),
        'post_std': float(post_std),
        'std_delta': float(std_delta),
        'pre_median': float(pre_median),
        'post_median': float(post_median),
        'median_delta': float(median_delta),
        'ks_statistic': float(ks_stat),
        'ks_pvalue': float(ks_pval),
        'ks_significant': ks_significant
    }
    
    # -------------------------------------------------------------------------
    # 5. Overall Quality Assessment
    # -------------------------------------------------------------------------
    
    print(f"\n{'Overall Assessment':-^70}")
    
    issues = []
    warnings_list = []
    
    # Check mean change (threshold: 10% of std dev)
    if abs(mean_delta) > pre_std * 0.1:
        pct_change = (mean_delta / pre_mean) * 100
        issues.append(f"Mean shifted by ${mean_delta:+.2f} ({pct_change:+.1f}%)")
        print(f"✗ Mean shifted significantly: ${mean_delta:+.2f}")
    else:
        print(f"✓ Mean preserved (Δ = ${mean_delta:+.2f})")
    
    # Check std change
    if abs(std_delta) > pre_std * 0.1:
        pct_change = (std_delta / pre_std) * 100
        warnings_list.append(f"Std dev changed by {pct_change:+.1f}%")
        print(f"⚠  Std dev changed: ${std_delta:+.2f}")
    else:
        print(f"✓ Std dev preserved (Δ = ${std_delta:+.2f})")
    
    # Check KS test
    if ks_pval > 0.05:
        print(f"✓ Distribution similar (KS p = {ks_pval:.4f})")
    else:
        issues.append(f"Distribution changed (KS p = {ks_pval:.4f})")
        print(f"✗ Distribution differs (KS p = {ks_pval:.4f})")
    
    # Check imputation completeness
    if missing_post == 0:
        print(f"✓ All missing values imputed ({missing_pre} filled)")
    elif missing_post < missing_pre:
        pct_filled = ((missing_pre - missing_post) / missing_pre) * 100
        print(f"✓ Most missing values imputed ({missing_pre - missing_post} filled, {pct_filled:.1f}%)")
    else:
        issues.append(f"Missing values not reduced")
    
    # Determine overall quality
    n_issues = len(issues)
    n_warnings = len(warnings_list)
    
    if n_issues == 0:
        overall = "EXCELLENT ✓"
        quality_score = 5
        message = "Imputation successfully preserved original characteristics!"
    elif n_issues == 1 and n_warnings == 0:
        overall = "GOOD ✓"
        quality_score = 4
        message = "Minor differences detected but generally good preservation."
    elif n_issues == 1 or (n_issues == 0 and n_warnings > 0):
        overall = "FAIR"
        quality_score = 3
        message = "Some differences detected. Review carefully."
    else:
        overall = "POOR ⚠️"
        quality_score = 2
        message = "Significant differences detected. Imputation may have introduced bias."
    
    print(f"\n{'='*70}")
    print(f"OVERALL QUALITY: {overall} (Score: {quality_score}/5)")
    print(f"{message}")
    
    if issues:
        print(f"\nIssues:")
        for issue in issues:
            print(f"  - {issue}")
    
    if warnings_list:
        print(f"\nWarnings:")
        for warning in warnings_list:
            print(f"  - {warning}")
    
    results['overall_assessment'] = {
        'quality': overall,
        'quality_score': quality_score,
        'issues': issues,
        'warnings': warnings_list,
        'message': message
    }
    
    return results


# ============================================================================
# Process All Hotels
# ============================================================================

def validate_all_hotels():
    """Validate imputation for all hotels"""
    
    print("="*70)
    print("IMPUTATION QUALITY VALIDATION - ALL HOTELS")
    print("="*70)
    
    # Find all raw competitor files
    raw_files = list(Path(RAW_DATA_DIR).glob("Hotel_*_competitors.csv"))
    
    print(f"\nFound {len(raw_files)} hotels to validate")
    print(f"Looking for matching files in: {PROCESSED_DATA_DIR}")
    
    all_results = []
    successful = 0
    failed = 0
    
    for raw_file in sorted(raw_files):
        hotel_id = raw_file.stem.replace('_competitors', '')
        
        result = validate_hotel_imputation(hotel_id)
        
        if result:
            all_results.append(result)
            successful += 1
        else:
            failed += 1
    
    print(f"\n{'Validation Summary':-^70}")
    print(f"Successful: {successful}/{len(raw_files)}")
    print(f"Failed: {failed}/{len(raw_files)}")
    
    if not all_results:
        print("\n❌ No hotels validated successfully!")
        return None, None
    
    # -------------------------------------------------------------------------
    # Create Summary Report
    # -------------------------------------------------------------------------
    
    print("\n" + "="*70)
    print("SUMMARY REPORT - ALL HOTELS")
    print("="*70)
    
    # Convert to DataFrame
    summary_df = pd.DataFrame([
        {
            'hotel_id': r['hotel_id'],
            'n_rows': r['n_rows'],
            'n_competitors': r['n_competitors'],
            'pct_missing': r['pct_missing'],
            'mean_delta': r['distribution_stats']['mean_delta'],
            'std_delta': r['distribution_stats']['std_delta'],
            'ks_pvalue': r['distribution_stats']['ks_pvalue'],
            'ks_significant': r['distribution_stats']['ks_significant'],
            'quality_score': r['overall_assessment']['quality_score'],
            'quality': r['overall_assessment']['quality']
        }
        for r in all_results
    ])
    
    # Statistics
    print(f"\nTotal hotels validated: {len(all_results)}")
    print(f"Mean missing data: {summary_df['pct_missing'].mean():.1f}%")
    print(f"Median missing data: {summary_df['pct_missing'].median():.1f}%")
    
    print("\nQuality Distribution:")
    quality_counts = summary_df['quality'].value_counts()
    for quality in ['EXCELLENT ✓', 'GOOD ✓', 'FAIR', 'POOR ⚠️']:
        count = quality_counts.get(quality, 0)
        pct = (count / len(summary_df)) * 100 if len(summary_df) > 0 else 0
        bar = '█' * int(pct / 5)
        print(f"  {quality:<15s}: {count:2d} ({pct:5.1f}%) {bar}")
    
    print("\nMean Delta Distribution:")
    print(f"  Mean of mean deltas: ${summary_df['mean_delta'].mean():.2f}")
    print(f"  Median of mean deltas: ${summary_df['mean_delta'].median():.2f}")
    print(f"  Hotels with negative bias: {(summary_df['mean_delta'] < -10).sum()}")
    print(f"  Hotels with positive bias: {(summary_df['mean_delta'] > 10).sum()}")
    
    print("\nTop 5 Hotels (Best Quality):")
    top5 = summary_df.nlargest(5, 'quality_score')[
        ['hotel_id', 'pct_missing', 'mean_delta', 'ks_pvalue', 'quality']
    ]
    print(top5.to_string(index=False))
    
    if len(summary_df) >= 5:
        print("\nBottom 5 Hotels (Issues Detected):")
        bottom5 = summary_df.nsmallest(5, 'quality_score')[
            ['hotel_id', 'pct_missing', 'mean_delta', 'ks_pvalue', 'quality']
        ]
        print(bottom5.to_string(index=False))
    
    # Save results
    summary_df.to_csv(f'{OUTPUT_DIR}/imputation_validation_summary.csv', 
                     index=False)
    print(f"\n✓ Summary saved: {OUTPUT_DIR}/imputation_validation_summary.csv")
    
    with open(f'{OUTPUT_DIR}/imputation_validation_details.json', 'w') as f:
        json.dump(all_results, f, indent=2, default=str)
    print(f"✓ Details saved: {OUTPUT_DIR}/imputation_validation_details.json")
    
    return summary_df, all_results


# ============================================================================
# MAIN EXECUTION
# ============================================================================

if __name__ == "__main__":
    
    print("\n" + "="*70)
    print("STARTING IMPUTATION VALIDATION")
    print("="*70)
    print(f"\nRaw data directory: {RAW_DATA_DIR}")
    print(f"Processed data directory: {PROCESSED_DATA_DIR}")
    print(f"Output directory: {OUTPUT_DIR}")
    print("\nComparing:")
    print("  PRE:  /raw/Hotel_XX_competitors.csv → 'price' column")
    print("  POST: /processed/Hotel_XX_competitors_matrix_completion.csv → 'competitor_price' column")
    
    # Validate all hotels
    result = validate_all_hotels()
    
    if result is not None and result[0] is not None:
        summary_df, all_results = result
        
        print("\n" + "="*70)
        print("VALIDATION COMPLETE!")
        print("="*70)
        print(f"\nResults saved to: {OUTPUT_DIR}/")
        print("  - imputation_validation_summary.csv (summary table)")
        print("  - imputation_validation_details.json (full details)")
        
        # Print key findings
        n_fair_or_worse = (summary_df['quality_score'] <= 3).sum()
        if n_fair_or_worse > 0:
            print(f"\n⚠️  Note: {n_fair_or_worse} hotels have FAIR or POOR quality")
            print("   Review imputation_validation_summary.csv for details")
    else:
        print("\n" + "="*70)
        print("VALIDATION FAILED!")
        print("="*70)
        print("\n📋 Check that both directories exist and contain matching files")
# Out:
# ======================================================================
# STARTING IMPUTATION VALIDATION
# ======================================================================
#
# Raw data directory: ../data/full-data/raw
# Processed data directory: ../data/full-data/processed
# Output directory: imputation_validation_results
#
# Comparing:
#   PRE:  /raw/Hotel_XX_competitors.csv → 'price' column
#   POST: /processed/Hotel_XX_competitors_matrix_completion.csv → 'competitor_price' column
# ======================================================================
# IMPUTATION QUALITY VALIDATION - ALL HOTELS
# ======================================================================
#
# Found 39 hotels to validate
# Looking for matching files in: ../data/full-data/processed
#
# ======================================================================
# Validating: Hotel_01
# ======================================================================
# ✓ Loaded pre-imputation: 2915 rows
# ✓ Loaded post-imputation: 2795 rows
# ✓ Common dates: 559
# ✓ Common competitors: 5
# ✓ Aligned datasets: 2795 rows each
#
# -------------------------Missing Data Summary-------------------------
# Total rows: 2,795
# Missing before: 859 (30.7%)
# Missing after: 0 (0.0%)
# Values imputed: 859
#
# -----------------Distribution Preservation (KS Test)------------------
# Sample sizes:
#   Pre (observed): 1936
#   Post (all): 2795
#
# Statistic       Pre             Post            Delta
# ----------------------------------------------------------------------
# Mean            $299.89         $329.11         $        +29.22
# Median          $259.24         $278.10         $        +18.87
# Std Dev         $175.01         $193.74         $        +18.74
# Min             $130.38         $130.38
# Max             $1810.00        $1810.00
#
# Kolmogorov-Smirnov Test:
#   KS Statistic: 0.0807
#   p-value: 0.0000
#   Result: Distributions DIFFER ⚠️ (p < 0.05)
#
# --------------------------Overall Assessment--------------------------
# ✗ Mean shifted significantly: $+29.22
# ⚠  Std dev changed: $+18.74
# ✗ Distribution differs (KS p = 0.0000)
# ✓ All missing values imputed (859 filled)
#
# ======================================================================
# OVERALL QUALITY: POOR ⚠️ (Score: 2/5)
# Significant differences detected. Imputation may have introduced bias.
#
# Issues:
#   - Mean shifted by $+29.22 (+9.7%)
#   - Distribution changed (KS p = 0.0000)
#
# Warnings:
#   - Std dev changed by +10.7%
#
# ======================================================================
# Validating: Hotel_02
# ======================================================================
# ✓ Loaded pre-imputation: 1720 rows
# ✓ Loaded post-imputation: 1720 rows
# ✓ Common dates: 430
# ✓ Common competitors: 4
# ✓ Aligned datasets: 1720 rows each
#
# -------------------------Missing Data Summary-------------------------
# Total rows: 1,720
# Missing before: 85 (4.9%)
# Missing after: 0 (0.0%)
# Values imputed: 85
#
# -----------------Distribution Preservation (KS Test)------------------
# Sample sizes:
#   Pre (observed): 1635
#   Post (all): 1720
#
# Statistic       Pre             Post            Delta
# ----------------------------------------------------------------------
# Mean            $87.09          $86.88          $         -0.22
# Median          $83.99          $83.99          $         +0.00
# Std Dev         $21.32          $21.72          $         +0.40
# Min             $49.94          $49.94
# Max             $249.00         $249.00
#
# Kolmogorov-Smirnov Test:
#   KS Statistic: 0.0190
#   p-value: 0.9146
#   Result: Distributions SIMILAR ✓ (p > 0.05)
#
# --------------------------Overall Assessment--------------------------
# ✓ Mean preserved (Δ = $-0.22)
# ✓ Std dev preserved (Δ = $+0.40)
# ✓ Distribution similar (KS p = 0.9146)
# ✓ All missing values imputed (85 filled)
#
# ======================================================================
# OVERALL QUALITY: EXCELLENT ✓ (Score: 5/5)
# Imputation successfully preserved original characteristics!
#
# ======================================================================
# Validating: Hotel_03
# ======================================================================
# ✓ Loaded pre-imputation: 7173 rows
# ✓ Loaded post-imputation: 3609 rows
# ✓ Common dates: 401
# ✓ Common competitors: 9
# ✓ Aligned datasets: 3609 rows each
#
# -------------------------Missing Data Summary-------------------------
# Total rows: 3,609
# Missing before: 760 (21.1%)
# Missing after: 0 (0.0%)
# Values imputed: 760
#
# -----------------Distribution Preservation (KS Test)------------------
# Sample sizes:
#   Pre (observed): 2849
#   Post (all): 3609
#
# Statistic       Pre             Post            Delta
# ----------------------------------------------------------------------
# Mean            $380.05         $402.71         $        +22.66
# Median          $292.95         $312.55         $        +19.60
# Std Dev         $201.50         $213.48         $        +11.98
# Min             $145.95         $0.00
# Max             $1185.45        $1190.05
#
# Kolmogorov-Smirnov Test:
#   KS Statistic: 0.0478
#   p-value: 0.0013
#   Result: Distributions DIFFER ⚠️ (p < 0.05)
#
# --------------------------Overall Assessment--------------------------
# ✗ Mean shifted significantly: $+22.66
# ✓ Std dev preserved (Δ = $+11.98)
# ✗ Distribution differs (KS p = 0.0013)
# ✓ All missing values imputed (760 filled)
#
# ======================================================================
# OVERALL QUALITY: POOR ⚠️ (Score: 2/5)
# Significant differences detected. Imputation may have introduced bias.
#
# Issues:
#   - Mean shifted by $+22.66 (+6.0%)
#   - Distribution changed (KS p = 0.0013)
#
# ======================================================================
# Validating: Hotel_04
# ======================================================================
# ✓ Loaded pre-imputation: 2500 rows
# ✓ Loaded post-imputation: 2500 rows
# ✓ Common dates: 625
# ✓ Common competitors: 4
# ✓ Aligned datasets: 2500 rows each
#
# -------------------------Missing Data Summary-------------------------
# Total rows: 2,500
# Missing before: 406 (16.2%)
# Missing after: 0 (0.0%)
# Values imputed: 406
#
# -----------------Distribution Preservation (KS Test)------------------
# Sample sizes:
#   Pre (observed): 2094
#   Post (all): 2500
#
# Statistic       Pre             Post            Delta
# ----------------------------------------------------------------------
# Mean            $129.66         $136.42         $         +6.76
# Median          $118.99         $118.99         $         +0.00
# Std Dev         $47.95          $68.78          $        +20.83
# Min             $72.29          $60.79
# Max             $1003.00        $1003.00
#
# Kolmogorov-Smirnov Test:
#   KS Statistic: 0.0256
#   p-value: 0.4349
#   Result: Distributions SIMILAR ✓ (p > 0.05)
#
# --------------------------Overall Assessment--------------------------
# ✗ Mean shifted significantly: $+6.76
# ⚠  Std dev changed: $+20.83
# ✓ Distribution similar (KS p = 0.4349)
# ✓ All missing values imputed (406 filled)
#
# ======================================================================
# OVERALL QUALITY: FAIR (Score: 3/5)
# Some differences detected. Review carefully.
#
# Issues:
#   - Mean shifted by $+6.76 (+5.2%)
#
# Warnings:
#   - Std dev changed by +43.4%
#
# ======================================================================
# Validating: Hotel_05
# ======================================================================
# ✓ Loaded pre-imputation: 7970 rows
# ✓ Loaded post-imputation: 6800 rows
# ✓ Common dates: 680
# ✓ Common competitors: 10
# ✓ Aligned datasets: 6800 rows each
#
# -------------------------Missing Data Summary-------------------------
# Total rows: 6,800
# Missing before: 1,481 (21.8%)
# Missing after: 0 (0.0%)
# Values imputed: 1,481
#
# -----------------Distribution Preservation (KS Test)------------------
# Sample sizes:
#   Pre (observed): 5319
#   Post (all): 6800
#
# Statistic       Pre             Post            Delta
# ----------------------------------------------------------------------
# Mean            $432.97         $433.47         $         +0.50
# Median          $351.60         $363.03         $        +11.43
# Std Dev         $269.29         $270.70         $         +1.41
# Min             $121.71         $0.00
# Max             $2412.00        $2412.00
#
# Kolmogorov-Smirnov Test:
#   KS Statistic: 0.0182
#   p-value: 0.2725
#   Result: Distributions SIMILAR ✓ (p > 0.05)
#
# --------------------------Overall Assessment--------------------------
# ✓ Mean preserved (Δ = $+0.50)
# ✓ Std dev preserved (Δ = $+1.41)
# ✓ Distribution similar (KS p = 0.2725)
# ✓ All missing values imputed (1481 filled)
#
# ======================================================================
# OVERALL QUALITY: EXCELLENT ✓ (Score: 5/5)
# Imputation successfully preserved original characteristics!
#
# ======================================================================
# Validating: Hotel_06
# ======================================================================
# ✓ Loaded pre-imputation: 2296 rows
# ✓ Loaded post-imputation: 2268 rows
# ✓ Common dates: 378
# ✓ Common competitors: 6
# ✓ Aligned datasets: 2248 rows each
#
# -------------------------Missing Data Summary-------------------------
# Total rows: 2,248
# Missing before: 178 (7.9%)
# Missing after: 0 (0.0%)
# Values imputed: 178
#
# -----------------Distribution Preservation (KS Test)------------------
# Sample sizes:
#   Pre (observed): 2070
#   Post (all): 2268
#
# Statistic       Pre             Post            Delta
# ----------------------------------------------------------------------
# Mean            $283.54         $287.44         $         +3.90
# Median          $261.00         $269.25         $         +8.25
# Std Dev         $107.32         $106.48         $         -0.83
# Min             $101.00         $101.00
# Max             $849.00         $849.00
#
# Kolmogorov-Smirnov Test:
#   KS Statistic: 0.0254
#   p-value: 0.4765
#   Result: Distributions SIMILAR ✓ (p > 0.05)
#
# --------------------------Overall Assessment--------------------------
# ✓ Mean preserved (Δ = $+3.90)
# ✓ Std dev preserved (Δ = $-0.83)
# ✓ Distribution similar (KS p = 0.4765)
# ✓ All missing values imputed (178 filled)
#
# ======================================================================
# OVERALL QUALITY: EXCELLENT ✓ (Score: 5/5)
# Imputation successfully preserved original characteristics!
#
# ======================================================================
# Validating: Hotel_07
# ======================================================================
# ✓ Loaded pre-imputation: 7173 rows
# ✓ Loaded post-imputation: 5440 rows
# ✓ Common dates: 680
# ✓ Common competitors: 8
# ✓ Aligned datasets: 5440 rows each
#
# -------------------------Missing Data Summary-------------------------
# Total rows: 5,440
# Missing before: 351 (6.5%)
# Missing after: 0 (0.0%)
# Values imputed: 351
#
# -----------------Distribution Preservation (KS Test)------------------
# Sample sizes:
#   Pre (observed): 5089
#   Post (all): 5440
#
# Statistic       Pre             Post            Delta
# ----------------------------------------------------------------------
# Mean            $119.00         $121.19         $         +2.20
# Median          $110.00         $113.90         $         +3.90
# Std Dev         $31.38          $32.45          $         +1.07
# Min             $65.45          $65.45
# Max             $355.00         $355.00
#
# Kolmogorov-Smirnov Test:
#   KS Statistic: 0.0334
#   p-value: 0.0055
#   Result: Distributions DIFFER ⚠️ (p < 0.05)
#
# --------------------------Overall Assessment--------------------------
# ✓ Mean preserved (Δ = $+2.20)
# ✓ Std dev preserved (Δ = $+1.07)
# ✗ Distribution differs (KS p = 0.0055)
# ✓ All missing values imputed (351 filled)
#
# ======================================================================
# OVERALL QUALITY: GOOD ✓ (Score: 4/5)
# Minor differences detected but generally good preservation.
#
# Issues:
#   - Distribution changed (KS p = 0.0055)
#
# ======================================================================
# Validating: Hotel_09
# ======================================================================
# ✓ Loaded pre-imputation: 1995 rows
# ✓ Loaded post-imputation: 220 rows
# ✓ Common dates: 44
# ✓ Common competitors: 5
# ✓ Aligned datasets: 220 rows each
#
# -------------------------Missing Data Summary-------------------------
# Total rows: 220
# Missing before: 88 (40.0%)
# Missing after: 0 (0.0%)
# Values imputed: 88
#
# -----------------Distribution Preservation (KS Test)------------------
# Sample sizes:
#   Pre (observed): 132
#   Post (all): 220
#
# Statistic       Pre             Post            Delta
# ----------------------------------------------------------------------
# Mean            $471.74         $476.05         $         +4.31
# Median          $435.56         $436.85         $         +1.29
# Std Dev         $164.53         $154.72         $         -9.80
# Min             $179.87         $179.87
# Max             $1158.09        $1158.09
#
# Kolmogorov-Smirnov Test:
#   KS Statistic: 0.0424
#   p-value: 0.9972
#   Result: Distributions SIMILAR ✓ (p > 0.05)
#
# --------------------------Overall Assessment--------------------------
# ✓ Mean preserved (Δ = $+4.31)
# ✓ Std dev preserved (Δ = $-9.80)
# ✓ Distribution similar (KS p = 0.9972)
# ✓ All missing values imputed (88 filled)
#
# ======================================================================
# OVERALL QUALITY: EXCELLENT ✓ (Score: 5/5)
# Imputation successfully preserved original characteristics!
#
# ======================================================================
# Validating: Hotel_10
# ======================================================================
# ✓ Loaded pre-imputation: 5463 rows
# ✓ Loaded post-imputation: 5463 rows
# ✓ Common dates: 607
# ✓ Common competitors: 9
# ✓ Aligned datasets: 5463 rows each
#
# -------------------------Missing Data Summary-------------------------
# Total rows: 5,463
# Missing before: 2,866 (52.5%)
# Missing after: 0 (0.0%)
# Values imputed: 2,866
#
# -----------------Distribution Preservation (KS Test)------------------
# Sample sizes:
#   Pre (observed): 2597
#   Post (all): 5463
#
# Statistic       Pre             Post            Delta
# ----------------------------------------------------------------------
# Mean            $252.11         $234.01         $        -18.10
# Median          $257.77         $235.03         $        -22.74
# Std Dev         $87.72          $78.23          $         -9.49
# Min             $90.91          $38.99
# Max             $506.45         $520.25
#
# Kolmogorov-Smirnov Test:
#   KS Statistic: 0.1310
#   p-value: 0.0000
#   Result: Distributions DIFFER ⚠️ (p < 0.05)
#
# --------------------------Overall Assessment--------------------------
# ✗ Mean shifted significantly: $-18.10
# ⚠  Std dev changed: $-9.49
# ✗ Distribution differs (KS p = 0.0000)
# ✓ All missing values imputed (2866 filled)
#
# ======================================================================
# OVERALL QUALITY: POOR ⚠️ (Score: 2/5)
# Significant differences detected. Imputation may have introduced bias.
#
# Issues:
#   - Mean shifted by $-18.10 (-7.2%)
#   - Distribution changed (KS p = 0.0000)
#
# Warnings:
#   - Std dev changed by -10.8%
#
# ======================================================================
# Validating: Hotel_12
# ======================================================================
# ✓ Loaded pre-imputation: 4023 rows
# ✓ Loaded post-imputation: 3996 rows
# ✓ Common dates: 444
# ✓ Common competitors: 9
# ✓ Aligned datasets: 3996 rows each
#
# -------------------------Missing Data Summary-------------------------
# Total rows: 3,996
# Missing before: 691 (17.3%)
# Missing after: 0 (0.0%)
# Values imputed: 691
#
# -----------------Distribution Preservation (KS Test)------------------
# Sample sizes:
#   Pre (observed): 3305
#   Post (all): 3996
#
# Statistic       Pre             Post            Delta
# ----------------------------------------------------------------------
# Mean            $216.19         $217.07         $         +0.88
# Median          $184.00         $186.00         $         +2.00
# Std Dev         $101.17         $101.10         $         -0.07
# Min             $83.85          $83.85
# Max             $980.00         $980.00
#
# Kolmogorov-Smirnov Test:
#   KS Statistic: 0.0166
#   p-value: 0.6905
#   Result: Distributions SIMILAR ✓ (p > 0.05)
#
# --------------------------Overall Assessment--------------------------
# ✓ Mean preserved (Δ = $+0.88)
# ✓ Std dev preserved (Δ = $-0.07)
# ✓ Distribution similar (KS p = 0.6905)
# ✓ All missing values imputed (691 filled)
#
# ======================================================================
# OVERALL QUALITY: EXCELLENT ✓ (Score: 5/5)
# Imputation successfully preserved original characteristics!
#
# ======================================================================
# Validating: Hotel_13
# ======================================================================
# ✓ Loaded pre-imputation: 5591 rows
# ✓ Loaded post-imputation: 5580 rows
# ✓ Common dates: 620
# ✓ Common competitors: 9
# ✓ Aligned datasets: 5551 rows each
#
# -------------------------Missing Data Summary-------------------------
# Total rows: 5,551
# Missing before: 1,958 (35.3%)
# Missing after: 0 (0.0%)
# Values imputed: 1,958
#
# -----------------Distribution Preservation (KS Test)------------------
# Sample sizes:
#   Pre (observed): 3593
#   Post (all): 5580
#
# Statistic       Pre             Post            Delta
# ----------------------------------------------------------------------
# Mean            $170.33         $171.56         $         +1.22
# Median          $150.20         $160.64         $        +10.44
# Std Dev         $73.14          $67.42          $         -5.72
# Min             $60.63          $0.00
# Max             $599.00         $683.77
#
# Kolmogorov-Smirnov Test:
#   KS Statistic: 0.0654
#   p-value: 0.0000
#   Result: Distributions DIFFER ⚠️ (p < 0.05)
#
# --------------------------Overall Assessment--------------------------
# ✓ Mean preserved (Δ = $+1.22)
# ✓ Std dev preserved (Δ = $-5.72)
# ✗ Distribution differs (KS p = 0.0000)
# ✓ All missing values imputed (1958 filled)
#
# ======================================================================
# OVERALL QUALITY: GOOD ✓ (Score: 4/5)
# Minor differences detected but generally good preservation.
#
# Issues:
#   - Distribution changed (KS p = 0.0000)
#
# ======================================================================
# Validating: Hotel_14
# ======================================================================
# ✓ Loaded pre-imputation: 3985 rows
# ✓ Loaded post-imputation: 3405 rows
# ✓ Common dates: 681
# ✓ Common competitors: 5
# ✓ Aligned datasets: 3405 rows each
#
# -------------------------Missing Data Summary-------------------------
# Total rows: 3,405
# Missing before: 518 (15.2%)
# Missing after: 0 (0.0%)
# Values imputed: 518
#
# -----------------Distribution Preservation (KS Test)------------------
# Sample sizes:
#   Pre (observed): 2887
#   Post (all): 3405
#
# Statistic       Pre             Post            Delta
# ----------------------------------------------------------------------
# Mean            $321.66         $326.25         $         +4.59
# Median          $293.90         $299.00         $         +5.10
# Std Dev         $121.63         $115.52         $         -6.11
# Min             $154.00         $0.00
# Max             $904.12         $904.12
#
# Kolmogorov-Smirnov Test:
#   KS Statistic: 0.0677
#   p-value: 0.0000
#   Result: Distributions DIFFER ⚠️ (p < 0.05)
#
# --------------------------Overall Assessment--------------------------
# ✓ Mean preserved (Δ = $+4.59)
# ✓ Std dev preserved (Δ = $-6.11)
# ✗ Distribution differs (KS p = 0.0000)
# ✓ All missing values imputed (518 filled)
#
# ======================================================================
# OVERALL QUALITY: GOOD ✓ (Score: 4/5)
# Minor differences detected but generally good preservation.
#
# Issues:
#   - Distribution changed (KS p = 0.0000)
#
# ======================================================================
# Validating: Hotel_15
# ======================================================================
# ✓ Loaded pre-imputation: 2060 rows
# ✓ Loaded post-imputation: 2025 rows
# ✓ Common dates: 405
# ✓ Common competitors: 5
# ✓ Aligned datasets: 2025 rows each
#
# -------------------------Missing Data Summary-------------------------
# Total rows: 2,025
# Missing before: 213 (10.5%)
# Missing after: 0 (0.0%)
# Values imputed: 213
#
# -----------------Distribution Preservation (KS Test)------------------
# Sample sizes:
#   Pre (observed): 1812
#   Post (all): 2025
#
# Statistic       Pre             Post            Delta
# ----------------------------------------------------------------------
# Mean            $352.51         $383.95         $        +31.43
# Median          $301.00         $308.40         $         +7.40
# Std Dev         $169.48         $202.02         $        +32.53
# Min             $151.75         $151.75
# Max             $1273.00        $1359.24
#
# Kolmogorov-Smirnov Test:
#   KS Statistic: 0.0650
#   p-value: 0.0006
#   Result: Distributions DIFFER ⚠️ (p < 0.05)
#
# --------------------------Overall Assessment--------------------------
# ✗ Mean shifted significantly: $+31.43
# ⚠  Std dev changed: $+32.53
# ✗ Distribution differs (KS p = 0.0006)
# ✓ All missing values imputed (213 filled)
#
# ======================================================================
# OVERALL QUALITY: POOR ⚠️ (Score: 2/5)
# Significant differences detected. Imputation may have introduced bias.
#
# Issues:
#   - Mean shifted by $+31.43 (+8.9%)
#   - Distribution changed (KS p = 0.0006)
#
# Warnings:
#   - Std dev changed by +19.2%
#
# ======================================================================
# Validating: Hotel_16
# ======================================================================
# ✗ Post-imputation file not found: ../data/full-data/processed/Hotel_16_competitors_matrix_completion.csv
#
# ======================================================================
# Validating: Hotel_17
# ======================================================================
# ✓ Loaded pre-imputation: 5080 rows
# ✓ Loaded post-imputation: 4784 rows
# ✓ Common dates: 598
# ✓ Common competitors: 8
# ✓ Aligned datasets: 4784 rows each
#
# -------------------------Missing Data Summary-------------------------
# Total rows: 4,784
# Missing before: 1,038 (21.7%)
# Missing after: 0 (0.0%)
# Values imputed: 1,038
#
# -----------------Distribution Preservation (KS Test)------------------
# Sample sizes:
#   Pre (observed): 3746
#   Post (all): 4784
#
# Statistic       Pre             Post            Delta
# ----------------------------------------------------------------------
# Mean            $372.82         $374.76         $         +1.94
# Median          $348.65         $354.25         $         +5.60
# Std Dev         $145.09         $143.19         $         -1.90
# Min             $148.70         $148.70
# Max             $1455.30        $1455.30
#
# Kolmogorov-Smirnov Test:
#   KS Statistic: 0.0232
#   p-value: 0.2036
#   Result: Distributions SIMILAR ✓ (p > 0.05)
#
# --------------------------Overall Assessment--------------------------
# ✓ Mean preserved (Δ = $+1.94)
# ✓ Std dev preserved (Δ = $-1.90)
# ✓ Distribution similar (KS p = 0.2036)
# ✓ All missing values imputed (1038 filled)
#
# ======================================================================
# OVERALL QUALITY: EXCELLENT ✓ (Score: 5/5)
# Imputation successfully preserved original characteristics!
#
# ======================================================================
# Validating: Hotel_18
# ======================================================================
# ✓ Loaded pre-imputation: 2250 rows
# ✓ Loaded post-imputation: 2244 rows
# ✓ Common dates: 374
# ✓ Common competitors: 6
# ✓ Aligned datasets: 2242 rows each
#
# -------------------------Missing Data Summary-------------------------
# Total rows: 2,242
# Missing before: 128 (5.7%)
# Missing after: 0 (0.0%)
# Values imputed: 128
#
# -----------------Distribution Preservation (KS Test)------------------
# Sample sizes:
#   Pre (observed): 2114
#   Post (all): 2244
#
# Statistic       Pre             Post            Delta
# ----------------------------------------------------------------------
# Mean            $111.69         $111.93         $         +0.24
# Median          $103.50         $97.00          $         -6.50
# Std Dev         $72.18          $74.06          $         +1.89
# Min             $50.99          $47.35
# Max             $851.60         $851.60
#
# Kolmogorov-Smirnov Test:
#   KS Statistic: 0.0125
#   p-value: 0.9946
#   Result: Distributions SIMILAR ✓ (p > 0.05)
#
# --------------------------Overall Assessment--------------------------
# ✓ Mean preserved (Δ = $+0.24)
# ✓ Std dev preserved (Δ = $+1.89)
# ✓ Distribution similar (KS p = 0.9946)
# ✓ All missing values imputed (128 filled)
#
# ======================================================================
# OVERALL QUALITY: EXCELLENT ✓ (Score: 5/5)
# Imputation successfully preserved original characteristics!
#
# ======================================================================
# Validating: Hotel_19
# ======================================================================
# ✓ Loaded pre-imputation: 2394 rows
# ✓ Loaded post-imputation: 265 rows
# ✓ Common dates: 53
# ✓ Common competitors: 5
# ✓ Aligned datasets: 265 rows each
#
# -------------------------Missing Data Summary-------------------------
# Total rows: 265
# Missing before: 185 (69.8%)
# Missing after: 0 (0.0%)
# Values imputed: 185
#
# -----------------Distribution Preservation (KS Test)------------------
# Sample sizes:
#   Pre (observed): 80
#   Post (all): 265
#
# Statistic       Pre             Post            Delta
# ----------------------------------------------------------------------
# Mean            $364.07         $361.18         $         -2.89
# Median          $369.90         $363.39         $         -6.51
# Std Dev         $114.27         $114.39         $         +0.13
# Min             $179.87         $126.65
# Max             $674.00         $674.00
#
# Kolmogorov-Smirnov Test:
#   KS Statistic: 0.1566
#   p-value: 0.0868
#   Result: Distributions SIMILAR ✓ (p > 0.05)
#
# --------------------------Overall Assessment--------------------------
# ✓ Mean preserved (Δ = $-2.89)
# ✓ Std dev preserved (Δ = $+0.13)
# ✓ Distribution similar (KS p = 0.0868)
# ✓ All missing values imputed (185 filled)
#
# ======================================================================
# OVERALL QUALITY: EXCELLENT ✓ (Score: 5/5)
# Imputation successfully preserved original characteristics!
#
# ======================================================================
# Validating: Hotel_20
# ======================================================================
# ✓ Loaded pre-imputation: 3700 rows
# ✓ Loaded post-imputation: 1576 rows
# ✓ Common dates: 197
# ✓ Common competitors: 8
# ✓ Aligned datasets: 1536 rows each
#
# -------------------------Missing Data Summary-------------------------
# Total rows: 1,536
# Missing before: 664 (43.2%)
# Missing after: 0 (0.0%)
# Values imputed: 664
#
# -----------------Distribution Preservation (KS Test)------------------
# Sample sizes:
#   Pre (observed): 872
#   Post (all): 1576
#
# Statistic       Pre             Post            Delta
# ----------------------------------------------------------------------
# Mean            $422.89         $442.01         $        +19.12
# Median          $372.00         $374.72         $         +2.72
# Std Dev         $182.06         $215.72         $        +33.65
# Min             $159.00         $153.47
# Max             $1450.00        $1580.74
#
# Kolmogorov-Smirnov Test:
#   KS Statistic: 0.1048
#   p-value: 0.0000
#   Result: Distributions DIFFER ⚠️ (p < 0.05)
#
# --------------------------Overall Assessment--------------------------
# ✗ Mean shifted significantly: $+19.12
# ⚠  Std dev changed: $+33.65
# ✗ Distribution differs (KS p = 0.0000)
# ✓ All missing values imputed (664 filled)
#
# ======================================================================
# OVERALL QUALITY: POOR ⚠️ (Score: 2/5)
# Significant differences detected. Imputation may have introduced bias.
#
# Issues:
#   - Mean shifted by $+19.12 (+4.5%)
#   - Distribution changed (KS p = 0.0000)
#
# Warnings:
#   - Std dev changed by +18.5%
#
# ======================================================================
# Validating: Hotel_21
# ======================================================================
# ✓ Loaded pre-imputation: 7954 rows
# ✓ Loaded post-imputation: 6450 rows
# ✓ Common dates: 645
# ✓ Common competitors: 10
# ✓ Aligned datasets: 6450 rows each
#
# -------------------------Missing Data Summary-------------------------
# Total rows: 6,450
# Missing before: 525 (8.1%)
# Missing after: 0 (0.0%)
# Values imputed: 525
#
# -----------------Distribution Preservation (KS Test)------------------
# Sample sizes:
#   Pre (observed): 5925
#   Post (all): 6450
#
# Statistic       Pre             Post            Delta
# ----------------------------------------------------------------------
# Mean            $247.07         $249.07         $         +2.00
# Median          $238.41         $238.86         $         +0.45
# Std Dev         $64.41          $66.79          $         +2.38
# Min             $125.30         $125.30
# Max             $844.88         $844.88
#
# Kolmogorov-Smirnov Test:
#   KS Statistic: 0.0131
#   p-value: 0.6615
#   Result: Distributions SIMILAR ✓ (p > 0.05)
#
# --------------------------Overall Assessment--------------------------
# ✓ Mean preserved (Δ = $+2.00)
# ✓ Std dev preserved (Δ = $+2.38)
# ✓ Distribution similar (KS p = 0.6615)
# ✓ All missing values imputed (525 filled)
#
# ======================================================================
# OVERALL QUALITY: EXCELLENT ✓ (Score: 5/5)
# Imputation successfully preserved original characteristics!
#
# ======================================================================
# Validating: Hotel_22
# ======================================================================
# ✓ Loaded pre-imputation: 7173 rows
# ✓ Loaded post-imputation: 6075 rows
# ✓ Common dates: 675
# ✓ Common competitors: 9
# ✓ Aligned datasets: 6075 rows each
#
# -------------------------Missing Data Summary-------------------------
# Total rows: 6,075
# Missing before: 570 (9.4%)
# Missing after: 0 (0.0%)
# Values imputed: 570
#
# -----------------Distribution Preservation (KS Test)------------------
# Sample sizes:
#   Pre (observed): 5505
#   Post (all): 6075
#
# Statistic       Pre             Post            Delta
# ----------------------------------------------------------------------
# Mean            $199.62         $204.89         $         +5.27
# Median          $185.00         $189.00         $         +4.00
# Std Dev         $59.91          $62.59          $         +2.67
# Min             $99.99          $99.99
# Max             $699.00         $699.00
# Kolmogorov-Smirnov Test:
#   KS Statistic: 0.0403
#   p-value: 0.0002
#   Result: Distributions DIFFER ⚠️ (p < 0.05)
#
# --------------------------Overall Assessment--------------------------
# ✓ Mean preserved (Δ = $+5.27)
# ✓ Std dev preserved (Δ = $+2.67)
# ✗ Distribution differs (KS p = 0.0002)
# ✓ All missing values imputed (570 filled)
#
# ======================================================================
# OVERALL QUALITY: GOOD ✓ (Score: 4/5)
# Minor differences detected but generally good preservation.
#
# Issues:
#   - Distribution changed (KS p = 0.0002)
#
# ======================================================================
# Validating: Hotel_23
# ======================================================================
# ✓ Loaded pre-imputation: 7830 rows
# ✓ Loaded post-imputation: 6810 rows
# ✓ Common dates: 681
# ✓ Common competitors: 10
# ✓ Aligned datasets: 6786 rows each
#
# -------------------------Missing Data Summary-------------------------
# Total rows: 6,786
# Missing before: 1,247 (18.4%)
# Missing after: 0 (0.0%)
# Values imputed: 1,247
#
# -----------------Distribution Preservation (KS Test)------------------
# Sample sizes:
#   Pre (observed): 5539
#   Post (all): 6810
#
# Statistic       Pre             Post            Delta
# ----------------------------------------------------------------------
# Mean            $417.12         $410.32         $         -6.80
# Median          $409.00         $389.99         $        -19.01
# Std Dev         $138.05         $129.42         $         -8.63
# Min             $206.15         $0.00
# Max             $2221.00        $2221.00
#
# Kolmogorov-Smirnov Test:
#   KS Statistic: 0.0475
#   p-value: 0.0000
#   Result: Distributions DIFFER ⚠️ (p < 0.05)
#
# --------------------------Overall Assessment--------------------------
# ✓ Mean preserved (Δ = $-6.80)
# ✓ Std dev preserved (Δ = $-8.63)
# ✗ Distribution differs (KS p = 0.0000)
# ✓ All missing values imputed (1247 filled)
#
# ======================================================================
# OVERALL QUALITY: GOOD ✓ (Score: 4/5)
# Minor differences detected but generally good preservation.
#
# Issues:
#   - Distribution changed (KS p = 0.0000)
#
# ======================================================================
# Validating: Hotel_24
# ======================================================================
# ✓ Loaded pre-imputation: 7970 rows
# ✓ Loaded post-imputation: 6140 rows
# ✓ Common dates: 614
# ✓ Common competitors: 10
# ✓ Aligned datasets: 6140 rows each
#
# -------------------------Missing Data Summary-------------------------
# Total rows: 6,140
# Missing before: 614 (10.0%)
# Missing after: 0 (0.0%)
# Values imputed: 614
#
# -----------------Distribution Preservation (KS Test)------------------
# Sample sizes:
#   Pre (observed): 5526
#   Post (all): 6140
#
# Statistic       Pre             Post            Delta
# ----------------------------------------------------------------------
# Mean            $241.88         $242.33         $         +0.45
# Median          $229.00         $228.91         $         -0.09
# Std Dev         $86.80          $89.21          $         +2.41
# Min             $79.00          $79.00
# Max             $750.29         $750.29
#
# Kolmogorov-Smirnov Test:
#   KS Statistic: 0.0146
#   p-value: 0.5617
#   Result: Distributions SIMILAR ✓ (p > 0.05)
#
# --------------------------Overall Assessment--------------------------
# ✓ Mean preserved (Δ = $+0.45)
# ✓ Std dev preserved (Δ = $+2.41)
# ✓ Distribution similar (KS p = 0.5617)
# ✓ All missing values imputed (614 filled)
#
# ======================================================================
# OVERALL QUALITY: EXCELLENT ✓ (Score: 5/5)
# Imputation successfully preserved original characteristics!
#
# ======================================================================
# Validating: Hotel_25
# ======================================================================
# ✓ Loaded pre-imputation: 7970 rows
# ✓ Loaded post-imputation: 6740 rows
# ✓ Common dates: 674
# ✓ Common competitors: 10
# ✓ Aligned datasets: 6740 rows each
#
# -------------------------Missing Data Summary-------------------------
# Total rows: 6,740
# Missing before: 1,376 (20.4%)
# Missing after: 0 (0.0%)
# Values imputed: 1,376
#
# -----------------Distribution Preservation (KS Test)------------------
# Sample sizes:
#   Pre (observed): 5364
#   Post (all): 6740
#
# Statistic       Pre             Post            Delta
# ----------------------------------------------------------------------
# Mean            $152.40         $153.80         $         +1.39
# Median          $140.08         $146.32         $         +6.23
# Std Dev         $48.69          $48.06          $         -0.63
# Min             $62.10          $20.28
# Max             $477.00         $477.00
#
# Kolmogorov-Smirnov Test:
#   KS Statistic: 0.0358
#   p-value: 0.0009
#   Result: Distributions DIFFER ⚠️ (p < 0.05)
#
# --------------------------Overall Assessment--------------------------
# ✓ Mean preserved (Δ = $+1.39)
# ✓ Std dev preserved (Δ = $-0.63)
# ✗ Distribution differs (KS p = 0.0009)
# ✓ All missing values imputed (1376 filled)
#
# ======================================================================
# OVERALL QUALITY: GOOD ✓ (Score: 4/5)
# Minor differences detected but generally good preservation.
#
# Issues:
#   - Distribution changed (KS p = 0.0009)
#
# ======================================================================
# Validating: Hotel_26
# ======================================================================
# ✓ Loaded pre-imputation: 7970 rows
# ✓ Loaded post-imputation: 6750 rows
# ✓ Common dates: 675
# ✓ Common competitors: 10
# ✓ Aligned datasets: 6750 rows each
#
# -------------------------Missing Data Summary-------------------------
# Total rows: 6,750
# Missing before: 2,391 (35.4%)
# Missing after: 0 (0.0%)
# Values imputed: 2,391
#
# -----------------Distribution Preservation (KS Test)------------------
# Sample sizes:
#   Pre (observed): 4359
#   Post (all): 6750
#
# Statistic       Pre             Post            Delta
# ----------------------------------------------------------------------
# Mean            $376.05         $390.44         $        +14.39
# Median          $365.00         $378.28         $        +13.28
# Std Dev         $117.54         $115.94         $         -1.59
# Min             $163.20         $161.65
# Max             $1144.00        $1144.00
#
# Kolmogorov-Smirnov Test:
#   KS Statistic: 0.0664
#   p-value: 0.0000
#   Result: Distributions DIFFER ⚠️ (p < 0.05)
#
# --------------------------Overall Assessment--------------------------
# ✗ Mean shifted significantly: $+14.39
# ✓ Std dev preserved (Δ = $-1.59)
# ✗ Distribution differs (KS p = 0.0000)
# ✓ All missing values imputed (2391 filled)
#
# ======================================================================
# OVERALL QUALITY: POOR ⚠️ (Score: 2/5)
# Significant differences detected. Imputation may have introduced bias.
#
# Issues:
#   - Mean shifted by $+14.39 (+3.8%)
#   - Distribution changed (KS p = 0.0000)
#
# ======================================================================
# Validating: Hotel_27
# ======================================================================
# ✓ Loaded pre-imputation: 2150 rows
# ✓ Loaded post-imputation: 2150 rows
# ✓ Common dates: 430
# ✓ Common competitors: 5
# ✓ Aligned datasets: 2150 rows each
#
# -------------------------Missing Data Summary-------------------------
# Total rows: 2,150
# Missing before: 645 (30.0%)
# Missing after: 0 (0.0%)
# Values imputed: 645
#
# -----------------Distribution Preservation (KS Test)------------------
# Sample sizes:
#   Pre (observed): 1505
#   Post (all): 2150
#
# Statistic       Pre             Post            Delta
# ----------------------------------------------------------------------
# Mean            $247.53         $258.44         $        +10.91
# Median          $205.32         $232.00         $        +26.68
# Std Dev         $148.63         $140.97         $         -7.66
# Min             $71.10          $71.10
# Max             $777.72         $944.36
#
# Kolmogorov-Smirnov Test:
#   KS Statistic: 0.0968
#   p-value: 0.0000
#   Result: Distributions DIFFER ⚠️ (p < 0.05)
#
# --------------------------Overall Assessment--------------------------
# ✓ Mean preserved (Δ = $+10.91)
# ✓ Std dev preserved (Δ = $-7.66)
# ✗ Distribution differs (KS p = 0.0000)
# ✓ All missing values imputed (645 filled)
#
# ======================================================================
# OVERALL QUALITY: GOOD ✓ (Score: 4/5)
# Minor differences detected but generally good preservation.
#
# Issues:
#   - Distribution changed (KS p = 0.0000)
#
# ======================================================================
# Validating: Hotel_28
# ======================================================================
# ✓ Loaded pre-imputation: 4800 rows
# ✓ Loaded post-imputation: 3600 rows
# ✓ Common dates: 600
# ✓ Common competitors: 6
# ✓ Aligned datasets: 3600 rows each
#
# -------------------------Missing Data Summary-------------------------
# Total rows: 3,600
# Missing before: 2,392 (66.4%)
# Missing after: 0 (0.0%)
# Values imputed: 2,392
#
# -----------------Distribution Preservation (KS Test)------------------
# Sample sizes:
#   Pre (observed): 1208
#   Post (all): 3600
#
# Statistic       Pre             Post            Delta
# ----------------------------------------------------------------------
# Mean            $150.60         $147.79         $         -2.81
# Median          $123.27         $148.95         $        +25.68
# Std Dev         $95.77          $68.22          $        -27.56
# Min             $34.50          $34.50
# Max             $775.72         $775.72
#
# Kolmogorov-Smirnov Test:
#   KS Statistic: 0.1800
#   p-value: 0.0000
#   Result: Distributions DIFFER ⚠️ (p < 0.05)
#
# --------------------------Overall Assessment--------------------------
# ✓ Mean preserved (Δ = $-2.81)
# ⚠  Std dev changed: $-27.56
# ✗ Distribution differs (KS p = 0.0000)
# ✓ All missing values imputed (2392 filled)
#
# ======================================================================
# OVERALL QUALITY: FAIR (Score: 3/5)
# Some differences detected. Review carefully.
#
# Issues:
#   - Distribution changed (KS p = 0.0000)
#
# Warnings:
#   - Std dev changed by -28.8%
#
# ======================================================================
# Validating: Hotel_29
# ======================================================================
# ✓ Loaded pre-imputation: 1670 rows
# ✓ Loaded post-imputation: 1670 rows
# ✓ Common dates: 167
# ✓ Common competitors: 10
# ✓ Aligned datasets: 1670 rows each
#
# -------------------------Missing Data Summary-------------------------
# Total rows: 1,670
# Missing before: 762 (45.6%)
# Missing after: 0 (0.0%)
# Values imputed: 762
#
# -----------------Distribution Preservation (KS Test)------------------
# Sample sizes:
#   Pre (observed): 908
#   Post (all): 1670
#
# Statistic       Pre             Post            Delta
# ----------------------------------------------------------------------
# Mean            $138.08         $140.64         $         +2.56
# Median          $131.00         $132.05         $         +1.05
# Std Dev         $52.12          $47.97          $         -4.15
# Min             $72.00          $70.52
# Max             $575.00         $575.00
#
# Kolmogorov-Smirnov Test:
#   KS Statistic: 0.0865
#   p-value: 0.0003
#   Result: Distributions DIFFER ⚠️ (p < 0.05)
#
# --------------------------Overall Assessment--------------------------
# ✓ Mean preserved (Δ = $+2.56)
# ✓ Std dev preserved (Δ = $-4.15)
# ✗ Distribution differs (KS p = 0.0003)
# ✓ All missing values imputed (762 filled)
#
# ======================================================================
# OVERALL QUALITY: GOOD ✓ (Score: 4/5)
# Minor differences detected but generally good preservation.
#
# Issues:
#   - Distribution changed (KS p = 0.0003)
#
# ======================================================================
# Validating: Hotel_30
# ======================================================================
# ✓ Loaded pre-imputation: 2391 rows
# ✓ Loaded post-imputation: 2040 rows
# ✓ Common dates: 680
# ✓ Common competitors: 3
# ✓ Aligned datasets: 2040 rows each
#
# -------------------------Missing Data Summary-------------------------
# Total rows: 2,040
# Missing before: 324 (15.9%)
# Missing after: 0 (0.0%)
# Values imputed: 324
#
# -----------------Distribution Preservation (KS Test)------------------
# Sample sizes:
#   Pre (observed): 1716
#   Post (all): 2040
#
# Statistic       Pre             Post            Delta
# ----------------------------------------------------------------------
# Mean            $168.02         $165.87         $         -2.15
# Median          $121.84         $125.45         $         +3.61
# Std Dev         $162.85         $150.87         $        -11.98
# Min             $60.00          $60.00
# Max             $795.45         $795.45
#
# Kolmogorov-Smirnov Test:
#   KS Statistic: 0.0327
#   p-value: 0.2628
#   Result: Distributions SIMILAR ✓ (p > 0.05)
#
# --------------------------Overall Assessment--------------------------
# ✓ Mean preserved (Δ = $-2.15)
# ✓ Std dev preserved (Δ = $-11.98)
# ✓ Distribution similar (KS p = 0.2628)
# ✓ All missing values imputed (324 filled)
#
# ======================================================================
# OVERALL QUALITY: EXCELLENT ✓ (Score: 5/5)
# Imputation successfully preserved original characteristics!
#
# ======================================================================
# Validating: Hotel_31
# ======================================================================
# ✓ Loaded pre-imputation: 4242 rows
# ✓ Loaded post-imputation: 4086 rows
# ✓ Common dates: 681
# ✓ Common competitors: 6
# ✓ Aligned datasets: 4086 rows each
#
# -------------------------Missing Data Summary-------------------------
# Total rows: 4,086
# Missing before: 573 (14.0%)
# Missing after: 0 (0.0%)
# Values imputed: 573
#
# -----------------Distribution Preservation (KS Test)------------------
# Sample sizes:
#   Pre (observed): 3513
#   Post (all): 4086
#
# Statistic       Pre             Post            Delta
# ----------------------------------------------------------------------
# Mean            $301.93         $313.49         $        +11.57
# Median          $266.00         $274.57         $         +8.57
# Std Dev         $142.96         $151.04         $         +8.09
# Min             $119.99         $119.99
# Max             $1269.00        $1269.00
#
# Kolmogorov-Smirnov Test:
#   KS Statistic: 0.0328
#   p-value: 0.0337
#   Result: Distributions DIFFER ⚠️ (p < 0.05)
#
# --------------------------Overall Assessment--------------------------
# ✓ Mean preserved (Δ = $+11.57)
# ✓ Std dev preserved (Δ = $+8.09)
# ✗ Distribution differs (KS p = 0.0337)
# ✓ All missing values imputed (573 filled)
#
# ======================================================================
# OVERALL QUALITY: GOOD ✓ (Score: 4/5)
# Minor differences detected but generally good preservation.
#
# Issues:
#   - Distribution changed (KS p = 0.0337)
#
# ======================================================================
# Validating: Hotel_32
# ======================================================================
# ✓ Loaded pre-imputation: 3135 rows
# ✓ Loaded post-imputation: 3010 rows
# ✓ Common dates: 602
# ✓ Common competitors: 5
# ✓ Aligned datasets: 3010 rows each
#
# -------------------------Missing Data Summary-------------------------
# Total rows: 3,010
# Missing before: 392 (13.0%)
# Missing after: 0 (0.0%)
# Values imputed: 392
#
# -----------------Distribution Preservation (KS Test)------------------
# Sample sizes:
#   Pre (observed): 2618
#   Post (all): 3010
#
# Statistic       Pre             Post            Delta
# ----------------------------------------------------------------------
# Mean            $529.42         $545.64         $        +16.22
# Median          $489.00         $499.00         $        +10.00
# Std Dev         $169.60         $181.20         $        +11.60
# Min             $262.65         $262.65
# Max             $1742.00        $1742.00
#
# Kolmogorov-Smirnov Test:
#   KS Statistic: 0.0422
#   p-value: 0.0130
#   Result: Distributions DIFFER ⚠️ (p < 0.05)
#
# --------------------------Overall Assessment--------------------------
# ✓ Mean preserved (Δ = $+16.22)
# ✓ Std dev preserved (Δ = $+11.60)
# ✗ Distribution differs (KS p = 0.0130)
# ✓ All missing values imputed (392 filled)
#
# ======================================================================
# OVERALL QUALITY: GOOD ✓ (Score: 4/5)
# Minor differences detected but generally good preservation.
#
# Issues:
#   - Distribution changed (KS p = 0.0130)
#
# ======================================================================
# Validating: Hotel_33
# ======================================================================
# ✓ Loaded pre-imputation: 4782 rows
# ✓ Loaded post-imputation: 4080 rows
# ✓ Common dates: 680
# ✓ Common competitors: 6
# ✓ Aligned datasets: 4080 rows each
#
# -------------------------Missing Data Summary-------------------------
# Total rows: 4,080
# Missing before: 659 (16.2%)
# Missing after: 0 (0.0%)
# Values imputed: 659
#
# -----------------Distribution Preservation (KS Test)------------------
# Sample sizes:
#   Pre (observed): 3421
#   Post (all): 4080
#
# Statistic       Pre             Post            Delta
# ----------------------------------------------------------------------
# Mean            $165.30         $169.30         $         +4.00
# Median          $152.10         $157.00         $         +4.90
# Std Dev         $50.29          $50.11          $         -0.18
# Min             $42.48          $42.48
# Max             $549.00         $549.00
#
# Kolmogorov-Smirnov Test:
#   KS Statistic: 0.0527
#   p-value: 0.0001
#   Result: Distributions DIFFER ⚠️ (p < 0.05)
#
# --------------------------Overall Assessment--------------------------
# ✓ Mean preserved (Δ = $+4.00)
# ✓ Std dev preserved (Δ = $-0.18)
# ✗ Distribution differs (KS p = 0.0001)
# ✓ All missing values imputed (659 filled)
#
# ======================================================================
# OVERALL QUALITY: GOOD ✓ (Score: 4/5)
# Minor differences detected but generally good preservation.
#
# Issues:
#   - Distribution changed (KS p = 0.0001)
#
# ======================================================================
# Validating: Hotel_34
# ======================================================================
# ✓ Loaded pre-imputation: 4270 rows
# ✓ Loaded post-imputation: 4256 rows
# ✓ Common dates: 608
# ✓ Common competitors: 7
# ✓ Aligned datasets: 4256 rows each
#
# -------------------------Missing Data Summary-------------------------
# Total rows: 4,256
# Missing before: 916 (21.5%)
# Missing after: 0 (0.0%)
# Values imputed: 916
#
# -----------------Distribution Preservation (KS Test)------------------
# Sample sizes:
#   Pre (observed): 3340
#   Post (all): 4256
#
# Statistic       Pre             Post            Delta
# ----------------------------------------------------------------------
# Mean            $745.07         $732.03         $        -13.05
# Median          $544.79         $531.31         $        -13.48
# Std Dev         $586.10         $577.06         $         -9.04
# Min             $218.00         $218.00
# Max             $5088.50        $5088.50
#
# Kolmogorov-Smirnov Test:
#   KS Statistic: 0.0258
#   p-value: 0.1612
#   Result: Distributions SIMILAR ✓ (p > 0.05)
#
# --------------------------Overall Assessment--------------------------
# ✓ Mean preserved (Δ = $-13.05)
# ✓ Std dev preserved (Δ = $-9.04)
# ✓ Distribution similar (KS p = 0.1612)
# ✓ All missing values imputed (916 filled)
#
# ======================================================================
# OVERALL QUALITY: EXCELLENT ✓ (Score: 5/5)
# Imputation successfully preserved original characteristics!
#
# ======================================================================
# Validating: Hotel_35
# ======================================================================
# ✓ Loaded pre-imputation: 3192 rows
# ✓ Loaded post-imputation: 3184 rows
# ✓ Common dates: 398
# ✓ Common competitors: 8
# ✓ Aligned datasets: 3184 rows each
#
# -------------------------Missing Data Summary-------------------------
# Total rows: 3,184
# Missing before: 336 (10.6%)
# Missing after: 0 (0.0%)
# Values imputed: 336
#
# -----------------Distribution Preservation (KS Test)------------------
# Sample sizes:
#   Pre (observed): 2848
#   Post (all): 3184
#
# Statistic       Pre             Post            Delta
# ----------------------------------------------------------------------
# Mean            $243.26         $245.87         $         +2.61
# Median          $201.14         $206.32         $         +5.18
# Std Dev         $123.10         $122.09         $         -1.01
# Min             $104.06         $79.25
# Max             $1233.00        $1233.00
#
# Kolmogorov-Smirnov Test:
#   KS Statistic: 0.0224
#   p-value: 0.4274
#   Result: Distributions SIMILAR ✓ (p > 0.05)
#
# --------------------------Overall Assessment--------------------------
# ✓ Mean preserved (Δ = $+2.61)
# ✓ Std dev preserved (Δ = $-1.01)
# ✓ Distribution similar (KS p = 0.4274)
# ✓ All missing values imputed (336 filled)
#
# ======================================================================
# OVERALL QUALITY: EXCELLENT ✓ (Score: 5/5)
# Imputation successfully preserved original characteristics!
#
# ======================================================================
# Validating: Hotel_36
# ======================================================================
# ✓ Loaded pre-imputation: 4782 rows
# ✓ Loaded post-imputation: 4080 rows
# ✓ Common dates: 680
# ✓ Common competitors: 6
# ✓ Aligned datasets: 4080 rows each
#
# -------------------------Missing Data Summary-------------------------
# Total rows: 4,080
# Missing before: 1,026 (25.1%)
# Missing after: 0 (0.0%)
# Values imputed: 1,026
#
# -----------------Distribution Preservation (KS Test)------------------
# Sample sizes:
#   Pre (observed): 3054
#   Post (all): 4080
#
# Statistic       Pre             Post            Delta
# ----------------------------------------------------------------------
# Mean            $359.87         $339.11         $        -20.76
# Median          $249.75         $242.46         $         -7.29
# Std Dev         $285.44         $263.58         $        -21.87
# Min             $60.00          $60.00
# Max             $1641.60        $1641.60
#
# Kolmogorov-Smirnov Test:
#   KS Statistic: 0.0465
#   p-value: 0.0010
#   Result: Distributions DIFFER ⚠️ (p < 0.05)
#
# --------------------------Overall Assessment--------------------------
# ✓ Mean preserved (Δ = $-20.76)
# ✓ Std dev preserved (Δ = $-21.87)
# ✗ Distribution differs (KS p = 0.0010)
# ✓ All missing values imputed (1026 filled)
#
# ======================================================================
# OVERALL QUALITY: GOOD ✓ (Score: 4/5)
# Minor differences detected but generally good preservation.
#
# Issues:
#   - Distribution changed (KS p = 0.0010)
#
# ======================================================================
# Validating: Hotel_37
# ======================================================================
# ✓ Loaded pre-imputation: 1995 rows
# ✓ Loaded post-imputation: 1990 rows
# ✓ Common dates: 398
# ✓ Common competitors: 5
# ✓ Aligned datasets: 1990 rows each
#
# -------------------------Missing Data Summary-------------------------
# Total rows: 1,990
# Missing before: 264 (13.3%)
# Missing after: 0 (0.0%)
# Values imputed: 264
#
# -----------------Distribution Preservation (KS Test)------------------
# Sample sizes:
#   Pre (observed): 1726
#   Post (all): 1990
#
# Statistic       Pre             Post            Delta
# ----------------------------------------------------------------------
# Mean            $175.23         $203.54         $        +28.30
# Median          $155.38         $160.65         $         +5.28
# Std Dev         $79.60          $140.49         $        +60.90
# Min             $107.00         $0.00
# Max             $734.64         $2031.78
#
# Kolmogorov-Smirnov Test:
#   KS Statistic: 0.0827
#   p-value: 0.0000
#   Result: Distributions DIFFER ⚠️ (p < 0.05)
#
# --------------------------Overall Assessment--------------------------
# ✗ Mean shifted significantly: $+28.30
# ⚠  Std dev changed: $+60.90
# ✗ Distribution differs (KS p = 0.0000)
# ✓ All missing values imputed (264 filled)
#
# ======================================================================
# OVERALL QUALITY: POOR ⚠️ (Score: 2/5)
# Significant differences detected. Imputation may have introduced bias.
#
# Issues:
#   - Mean shifted by $+28.30 (+16.2%)
#   - Distribution changed (KS p = 0.0000)
#
# Warnings:
#   - Std dev changed by +76.5%
#
# ======================================================================
# Validating: Hotel_38
# ======================================================================
# ✓ Loaded pre-imputation: 2940 rows
# ✓ Loaded post-imputation: 2534 rows
# ✓ Common dates: 362
# ✓ Common competitors: 7
# ✓ Aligned datasets: 2534 rows each
#
# -------------------------Missing Data Summary-------------------------
# Total rows: 2,534
# Missing before: 116 (4.6%)
# Missing after: 0 (0.0%)
# Values imputed: 116
#
# -----------------Distribution Preservation (KS Test)------------------
# Sample sizes:
#   Pre (observed): 2418
#   Post (all): 2534
#
# Statistic       Pre             Post            Delta
# ----------------------------------------------------------------------
# Mean            $421.38         $423.80         $         +2.41
# Median          $399.00         $409.00         $        +10.00
# Std Dev         $168.51         $166.04         $         -2.47
# Min             $163.18         $163.18
# Max             $1183.84        $1183.84
#
# Kolmogorov-Smirnov Test:
#   KS Statistic: 0.0195
#   p-value: 0.7246
#   Result: Distributions SIMILAR ✓ (p > 0.05)
#
# --------------------------Overall Assessment--------------------------
# ✓ Mean preserved (Δ = $+2.41)
# ✓ Std dev preserved (Δ = $-2.47)
# ✓ Distribution similar (KS p = 0.7246)
# ✓ All missing values imputed (116 filled)
#
# ======================================================================
# OVERALL QUALITY: EXCELLENT ✓ (Score: 5/5)
# Imputation successfully preserved original characteristics!
#
# ======================================================================
# Validating: Hotel_39
# ======================================================================
# ✓ Loaded pre-imputation: 4620 rows
# ✓ Loaded post-imputation: 3550 rows
# ✓ Common dates: 355
# ✓ Common competitors: 10
# ✓ Aligned datasets: 3550 rows each
#
# -------------------------Missing Data Summary-------------------------
# Total rows: 3,550
# Missing before: 313 (8.8%)
# Missing after: 0 (0.0%)
# Values imputed: 313
#
# -----------------Distribution Preservation (KS Test)------------------
# Sample sizes:
#   Pre (observed): 3237
#   Post (all): 3550
#
# Statistic       Pre             Post            Delta
# ----------------------------------------------------------------------
# Mean            $3387.09        $3364.25        $        -22.84
# Median          $3080.00        $3066.80        $        -13.20
# Std Dev         $1436.41        $1432.83        $         -3.58
# Min             $715.00         $715.00
# Max             $33660.00       $33660.00
#
# Kolmogorov-Smirnov Test:
#   KS Statistic: 0.0168
#   p-value: 0.7164
#   Result: Distributions SIMILAR ✓ (p > 0.05)
#
# --------------------------Overall Assessment--------------------------
# ✓ Mean preserved (Δ = $-22.84)
# ✓ Std dev preserved (Δ = $-3.58)
# ✓ Distribution similar (KS p = 0.7164)
# ✓ All missing values imputed (313 filled)
#
# ======================================================================
# OVERALL QUALITY: EXCELLENT ✓ (Score: 5/5)
# Imputation successfully preserved original characteristics!
#
# ======================================================================
# Validating: Hotel_40
# ======================================================================
# ✓ Loaded pre-imputation: 3619 rows
# ✓ Loaded post-imputation: 3122 rows
# ✓ Common dates: 446
# ✓ Common competitors: 7
# ✓ Aligned datasets: 3082 rows each
#
# -------------------------Missing Data Summary-------------------------
# Total rows: 3,082
# Missing before: 494 (16.0%)
# Missing after: 0 (0.0%)
# Values imputed: 494
#
# -----------------Distribution Preservation (KS Test)------------------
# Sample sizes:
#   Pre (observed): 2588
#   Post (all): 3122
#
# Statistic       Pre             Post            Delta
# ----------------------------------------------------------------------
# Mean            $320.11         $312.90         $         -7.21
# Median          $239.00         $239.00         $         +0.00
# Std Dev         $513.51         $477.51         $        -36.00
# Min             $101.15         $0.00
# Max             $10098.99       $10098.99
#
# Kolmogorov-Smirnov Test:
#   KS Statistic: 0.0377
#   p-value: 0.0346
#   Result: Distributions DIFFER ⚠️ (p < 0.05)
#
# --------------------------Overall Assessment--------------------------
# ✓ Mean preserved (Δ = $-7.21)
# ✓ Std dev preserved (Δ = $-36.00)
# ✗ Distribution differs (KS p = 0.0346)
# ✓ All missing values imputed (494 filled)
#
# ======================================================================
# OVERALL QUALITY: GOOD ✓ (Score: 4/5)
# Minor differences detected but generally good preservation.
#
# Issues:
#   - Distribution changed (KS p = 0.0346)
#
# ======================================================================
# Validating: Hotel_41
# ======================================================================
# ✓ Loaded pre-imputation: 2580 rows
# ✓ Loaded post-imputation: 2580 rows
# ✓ Common dates: 430
# ✓ Common competitors: 6
# ✓ Aligned datasets: 2580 rows each
#
# -------------------------Missing Data Summary-------------------------
# Total rows: 2,580
# Missing before: 600 (23.3%)
# Missing after: 0 (0.0%)
# Values imputed: 600
#
# -----------------Distribution Preservation (KS Test)------------------
# Sample sizes:
#   Pre (observed): 1980
#   Post (all): 2580
#
# Statistic       Pre             Post            Delta
# ----------------------------------------------------------------------
# Mean            $359.51         $397.07         $        +37.56
# Median          $281.34         $311.34         $        +30.00
# Std Dev         $229.71         $258.95         $        +29.24
# Min             $139.00         $139.00
# Max             $1399.00        $1490.55
#
# Kolmogorov-Smirnov Test:
#   KS Statistic: 0.0745
#   p-value: 0.0000
#   Result: Distributions DIFFER ⚠️ (p < 0.05)
#
# --------------------------Overall Assessment--------------------------
# ✗ Mean shifted significantly: $+37.56
# ⚠  Std dev changed: $+29.24
# ✗ Distribution differs (KS p = 0.0000)
# ✓ All missing values imputed (600 filled)
#
# ======================================================================
# OVERALL QUALITY: POOR ⚠️ (Score: 2/5)
# Significant differences detected. Imputation may have introduced bias.
#
# Issues:
#   - Mean shifted by $+37.56 (+10.4%)
#   - Distribution changed (KS p = 0.0000)
#
# Warnings:
#   - Std dev changed by +12.7%
#
# --------------------------Validation Summary--------------------------
# Successful: 38/39
# Failed: 1/39
#
# ======================================================================
# SUMMARY REPORT - ALL HOTELS
# ======================================================================
#
# Total hotels validated: 38
# Mean missing data: 22.3%
# Median missing data: 16.8%
#
# Quality Distribution:
#   EXCELLENT ✓    : 15 ( 39.5%) ███████
#   GOOD ✓         : 13 ( 34.2%) ██████
#   FAIR           :  2 (  5.3%) █
#   POOR ⚠️        :  8 ( 21.1%) ████
#
# Mean Delta Distribution:
#   Mean of mean deltas: $4.52
#   Median of mean deltas: $2.30
#   Hotels with negative bias: 4
#   Hotels with positive bias: 10
#
# Top 5 Hotels (Best Quality):
# hotel_id  pct_missing  mean_delta  ks_pvalue     quality
# Hotel_02     4.941860   -0.215216   0.914608 EXCELLENT ✓
# Hotel_05    21.779412    0.500929   0.272454 EXCELLENT ✓
# Hotel_06     7.918149    3.901738   0.476470 EXCELLENT ✓
# Hotel_09    40.000000    4.308805   0.997159 EXCELLENT ✓
# Hotel_12    17.292292    0.884389   0.690512 EXCELLENT ✓
#
# Bottom 5 Hotels (Issues Detected):
# hotel_id  pct_missing  mean_delta    ks_pvalue quality
# Hotel_01    30.733453   29.215706 6.209911e-07 POOR ⚠️
# Hotel_03    21.058465   22.659312 1.341771e-03 POOR ⚠️
# Hotel_10    52.462017  -18.100118 8.757192e-27 POOR ⚠️
# Hotel_15    10.518519   31.434782 5.753999e-04 POOR ⚠️
# Hotel_20    43.229167   19.115738 7.909320e-06 POOR ⚠️
# ✓ Summary saved: imputation_validation_results/imputation_validation_summary.csv
# ✓ Details saved: imputation_validation_results/imputation_validation_details.json
#
# ======================================================================
# VALIDATION COMPLETE!
# ======================================================================
#
# Results saved to: imputation_validation_results/
#   - imputation_validation_summary.csv (summary table)
#   - imputation_validation_details.json (full details)
#
# ⚠️  Note: 10 hotels have FAIR or POOR quality
#    Review imputation_validation_summary.csv for details
